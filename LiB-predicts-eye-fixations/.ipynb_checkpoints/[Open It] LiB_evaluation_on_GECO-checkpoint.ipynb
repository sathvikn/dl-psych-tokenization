# %%
# %pylab inline

import os
import unicodedata
import string
import re
import random
import scipy.stats
import importlib
from sklearn import metrics
import seaborn as sns
import pandas as pd

import warnings
warnings.filterwarnings('ignore') 

import LiB
model = LiB.model

import pickle

for fn in ['geco_mono',
           'geco_l1',
           'line_ends_english',
            'line_ends_dutch',
            'tokens_l1_all',
            'sents_l1_all',
            'tokens_mono_all',
            'sents_mono_all',
            'sents_with_line_ends_without_repeat_nl',
            'sents_with_line_ends_without_repeat_en',]:
    with open(fn, 'rb') as f: 
        exec(f"{fn} = pickle.load(f)")

geco_res = {
    'L1': (geco_l1,tokens_l1_all,sents_l1_all),
    'mono': (geco_mono,tokens_mono_all,sents_mono_all)
    }
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Demo of Segmentation

# %%
importlib.reload(LiB)
model = LiB.model

'Define the train/test corpus'
corpus = model.create_corpus('br-text.txt')
'New and init a memory'
m_geco_en = model(corpus, lexicon_in=0.25, lexicon_out=0.0001, update_rate=0.2, life=3)

'RUN!!!'
m_geco_en.logs['note'] = 0
for epoch_id in range(0,501):
    m_geco_en.run(epoch_id, article_length=200, test_interval=100);
    if epoch_id > 1 and epoch_id % 100 == 0 and \
            m_geco_en.logs['eval_index'][-1] > m_geco_en.logs['eval_index'][-2]:
        break
            
print(f"Time cost for training: {sum(m_geco_en.logs['time_cost'])//60} min {sum(m_geco_en.logs['time_cost'])%60:.1f}s\n")

print('Raw/LiB segmentation:')
m_geco_en.show_result(corpus[:10])
# Out:
# 0	  MemLength: 403 3.8	  ChunkLength: 2.24	  EvalIndex: 3.856
#
# 100	  MemLength: 2337 7.1	  ChunkLength: 5.74	  EvalIndex: 1.950 Change:49.4%
#
# 200	  MemLength: 2868 7.6	  ChunkLength: 6.19	  EvalIndex: 1.855 Change:4.9%
#
# 300	  MemLength: 3115 8.0	  ChunkLength: 6.45	  EvalIndex: 1.800 Change:3.0%
#
# 400	  MemLength: 3373 8.3	  ChunkLength: 6.67	  EvalIndex: 1.757 Change:2.4%
#
# 500	  MemLength: 3522 8.5	  ChunkLength: 6.79	  EvalIndex: 1.734 Change:1.3%
#
# Time cost for training: 0.0 min 5.1s
#
# Raw/LiB segmentation:
# you |want |to |see |the |book
# you want to |see the |book
#
# look |there's |a |boy |with |his |hat
# look |there's a |boy |with |his |hat
#
# and |a |doggie
# and a |doggie
#
# you |want |to |look |at |this
# you want to |look at this
#
# look |at |this
# look at this
#
# have |a |drink
# have |a |drink
#
# okay |now
# okay now
#
# what's |this
# what's this
#
# what's |that
# what's that
#
# what |is |it
# what is it

# %% [markdown]
# ## Eye-fixation Predicting

# %%
# Execute this cell if you need corpus_coca and corpus_sonar
for fn in ['corpus_coca',
           'corpus_sonar',]:
    with open(fn, 'rb') as f: 
        exec(f"{fn} = pickle.load(f)")

# %%
importlib.reload(LiB)
model = LiB.model

'Define the train/test set'
corpus_train = sents_with_line_ends_without_repeat_en
corpus_test = sents_with_line_ends_without_repeat_en
'New and init a memory'
m_geco_en = model(corpus_train, corpus_test, lexicon_in=0.25, lexicon_out=0.0001, update_rate=0.2, life=3)

'RUN!!!'
m_geco_en.logs['note'] = 0
for epoch_id in range(0,10001):
    m_geco_en.run(epoch_id, article_length=200, test_interval=100);
    if epoch_id > 1 and epoch_id % 100 == 0 and \
            m_geco_en.logs['eval_index'][-1] > m_geco_en.logs['eval_index'][-2]:
        break
            
f1 = m_geco_en.predict_eye_fixations(geco_res['mono'], show_length=True);
print(f"Time cost for training: {sum(m_geco_en.logs['time_cost'])//60}min{sum(m_geco_en.logs['time_cost'])%60}s")
# Out:
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3677 6.3	  ChunkLength: 4.67	  EvalIndex: 2.535 Change:39.8%
#
# 200	  MemLength: 4412 6.8	  ChunkLength: 5.02	  EvalIndex: 2.411 Change:4.9%
#
# 300	  MemLength: 5108 7.1	  ChunkLength: 5.28	  EvalIndex: 2.333 Change:3.2%
#
# 400	  MemLength: 5640 7.4	  ChunkLength: 5.45	  EvalIndex: 2.287 Change:2.0%
#
# 500	  MemLength: 6229 7.7	  ChunkLength: 5.62	  EvalIndex: 2.243 Change:2.0%
#
# 600	  MemLength: 6470 7.8	  ChunkLength: 5.70	  EvalIndex: 2.219 Change:1.1%
#
# 700	  MemLength: 6737 8.0	  ChunkLength: 5.79	  EvalIndex: 2.197 Change:1.0%
#
# 800	  MemLength: 7227 8.1	  ChunkLength: 5.91	  EvalIndex: 2.170 Change:1.2%
#
# 900	  MemLength: 7451 8.2	  ChunkLength: 5.98	  EvalIndex: 2.150 Change:0.9%
#
# 1000	  MemLength: 7862 8.5	  ChunkLength: 6.07	  EvalIndex: 2.133 Change:0.8%
#
# 1100	  MemLength: 8077 8.4	  ChunkLength: 6.11	  EvalIndex: 2.125 Change:0.4%
#
# 1200	  MemLength: 8298 8.6	  ChunkLength: 6.17	  EvalIndex: 2.109 Change:0.7%
#
# 1300	  MemLength: 8416 8.6	  ChunkLength: 6.22	  EvalIndex: 2.097 Change:0.6%
#
# 1400	  MemLength: 8563 8.7	  ChunkLength: 6.25	  EvalIndex: 2.090 Change:0.4%
#
# 1500	  MemLength: 8779 8.8	  ChunkLength: 6.29	  EvalIndex: 2.083 Change:0.3%
#
# 1600	  MemLength: 9049 8.9	  ChunkLength: 6.35	  EvalIndex: 2.070 Change:0.7%
#
# 1700	  MemLength: 9169 9.0	  ChunkLength: 6.38	  EvalIndex: 2.062 Change:0.4%
#
# 1800	  MemLength: 9398 9.0	  ChunkLength: 6.43	  EvalIndex: 2.053 Change:0.4%
#
# 1900	  MemLength: 9499 9.0	  ChunkLength: 6.45	  EvalIndex: 2.048 Change:0.3%
#
# 2000	  MemLength: 9746 9.2	  ChunkLength: 6.50	  EvalIndex: 2.038 Change:0.5%
#
# 2100	  MemLength: 9899 9.2	  ChunkLength: 6.55	  EvalIndex: 2.027 Change:0.5%
#
# 2200	  MemLength: 10011 9.3	  ChunkLength: 6.56	  EvalIndex: 2.025 Change:0.1%
#
# 2300	  MemLength: 10189 9.3	  ChunkLength: 6.59	  EvalIndex: 2.019 Change:0.3%
#
# 2400	  MemLength: 10311 9.4	  ChunkLength: 6.62	  EvalIndex: 2.014 Change:0.3%
#
# 2500	  MemLength: 10584 9.5	  ChunkLength: 6.68	  EvalIndex: 2.002 Change:0.6%
#
# 2600	  MemLength: 10807 9.5	  ChunkLength: 6.72	  EvalIndex: 1.995 Change:0.3%
#
# 2700	  MemLength: 10964 9.6	  ChunkLength: 6.75	  EvalIndex: 1.988 Change:0.3%
#
# 2800	  MemLength: 11135 9.6	  ChunkLength: 6.79	  EvalIndex: 1.981 Change:0.4%
#
# 2900	  MemLength: 11355 9.7	  ChunkLength: 6.82	  EvalIndex: 1.975 Change:0.3%
#
# 3000	  MemLength: 11518 9.8	  ChunkLength: 6.85	  EvalIndex: 1.969 Change:0.3%
#
# 3100	  MemLength: 11774 9.9	  ChunkLength: 6.91	  EvalIndex: 1.958 Change:0.6%
#
# 3200	  MemLength: 11989 10.0	  ChunkLength: 6.95	  EvalIndex: 1.950 Change:0.4%
#
# 3300	  MemLength: 12187 10.1	  ChunkLength: 6.99	  EvalIndex: 1.942 Change:0.4%
#
# 3400	  MemLength: 12442 10.1	  ChunkLength: 7.02	  EvalIndex: 1.937 Change:0.3%
#
# 3500	  MemLength: 12479 10.2	  ChunkLength: 7.03	  EvalIndex: 1.935 Change:0.1%
#
# 3600	  MemLength: 12620 10.2	  ChunkLength: 7.07	  EvalIndex: 1.928 Change:0.3%
#
# 3700	  MemLength: 12852 10.3	  ChunkLength: 7.12	  EvalIndex: 1.918 Change:0.6%
#
# 3800	  MemLength: 12917 10.3	  ChunkLength: 7.13	  EvalIndex: 1.916 Change:0.1%
#
# 3900	  MemLength: 12999 10.4	  ChunkLength: 7.14	  EvalIndex: 1.913 Change:0.2%
#
# 4000	  MemLength: 13091 10.4	  ChunkLength: 7.16	  EvalIndex: 1.911 Change:0.1%
#
# 4100	  MemLength: 13212 10.4	  ChunkLength: 7.19	  EvalIndex: 1.905 Change:0.3%
#
# 4200	  MemLength: 13487 10.5	  ChunkLength: 7.24	  EvalIndex: 1.895 Change:0.5%
#
# 4300	  MemLength: 13648 10.5	  ChunkLength: 7.28	  EvalIndex: 1.886 Change:0.4%
#
# 4400	  MemLength: 13741 10.6	  ChunkLength: 7.29	  EvalIndex: 1.886 Change:0.0%
#
# 4500	  MemLength: 13918 10.6	  ChunkLength: 7.33	  EvalIndex: 1.877 Change:0.5%
#
# 4600	  MemLength: 14063 10.7	  ChunkLength: 7.36	  EvalIndex: 1.873 Change:0.2%
#
# 4700	  MemLength: 14167 10.7	  ChunkLength: 7.39	  EvalIndex: 1.866 Change:0.3%
#
# 4800	  MemLength: 14155 10.8	  ChunkLength: 7.39	  EvalIndex: 1.866 Change:0.0%
#
# 4900	  MemLength: 14543 10.8	  ChunkLength: 7.44	  EvalIndex: 1.859 Change:0.4%
#
# 5000	  MemLength: 14664 10.9	  ChunkLength: 7.47	  EvalIndex: 1.854 Change:0.3%
#
# 5100	  MemLength: 14647 10.9	  ChunkLength: 7.48	  EvalIndex: 1.849 Change:0.2%
#
# 5200	  MemLength: 14822 11.0	  ChunkLength: 7.50	  EvalIndex: 1.847 Change:0.1%
#
# 5300	  MemLength: 14906 11.0	  ChunkLength: 7.52	  EvalIndex: 1.843 Change:0.2%
#
# 5400	  MemLength: 15212 11.1	  ChunkLength: 7.57	  EvalIndex: 1.835 Change:0.4%
#
# 5500	  MemLength: 15203 11.1	  ChunkLength: 7.57	  EvalIndex: 1.834 Change:0.0%
#
# 5600	  MemLength: 15299 11.2	  ChunkLength: 7.60	  EvalIndex: 1.830 Change:0.2%
#
# 5700	  MemLength: 15368 11.1	  ChunkLength: 7.62	  EvalIndex: 1.825 Change:0.2%
#
# 5800	  MemLength: 15569 11.2	  ChunkLength: 7.66	  EvalIndex: 1.817 Change:0.5%
#
# 5900	  MemLength: 15651 11.2	  ChunkLength: 7.69	  EvalIndex: 1.813 Change:0.2%
#
# 6000	  MemLength: 15743 11.3	  ChunkLength: 7.71	  EvalIndex: 1.808 Change:0.3%
#
# 6100	  MemLength: 15843 11.3	  ChunkLength: 7.73	  EvalIndex: 1.806 Change:0.1%
#
# 6200	  MemLength: 15867 11.3	  ChunkLength: 7.73	  EvalIndex: 1.806 Change:-0.0%
#
# [Length] Word 5.353 Pred 7.718 Real 7.820	Model_SE 0.007 CI 0.018
# [F1] Model 53.06 Word 38.32	Time cost for training: 2.0min28.630129098892212s

# %%
importlib.reload(LiB)
model = LiB.model

'Define the train/test set'
corpus_train = sents_with_line_ends_without_repeat_nl
corpus_test = sents_with_line_ends_without_repeat_nl
'New and init a memory'
m_geco_nl = model(corpus_train, corpus_test, lexicon_in=0.25, lexicon_out=0.0001, update_rate=0.2, life=3)
m_geco_nl.max_len = None

'RUN!!!'
m_geco_nl.logs['note'] = 0
for epoch_id in range(0,10001):
    m_geco_nl.run(epoch_id, article_length=200, test_interval=100);
    if epoch_id > 1 and epoch_id % 100 == 0:
        if m_geco_nl.logs['eval_index'][-1] > m_geco_nl.logs['eval_index'][-2]:
            break
            
f1 = m_geco_nl.predict_eye_fixations(geco_res['L1'], show_length=True);
print(f"Time cost for training: {sum(m_geco_nl.logs['time_cost'])//60}min{sum(m_geco_nl.logs['time_cost'])%60}s")
# Out:
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.909
#
# 100	  MemLength: 4020 6.8	  ChunkLength: 4.87	  EvalIndex: 2.461 Change:37.1%
#
# 200	  MemLength: 5057 7.2	  ChunkLength: 5.26	  EvalIndex: 2.338 Change:5.0%
#
# 300	  MemLength: 5503 7.5	  ChunkLength: 5.49	  EvalIndex: 2.262 Change:3.3%
#
# 400	  MemLength: 6046 7.8	  ChunkLength: 5.67	  EvalIndex: 2.214 Change:2.1%
#
# 500	  MemLength: 6611 8.2	  ChunkLength: 5.83	  EvalIndex: 2.178 Change:1.6%
#
# 600	  MemLength: 7114 8.4	  ChunkLength: 5.94	  EvalIndex: 2.156 Change:1.0%
#
# 700	  MemLength: 7359 8.5	  ChunkLength: 6.02	  EvalIndex: 2.134 Change:1.0%
#
# 800	  MemLength: 7715 8.7	  ChunkLength: 6.11	  EvalIndex: 2.114 Change:0.9%
#
# 900	  MemLength: 8088 8.8	  ChunkLength: 6.19	  EvalIndex: 2.098 Change:0.8%
#
# 1000	  MemLength: 8400 8.9	  ChunkLength: 6.26	  EvalIndex: 2.081 Change:0.8%
#
# 1100	  MemLength: 8800 9.1	  ChunkLength: 6.34	  EvalIndex: 2.066 Change:0.8%
#
# 1200	  MemLength: 8916 9.1	  ChunkLength: 6.37	  EvalIndex: 2.059 Change:0.3%
#
# 1300	  MemLength: 9369 9.2	  ChunkLength: 6.44	  EvalIndex: 2.048 Change:0.6%
#
# 1400	  MemLength: 9646 9.3	  ChunkLength: 6.50	  EvalIndex: 2.035 Change:0.6%
#
# 1500	  MemLength: 9874 9.5	  ChunkLength: 6.55	  EvalIndex: 2.025 Change:0.5%
#
# 1600	  MemLength: 9995 9.5	  ChunkLength: 6.58	  EvalIndex: 2.020 Change:0.3%
#
# 1700	  MemLength: 10289 9.6	  ChunkLength: 6.64	  EvalIndex: 2.006 Change:0.7%
#
# 1800	  MemLength: 10256 9.6	  ChunkLength: 6.65	  EvalIndex: 2.004 Change:0.1%
#
# 1900	  MemLength: 10718 9.7	  ChunkLength: 6.72	  EvalIndex: 1.992 Change:0.6%
#
# 2000	  MemLength: 10831 9.8	  ChunkLength: 6.75	  EvalIndex: 1.985 Change:0.3%
#
# 2100	  MemLength: 11093 9.9	  ChunkLength: 6.79	  EvalIndex: 1.978 Change:0.3%
#
# 2200	  MemLength: 11278 10.0	  ChunkLength: 6.83	  EvalIndex: 1.970 Change:0.4%
#
# 2300	  MemLength: 11622 10.0	  ChunkLength: 6.89	  EvalIndex: 1.960 Change:0.5%
#
# 2400	  MemLength: 11965 10.2	  ChunkLength: 6.95	  EvalIndex: 1.950 Change:0.5%
#
# 2500	  MemLength: 12027 10.2	  ChunkLength: 6.97	  EvalIndex: 1.946 Change:0.2%
#
# 2600	  MemLength: 12208 10.3	  ChunkLength: 7.00	  EvalIndex: 1.939 Change:0.4%
#
# 2700	  MemLength: 12269 10.3	  ChunkLength: 7.01	  EvalIndex: 1.936 Change:0.1%
#
# 2800	  MemLength: 12494 10.3	  ChunkLength: 7.06	  EvalIndex: 1.927 Change:0.5%
#
# 2900	  MemLength: 12666 10.4	  ChunkLength: 7.09	  EvalIndex: 1.923 Change:0.2%
#
# 3000	  MemLength: 12874 10.4	  ChunkLength: 7.12	  EvalIndex: 1.917 Change:0.3%
#
# 3100	  MemLength: 12958 10.5	  ChunkLength: 7.14	  EvalIndex: 1.914 Change:0.2%
#
# 3200	  MemLength: 13118 10.5	  ChunkLength: 7.17	  EvalIndex: 1.907 Change:0.4%
#
# 3300	  MemLength: 13303 10.6	  ChunkLength: 7.21	  EvalIndex: 1.901 Change:0.3%
#
# 3400	  MemLength: 13344 10.6	  ChunkLength: 7.22	  EvalIndex: 1.898 Change:0.2%
#
# 3500	  MemLength: 13490 10.6	  ChunkLength: 7.25	  EvalIndex: 1.894 Change:0.2%
#
# 3600	  MemLength: 13711 10.7	  ChunkLength: 7.28	  EvalIndex: 1.887 Change:0.3%
#
# 3700	  MemLength: 13813 10.7	  ChunkLength: 7.31	  EvalIndex: 1.882 Change:0.3%
#
# 3800	  MemLength: 13966 10.9	  ChunkLength: 7.33	  EvalIndex: 1.878 Change:0.2%
#
# 3900	  MemLength: 14217 10.9	  ChunkLength: 7.38	  EvalIndex: 1.869 Change:0.5%
#
# 4000	  MemLength: 14414 11.0	  ChunkLength: 7.42	  EvalIndex: 1.862 Change:0.3%
#
# 4100	  MemLength: 14430 10.9	  ChunkLength: 7.43	  EvalIndex: 1.860 Change:0.1%
#
# 4200	  MemLength: 14599 11.0	  ChunkLength: 7.46	  EvalIndex: 1.854 Change:0.3%
#
# 4300	  MemLength: 14946 11.1	  ChunkLength: 7.52	  EvalIndex: 1.843 Change:0.6%
#
# 4400	  MemLength: 15110 11.2	  ChunkLength: 7.55	  EvalIndex: 1.838 Change:0.3%
#
# 4500	  MemLength: 15226 11.2	  ChunkLength: 7.58	  EvalIndex: 1.834 Change:0.2%
#
# 4600	  MemLength: 15449 11.3	  ChunkLength: 7.62	  EvalIndex: 1.826 Change:0.5%
#
# 4700	  MemLength: 15783 11.4	  ChunkLength: 7.68	  EvalIndex: 1.815 Change:0.6%
#
# 4800	  MemLength: 15922 11.4	  ChunkLength: 7.70	  EvalIndex: 1.812 Change:0.2%
#
# 4900	  MemLength: 16015 11.5	  ChunkLength: 7.73	  EvalIndex: 1.806 Change:0.3%
#
# 5000	  MemLength: 16217 11.5	  ChunkLength: 7.76	  EvalIndex: 1.801 Change:0.3%
#
# 5100	  MemLength: 16331 11.6	  ChunkLength: 7.79	  EvalIndex: 1.797 Change:0.2%
#
# 5200	  MemLength: 16560 11.6	  ChunkLength: 7.83	  EvalIndex: 1.790 Change:0.4%
#
# 5300	  MemLength: 16659 11.7	  ChunkLength: 7.86	  EvalIndex: 1.785 Change:0.3%
#
# 5400	  MemLength: 16861 11.7	  ChunkLength: 7.89	  EvalIndex: 1.779 Change:0.3%
#
# 5500	  MemLength: 16889 11.7	  ChunkLength: 7.90	  EvalIndex: 1.778 Change:0.1%
#
# 5600	  MemLength: 17021 11.8	  ChunkLength: 7.93	  EvalIndex: 1.773 Change:0.3%
#
# 5700	  MemLength: 17244 11.9	  ChunkLength: 7.97	  EvalIndex: 1.766 Change:0.4%
#
# 5800	  MemLength: 17452 11.9	  ChunkLength: 8.02	  EvalIndex: 1.757 Change:0.5%
#
# 5900	  MemLength: 17525 12.0	  ChunkLength: 8.02	  EvalIndex: 1.758 Change:-0.1%
#
# [Length] Word 5.596 Pred 8.004 Real 8.194	Model_SE 0.009 CI 0.023
# [F1] Model 51.87 Word 38.68	Time cost for training: 2.0min52.065295934677124s

# %%
# Training on COCA
importlib.reload(LiB)
model = LiB.model

'Define the train/test set'
corpus_test = sents_with_line_ends_without_repeat_en

'New and init a memory'
m_geco_coca = model(corpus_coca[0], corpus_test, lexicon_in=0.25, lexicon_out=0.0001, update_rate=0.2, life=3)
m_geco_coca.max_len = None
interval = 1000
m_geco_coca.logs['eval_index'] = [10]

'RUN!!!'
corpus_train = [(art_id, i) for art_id in range(len(corpus_coca)) for i in range(0,len(corpus_coca[art_id]),200)]
rag = list(range(0,len(corpus_train)))
random.shuffle(rag)
for epoch_id in range(len(rag)):
    art_id, i = corpus_train[epoch_id]
    m_geco_coca.corpus_train = corpus_coca[art_id][i:i+200]
    m_geco_coca.run(epoch_id, article_length=None, test_interval=interval);
    
f1 = m_geco_coca.predict_eye_fixations(geco_res['mono'], show_length=True);
print(sum(m_geco_coca.logs['time_cost']),sum(m_geco_coca.logs['time_cost'])//60,sum(m_geco_coca.logs['time_cost'])%60)
# Out:
# 0	  MemLength: 1063 4.1	  ChunkLength: 2.37	  B: 14524 1053011 1067535 2.881
#
# 1000	  MemLength: 30273 9.7	  ChunkLength: 4.78	  B: 158989 665686 824675 1.809 26.6
#
# 2000	  MemLength: 41460 9.9	  ChunkLength: 5.14	  B: 197964 635900 833864 1.717 4.0
#
# 3000	  MemLength: 50413 10.0	  ChunkLength: 5.39	  B: 227508 616512 844021 1.654 3.0
#
# 4000	  MemLength: 56828 9.9	  ChunkLength: 5.65	  B: 252706 596670 849375 1.592 3.5
#
# 5000	  MemLength: 65192 10.0	  ChunkLength: 5.74	  B: 261730 589368 851097 1.571 0.3
#
# 6000	  MemLength: 71336 10.0	  ChunkLength: 5.79	  B: 268021 586112 854133 1.563 -0.0
#
# 7000	  MemLength: 77213 10.1	  ChunkLength: 5.84	  B: 272702 580930 853632 1.550 0.2
#
# 8000	  MemLength: 83199 10.2	  ChunkLength: 5.91	  B: 281360 576032 857392 1.534 0.5
#
# 9000	  MemLength: 85876 10.2	  ChunkLength: 6.02	  B: 287359 568305 855664 1.510 1.5
#
# 10000	  MemLength: 89326 10.3	  ChunkLength: 6.08	  B: 292763 564031 856794 1.496 0.7
#
# 11000	  MemLength: 95898 10.5	  ChunkLength: 6.11	  B: 298013 562132 860146 1.490 -0.1
#
# [Length] Word 5.35 Pred 6.17 First 7.82 Total 6.64	[F1] First 53.46 38.32	Total 46.49 29.04
#
# 1491.1521384716034 24.0 51.152138471603394

# %%
# Training on SoNaR
importlib.reload(LiB)
model = LiB.model

'Define the train/test set'
corpus_test = sents_with_line_ends_without_repeat_nl

'New and init a memory'
m_geco_sonar = model(corpus_sonar[0], corpus_test, lexicon_in=0.25, lexicon_out=0.0001, update_rate=0.2, life=3)
m_geco_sonar.max_len = None
interval = 1000
m_geco_sonar.logs['eval_index'] = [10]

'RUN!!!'
corpus_train = [(art_id, i) for art_id in range(len(corpus_sonar)) for i in range(0,len(corpus_sonar[art_id]),200)]
rag = list(range(0,len(corpus_train)))
random.shuffle(rag)
for epoch_id in range(len(rag)):
    art_id, i = corpus_train[epoch_id]
    m_geco_sonar.corpus_train = corpus_sonar[art_id][i:i+200]
    m_geco_sonar.run(epoch_id, article_length=None, test_interval=interval);
    
f1 = m_geco_sonar.predict_eye_fixations(geco_res['L1'], show_length=True);
print(sum(m_geco_sonar.logs['time_cost']),sum(m_geco_sonar.logs['time_cost'])//60,sum(m_geco_sonar.logs['time_cost'])%60)
# Out:
# [Length] Word 5.60 Pred 6.91 First 8.19 Total 7.03	[F1] First 53.72 38.68	Total 46.89 29.76
#
# 4325.843949556351 72.0 5.843949556350708

# %% [markdown]
# # CBL

# %%
from itertools import accumulate,groupby
def CBL_predict_eye_fixations(shallow_parses_for_inference, corpus, adjust=None, target='WORD_FIRST_RUN_FIXATION_COUNT', return_fixations=False):
    cbl_result = dict([(' '.join(l) + ' ').replace('|| ',''), 
                       (' '.join(l) + ' ').split('|| ')] 
                          for l in shallow_parses_for_inference)
    
    fixations0_ = []
    fixations1_ = []
    tokens_ = []
    len0_ = []
    len1_ = []
    unit_len_model = []

    for geco,tokens,sents in zip(*corpus): # corpus: sentences_x,tokens_x_all,sents_x_all
        jump = 0
        chunks = []
        sent_idx = 0
        while sent_idx < len(sents):
            if sents[sent_idx] in cbl_result:
                chunks.extend(cbl_result[sents[sent_idx]])
                sent_idx += 1
            else:
                jump = 1
                break
        if jump == 1:
            continue
        
        len0_.extend([len(c) for c in tokens])
        len1_.extend([len(c) for c in chunks])
        chunk_pos = list(accumulate([len(c) for c in chunks]))

        chunk_pos_0 = set(accumulate([len(c) for c in tokens]))
        chunk_pos_0, chunk_pos = [0] + sorted(chunk_pos_0),[0] + sorted(chunk_pos)
        
        unit_len_model.extend([n-m for m,n in zip(chunk_pos[:-1],chunk_pos[1:])])

        fix_pos = [(n+m)/2 for m,n in zip(chunk_pos[:-1],chunk_pos[1:])]

        fix_pos = np.array(fix_pos)
        fixations1 = [len(fix_pos[(a<=fix_pos)&(fix_pos<b)])
                        for a,b in zip(chunk_pos_0[:-1],chunk_pos_0[1:])]

        fixations1_.extend(fixations1)

        fixations0 = [0 if i=='.' else int(i) for i in geco[target]]
        fixations0_.extend(fixations0)
        
        tokens_.extend(tokens)
        
    # print(f'len {sum([len(i) for i in tokens_])/sum(fixations1_):.3f} {sum([len(i) for i in tokens_])/sum(fixations0_):.3f}')
    print(f'Model_len_AVG {np.mean(unit_len_model):.3f}')
    print(f'Model_len_SE {np.std(unit_len_model)/(len(unit_len_model)**0.5):.3f} CI {2.575*np.std(unit_len_model)/(len(unit_len_model)**0.5):.3f}')
        
    if return_fixations:
        return fixations0_, fixations1_, unit_len_model
    else:
        
        f1 = metrics.f1_score(fixations0_, fixations1_, average='weighted')
        f1_ = metrics.f1_score(fixations0_, [1 for i in fixations1_], average='weighted')
        print(f'f1 {f1*100:.2f} {f1_*100:.2f}')
        return f1, f1_

# %%
from other_models import cbl_modified
import time
start = time.time()
cbl_en = cbl_modified.CBL_Model()

for line in ['* '+''.join(i)+'*' for i in sents_with_line_ends_without_repeat_en]:
    cbl_en.process(line)
    
print(time.time()-start)

for line in ['* '+''.join(i)+'*' for i in sents_with_line_ends_without_repeat_en]:
    cbl_en.process_for_inference(line)
    
cbl_result_en = dict([(' '.join(l) + ' ').replace('|| ',''), 
                       (' '.join(l) + ' ').split('|| ')] 
                          for l in cbl_en.shallow_parses_for_inference)

for i in cbl_en.shallow_parses_for_inference[:10]:
    print(' '.join(i))
    
CBL_predict_eye_fixations(cbl_en.shallow_parses_for_inference, geco_res['mono'], target='WORD_FIRST_RUN_FIXATION_COUNT');
# Out:
# 0.5149741172790527
# the intense || interest || aroused || in || the public || by || what || was known || at || the time || as
# the
# styles || case
# has || now || somewhat subsided
# nevertheless
# in view || of || the world wide
# notoriety || which attended || it
# i have been asked
# both || by || my friend poirot || and || the
# family themselves
# Model_len_AVG 7.198
# Model_len_SE 0.006 CI 0.015
# f1 52.28 38.33

# %%
from other_models import cbl_modified
import time
start = time.time()
cbl_nl = cbl_modified.CBL_Model()

for line in ['* '+''.join(i)+'*' for i in sents_with_line_ends_without_repeat_nl]:
    cbl_nl.process(line)
    
print(time.time()-start)

for line in ['* '+''.join(i)+'*' for i in sents_with_line_ends_without_repeat_nl]:
    cbl_nl.process_for_inference(line)
    
cbl_result_nl = dict([(' '.join(l) + ' ').replace('|| ',''), 
                       (' '.join(l) + ' ').split('|| ')] 
                          for l in cbl_nl.shallow_parses_for_inference)

for i in cbl_nl.shallow_parses_for_inference[:10]:
    print(' '.join(i))
    
CBL_predict_eye_fixations(cbl_nl.shallow_parses_for_inference, geco_res['L1'], target='WORD_FIRST_RUN_FIXATION_COUNT');
# Out:
# 0.4550313949584961
# de || enorme belangstelling || die || het publiek toonde || voor || wat indertijd || bekend || stond
# als
# de zaak || styles
# wordt || nu || wat minder
# niettemin || is || mij
# zowel || door || mijn
# vriend poirot || als || door || de betrokken familieleden
# verzocht || een verslag || van || het
# hele || gebeuren || te schrijven
# gezien || het feit || dat || er || in || de hele wereld || grote
# Model_len_AVG 7.372
# Model_len_SE 0.008 CI 0.020
# f1 50.04 38.70

# %%
# Training on COCA
from other_models import cbl_modified
import time
start = time.time()
cbl_en_coca = cbl_modified.CBL_Model()

for line in ('* '+''.join(i)+'*' for art in corpus_coca for i in art):
    cbl_en_coca.process(line)
    
print(time.time()-start)
    
for line in ['* '+''.join(i)+'*' for i in sents_with_line_ends_without_repeat_en]:
    cbl_en_coca.process_for_inference(line)
    
cbl_result_en_coca = dict([(' '.join(l) + ' ').replace('|| ',''), 
                       (' '.join(l) + ' ').split('|| ')] 
                          for l in cbl_en_coca.shallow_parses_for_inference)
for i in cbl_en_coca.shallow_parses_for_inference[:10]:
    print(' '.join(i))
    
CBL_predict_eye_fixations(cbl_en_coca.shallow_parses_for_inference, geco_res['mono'], target='WORD_FIRST_RUN_FIXATION_COUNT');

# %%
# Training on SoNAR
from other_models import cbl_modified
import time
start = time.time()
cbl_en_sonar = cbl_modified.CBL_Model()

for line in ('* '+''.join(i)+'*' for art in corpus_sonar for i in art):
    cbl_en_sonar.process(line)
    
print(time.time()-start)
    
for line in ['* '+''.join(i)+'*' for i in sents_with_line_ends_without_repeat_nl]:
    cbl_en_sonar.process_for_inference(line)
    
cbl_result_en_sonar = dict([(' '.join(l) + ' ').replace('|| ',''), 
                       (' '.join(l) + ' ').split('|| ')] 
                          for l in cbl_en_sonar.shallow_parses_for_inference)
for i in cbl_en_sonar.shallow_parses_for_inference[:10]:
    print(' '.join(i))
    
CBL_predict_eye_fixations(cbl_en_sonar.shallow_parses_for_inference, geco_res['L1'], target='WORD_FIRST_RUN_FIXATION_COUNT');
# Out:
# 203.09252834320068
# de enorme || belangstelling || die || het publiek || toonde || voor || wat || indertijd || bekend || stond
# als
# de zaak || styles
# wordt || nu || wat || minder
# niettemin || is || mij
# zowel || door || mijn
# vriend || poirot || als || door || de betrokken || familieleden
# verzocht || een verslag || van het
# hele || gebeuren || te schrijven
# gezien || het feit || dat er || in de hele wereld || grote
# len 6.82 8.19
# f1 51.71 38.70

# %% [markdown]
# # AG

# %%
from itertools import accumulate,groupby
def AG_predict_eye_fixations(ag_result, corpus, adjust=None, target='WORD_FIRST_RUN_FIXATION_COUNT', return_fixations=False):
    fixations0_ = []
    fixations1_ = []
    tokens_ = []
    len0_ = []
    len1_ = []
    unit_len_ = []

    for geco,tokens,sents in zip(*corpus): # corpus: sentences_x,tokens_x_all,sents_x_all
        jump = 0
        chunks = []
        sent_idx = 0
        while sent_idx < len(sents):
            if sents[sent_idx] in ag_result:
                chunks.extend(ag_result[sents[sent_idx]])
                sent_idx += 1
            else:
                jump = 1
                break
        if jump == 1:
            continue
        
        len0_.extend([len(c) for c in tokens])
        len1_.extend([len(c) for c in chunks])
        chunk_pos = list(accumulate([len(c) for c in chunks]))

        chunk_pos_0 = set(accumulate([len(c) for c in tokens]))
        chunk_pos_0, chunk_pos = [0] + sorted(chunk_pos_0),[0] + sorted(chunk_pos)
        
        unit_len_.extend([n-m for m,n in zip(chunk_pos[:-1],chunk_pos[1:])])

        fix_pos = [(n+m)/2 for m,n in zip(chunk_pos[:-1],chunk_pos[1:])]

        fix_pos = np.array(fix_pos)
        fixations1 = [len(fix_pos[(a<=fix_pos)&(fix_pos<b)])
                        for a,b in zip(chunk_pos_0[:-1],chunk_pos_0[1:])]

        fixations1_.extend(fixations1)

        fixations0 = [0 if i=='.' else int(i) for i in geco[target]]
        fixations0_.extend(fixations0)
        
        tokens_.extend(tokens)
    
    # print(f'len {sum(len1_)/len(len1_):.2f} {sum(len0_)/len(len0_):.2f}')
    print(f'Model_len_AVG {np.mean(unit_len_):.3f}')
    print(f'Model_len_SE {np.std(unit_len_)/(len(unit_len_)**0.5):.3f} CI {2.575*np.std(unit_len_)/(len(unit_len_)**0.5):.3f}')
    
    if return_fixations:
        return fixations0_, fixations1_
    else:
        f1 = metrics.f1_score(fixations0_, fixations1_, average='weighted')
        f1_ = metrics.f1_score(fixations0_, [1 for i in fixations1_], average='weighted')
        print(f'f1 {f1*100:.2f} {f1_*100:.2f}')
        return f1, f1_

# %%
ag_res_col_en = dict()
with open('other_models/geco-en_Gcolloctext2_D_E_n2000_m0_t1_w1_a1e-4_b1e4_e1_f1_g10_h0.1_R-1_0.prs') as f:
    for l in f.readlines():
        chunks = [i.replace('Word ','').replace('(','').replace(')','').replace(' ','').replace("\\'","\'").replace('*',' ')
               for i in re.findall(r'\(Colloc (.*?)\)\)',l)]
        ag_res_col_en[''.join(chunks)] = chunks
ag_res_uni_en = dict()
with open('other_models/geco-en_Gcolloctext2_D_E_n2000_m0_t1_w1_a1e-4_b1e4_e1_f1_g10_h0.1_R-1_0.prs') as f:
    for l in f.readlines():
        chunks = [i.replace('(','').replace(')','').replace(' ','').replace("\\'","\'").replace('*',' ')
               for i in re.findall(r'\(Word (.*?)\)',l)]
        ag_res_uni_en[''.join(chunks)] = chunks
        
ag_res_col_nl = dict()
with open('other_models/geco-nl_Gcolloctext-nl_D_E_n2000_m0_t1_w1_a1e-4_b1e4_e1_f1_g10_h0.1_R-1_0.prs') as f:
    for l in f.readlines():
        chunks = [i.replace('Word ','').replace('(','').replace(')','').replace(' ','').replace("\\'","\'").replace('*',' ')
               for i in re.findall(r'\(Colloc (.*?)\)\)',l)]
        ag_res_col_nl[''.join(chunks)] = chunks
ag_res_uni_nl = dict()
with open('other_models/geco-nl_Gcolloctext-nl_D_E_n2000_m0_t1_w1_a1e-4_b1e4_e1_f1_g10_h0.1_R-1_0.prs') as f:
    for l in f.readlines():
        chunks = [i.replace('(','').replace(')','').replace(' ','').replace("\\'","\'").replace('*',' ')
               for i in re.findall(r'\(Word (.*?)\)',l)]
        ag_res_uni_nl[''.join(chunks)] = chunks

# %%
AG_predict_eye_fixations(ag_res_col_en, geco_res['mono']);
AG_predict_eye_fixations(ag_res_uni_en, geco_res['mono']);
AG_predict_eye_fixations(ag_res_col_nl, geco_res['L1']);
AG_predict_eye_fixations(ag_res_uni_nl, geco_res['L1']);
# Out:
# Model_len_AVG 6.720
# Model_len_SE 0.004 CI 0.010
# f1 53.34 38.33
# Model_len_AVG 3.629
# Model_len_SE 0.001 CI 0.004
# f1 30.15 38.33
# Model_len_AVG 6.670
# Model_len_SE 0.005 CI 0.012
# f1 51.45 38.71
# Model_len_AVG 3.614
# Model_len_SE 0.002 CI 0.004
# f1 28.95 38.71

# %% [markdown]
# # Distributions

# %%
fixations0, fixations_c_ag_en = AG_predict_eye_fixations(ag_res_col_en, geco_res['mono'],return_fixations=True);
fixations0, fixations_w_ag_en = AG_predict_eye_fixations(ag_res_uni_en, geco_res['mono'],return_fixations=True);
fixations0, fixations_c_ag_nl = AG_predict_eye_fixations(ag_res_col_nl, geco_res['L1'],return_fixations=True);
fixations0, fixations_w_ag_nl = AG_predict_eye_fixations(ag_res_uni_nl, geco_res['L1'],return_fixations=True);
# Out:
# Model_len_AVG 6.720
# Model_len_SE 0.004 CI 0.010
# Model_len_AVG 3.629
# Model_len_SE 0.001 CI 0.004
# Model_len_AVG 6.670
# Model_len_SE 0.005 CI 0.012
# Model_len_AVG 3.614
# Model_len_SE 0.002 CI 0.004

# %%
foo, fixations_cbl_en, unit_len_en = CBL_predict_eye_fixations(cbl_en.shallow_parses_for_inference, geco_res['mono'],
                                                 return_fixations=True);
foo, fixations_cbl_nl, unit_len_nl = CBL_predict_eye_fixations(cbl_nl.shallow_parses_for_inference, geco_res['L1'],
                                                 return_fixations=True);
# Out:
# Model_len_AVG 7.198
# Model_len_SE 0.006 CI 0.015
# Model_len_AVG 7.372
# Model_len_SE 0.008 CI 0.020

# %%
fixations_real_first_en, fixations_pred_en = m_geco_en.predict_eye_fixations(geco_res['mono'],
                                    return_fixations=True);
fixations_real_first_nl, fixations_pred_nl = m_geco_nl.predict_eye_fixations(geco_res['L1'],
                                    return_fixations=True);

# %%
## English
# %pylab inline

# start with a square Figure
fig = plt.figure(figsize=(15, 7), dpi=300)

gs = matplotlib.gridspec.GridSpec(ncols=5, nrows=2, figure=fig,
                      left=0.1, right=0.9, bottom=0.1, top=0.9,
                      wspace=0.05, hspace=0.05)

for ind,name,predicted in zip(range(4), 
                              ['LiB','CBL','AG-word','AG-collocation'], 
                              [fixations_pred_en,fixations_cbl_en,fixations_w_ag_en,fixations_c_ag_en]):
    ax_model = fig.add_subplot(gs[0, ind])
    ax_fir = fig.add_subplot(gs[1, ind], sharex=ax_model)

    model_count = [sum([i==0 for i in predicted]),
            sum([i==1 for i in predicted]),
            sum([i>1 for i in predicted])]

    ax_model.bar(['Skip','One','More'],model_count)
    ax_model.set_ylim((0,600000))
    ax_model.set_title(name, fontsize=22)
    if ind == 0:
        ax_model.set_yticks([0. ,  200000 ,  400000 ,  600000])
        ax_model.set_yticklabels([0,'2e5','4e5','6e5'], fontsize=15)
        ax_model.set_ylabel('Predicted fixation count', fontsize=14)
    else:
        ax_model.set_yticks([])
    ax_model.set_xticklabels(['','',''], fontsize=0)
    
    data, ax  = fixations_real_first_en, ax_fir
    stats = dict()
    for f1,f0 in zip(predicted, data):
        f1, f0 = f1 if f1<2 else 2, f0 if f0<2 else 2
        
        # reversed y labels
        if f0 == 0:f0 = 2
        elif f0 == 2:f0 = 0
        
        if (f1, f0) in stats:
            stats[(f1, f0)] += 1
        else:
            stats[(f1, f0)] = 0
    f1 = [f1 for (f1, f0), v in stats.items()]
    f0 = [f0 for (f1, f0), v in stats.items()]
    N = [v**0.5*2 for (f1, f0), v in stats.items()]

    ax.set_ylim((-0.5,2.5))
    if ind == 0:
        ax.set_yticks([0. ,  1 ,  2])
        ax.set_yticklabels(['More','One','Skip'], fontsize=15)
    else:
        ax.set_yticks([])
        
    ax.set_xticklabels(['Skip','One','More'], fontsize=15)
    ax.scatter(f1,f0,sizes=N)

ax_fir_hist = fig.add_subplot(gs[1, 4])

name, data, ax = 'First-pass fixation', fixations_real_first_en, ax_fir_hist
count = [sum([i>1 for i in data]),
        sum([i==1 for i in data]),
        sum([i==0 for i in data])]
ax.barh(['More','One','Skip'], count)
ax.set_xlim((0,600000))

ax.set_xticks([0. ,  200000 ,  400000 ,  600000])
ax.set_xticklabels([0,'2e5','4e5','6e5'], fontsize=15)
ax.set_xlabel('Observed fixation count', fontsize=14)
ax.yaxis.set_label_position("right")
ax.set_ylabel('GECO', fontsize=22, rotation=-90, labelpad=20)
ax.set_yticks([])

fig.text(0.37, 0.98, 'Prediction', style='italic',fontsize=20,)
fig.text(0.93, 0.17, 'Observation', style='italic',fontsize=20, rotation=-90)

plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
## Dutch
# %pylab inline

# start with a square Figure
fig = plt.figure(figsize=(15, 7), dpi=300)

gs = matplotlib.gridspec.GridSpec(ncols=5, nrows=2, figure=fig,
                      left=0.1, right=0.9, bottom=0.1, top=0.9,
                      wspace=0.05, hspace=0.05)

for ind,name,predicted in zip(range(4), 
                              ['LiB','CBL','AG-word','AG-collocation'], 
                              [fixations_pred_nl,fixations_cbl_nl,fixations_w_ag_nl,fixations_c_ag_nl]):
    ax_model = fig.add_subplot(gs[0, ind])
    ax_fir = fig.add_subplot(gs[1, ind], sharex=ax_model)

    model_count = [sum([i==0 for i in predicted]),
            sum([i==1 for i in predicted]),
            sum([i>1 for i in predicted])]

    ax_model.bar(['Skip','One','More'],model_count)
    ax_model.set_ylim((0,600000))
    ax_model.set_title(name, fontsize=22)
    if ind == 0:
        ax_model.set_yticks([0. ,  200000 ,  400000 ,  600000])
        ax_model.set_yticklabels([0,'2e5','4e5','6e5'], fontsize=15)
        ax_model.set_ylabel('Predicted fixation count', fontsize=14)
    else:
        ax_model.set_yticks([])
    ax_model.set_xticklabels(['','',''], fontsize=0)
    
    data, ax  = fixations_real_first_nl, ax_fir
    stats = dict()
    for f1,f0 in zip(predicted, data):
        f1, f0 = f1 if f1<2 else 2, f0 if f0<2 else 2
        
        # reversed y labels
        if f0 == 0:f0 = 2
        elif f0 == 2:f0 = 0
        
        if (f1, f0) in stats:
            stats[(f1, f0)] += 1
        else:
            stats[(f1, f0)] = 0
    f1 = [f1 for (f1, f0), v in stats.items()]
    f0 = [f0 for (f1, f0), v in stats.items()]
    N = [v**0.5*2 for (f1, f0), v in stats.items()]

    ax.set_ylim((-0.5,2.5))
    if ind == 0:
        ax.set_yticks([0. ,  1 ,  2])
        ax.set_yticklabels(['More','One','Skip'], fontsize=15)
    else:
        ax.set_yticks([])
        
    ax.set_xticklabels(['Skip','One','More'], fontsize=15)
    ax.scatter(f1,f0,sizes=N)

ax_fir_hist = fig.add_subplot(gs[1, 4])

name, data, ax = 'First-pass fixation', fixations_real_first_nl, ax_fir_hist
count = [sum([i>1 for i in data]),
        sum([i==1 for i in data]),
        sum([i==0 for i in data])]
ax.barh(['More','One','Skip'], count)
ax.set_xlim((0,600000))

ax.set_xticks([0. ,  200000 ,  400000 ,  600000])
ax.set_xticklabels([0,'2e5','4e5','6e5'], fontsize=15)
ax.set_xlabel('Observed fixation count', fontsize=14)
ax.yaxis.set_label_position("right")
ax.set_ylabel('GECO', fontsize=22, rotation=-90, labelpad=20)
ax.set_yticks([])

fig.text(0.37, 0.98, 'Prediction', style='italic',fontsize=20,)
fig.text(0.93, 0.17, 'Observation', style='italic',fontsize=20, rotation=-90)

plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Lengths of different types of units

# %%
fig, ax = plt.subplots(dpi=300)
sns.set_theme(style="white")
# sns.set(font_scale=5)
sns.barplot(y=['Eye fixation','Eye fixation','LiB','LiB','CBL','CBL','AG-word','AG-word','AG-collocation','AG-collocation','Word','Word',],
            x=np.array([7.819, 8.192,7.718, 8.004, 7.198 , 7.372, 3.629, 3.614, 6.720, 6.670, 5.353, 5.596, ]), palette="tab10", ax=ax, hue=['English', 'Dutch','English', 'Dutch','English', 'Dutch','English', 'Dutch','English', 'Dutch','English', 'Dutch'],orient='h')
ax.set_xlabel('Number of characters')

# ax.errorbar(y=np.arange(0,6,0.5),x=[7.82, 8.19,7.72, 8.  , 6.9 , 7.37, 3.63, 3.61, 6.72, 6.67, 5.35, 5.6 , ], xerr=0.02)
ax.errorbar(y=-0.2,x=7.819, xerr=0.018,capsize=5,c='black', uplims=True,lolims=False)
ax.errorbar(y=0.2,x=8.192, xerr=0.021,capsize=5,c='black', uplims=True,lolims=False)
ax.errorbar(y=0.8,x=7.718, xerr=0.018,capsize=5,c='black', uplims=True,lolims=False)
ax.errorbar(y=1.2,x=8.004, xerr=0.023,capsize=5,c='black', uplims=True,lolims=False)
ax.errorbar(y=1.8,x=7.198, xerr=0.015,capsize=5,c='black', uplims=True,lolims=False)
ax.errorbar(y=2.2,x=7.372, xerr=0.020,capsize=5,c='black', uplims=True,lolims=False)
ax.errorbar(y=2.8,x=3.629, xerr=0.004,capsize=5,c='black', uplims=True,lolims=False)
ax.errorbar(y=3.2,x=3.614, xerr=0.004,capsize=5,c='black', uplims=True,lolims=False)
ax.errorbar(y=3.8,x=6.720, xerr=0.010,capsize=5,c='black', uplims=True,lolims=False)
ax.errorbar(y=4.2,x=6.670, xerr=0.012,capsize=5,c='black', uplims=True,lolims=False)
ax.errorbar(y=4.8,x=5.353, xerr=0.007,capsize=5,c='black', uplims=True,lolims=False)
ax.errorbar(y=5.2,x=5.596, xerr=0.009,capsize=5,c='black', uplims=True,lolims=False)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # Different limitations of unit length

# %%
importlib.reload(LiB)
model = LiB.model

'Define the train/test set'
corpus_train = sents_with_line_ends_without_repeat_en
corpus_test = sents_with_line_ends_without_repeat_en

'New and init a memory'
for i in range(5,31):
    print()
    print(i)
    m_geco_en_t = model(corpus_train, corpus_test, lexicon_in=0.25, lexicon_out=0.0001, update_rate=0.2, life=3)
    m_geco_en_t.logs['note'] = 0
    m_geco_en_t.max_len = i

    'RUN!!!'
    for epoch_id in range(0,10001):
        m_geco_en_t.run(epoch_id, article_length=200, test_interval=100);
        if epoch_id>0 and epoch_id % 100==0:
            if m_geco_en_t.logs['eval_index'][-1] > m_geco_en_t.logs['eval_index'][-2]:
                break
    f1 = m_geco_en_t.predict_eye_fixations(geco_res['mono'], show_length=True);
# Out:
# 5
# 0	  MemLength: 551 3.4	  ChunkLength: 2.17	  EvalIndex: 4.203
#
# 100	  MemLength: 2415 4.5	  ChunkLength: 3.55	  EvalIndex: 3.165 Change:24.7%
#
# 200	  MemLength: 2742 4.5	  ChunkLength: 3.63	  EvalIndex: 3.144 Change:0.6%
#
# 300	  MemLength: 2839 4.5	  ChunkLength: 3.67	  EvalIndex: 3.123 Change:0.7%
#
# 400	  MemLength: 2907 4.5	  ChunkLength: 3.67	  EvalIndex: 3.131 Change:-0.3%
#
# [Length] Word 5.353 Pred 3.674 Real 7.820	Model_SE 0.001 CI 0.003
# [F1] Model 32.15 Word 38.32
# 6
# 0	  MemLength: 551 3.4	  ChunkLength: 2.17	  EvalIndex: 4.192
#
# 100	  MemLength: 2692 4.8	  ChunkLength: 3.83	  EvalIndex: 2.975 Change:29.0%
#
# 200	  MemLength: 3072 4.9	  ChunkLength: 3.96	  EvalIndex: 2.924 Change:1.7%
#
# 300	  MemLength: 3281 4.9	  ChunkLength: 4.02	  EvalIndex: 2.904 Change:0.7%
#
# 400	  MemLength: 3411 4.9	  ChunkLength: 4.07	  EvalIndex: 2.885 Change:0.7%
#
# 500	  MemLength: 3526 5.0	  ChunkLength: 4.08	  EvalIndex: 2.887 Change:-0.1%
#
# [Length] Word 5.353 Pred 4.080 Real 7.820	Model_SE 0.001 CI 0.004
# [F1] Model 36.93 Word 38.32
# 7
# 0	  MemLength: 551 3.5	  ChunkLength: 2.17	  EvalIndex: 4.192
#
# 100	  MemLength: 3013 5.1	  ChunkLength: 4.13	  EvalIndex: 2.798 Change:33.3%
#
# 200	  MemLength: 3422 5.3	  ChunkLength: 4.30	  EvalIndex: 2.727 Change:2.5%
#
# 300	  MemLength: 3737 5.3	  ChunkLength: 4.39	  EvalIndex: 2.701 Change:1.0%
#
# 400	  MemLength: 3948 5.4	  ChunkLength: 4.46	  EvalIndex: 2.679 Change:0.8%
#
# 500	  MemLength: 4123 5.4	  ChunkLength: 4.49	  EvalIndex: 2.675 Change:0.2%
#
# 600	  MemLength: 4322 5.4	  ChunkLength: 4.54	  EvalIndex: 2.660 Change:0.6%
#
# 700	  MemLength: 4443 5.4	  ChunkLength: 4.57	  EvalIndex: 2.654 Change:0.2%
#
# 800	  MemLength: 4501 5.4	  ChunkLength: 4.59	  EvalIndex: 2.647 Change:0.3%
#
# 900	  MemLength: 4552 5.4	  ChunkLength: 4.60	  EvalIndex: 2.644 Change:0.1%
#
# 1000	  MemLength: 4597 5.4	  ChunkLength: 4.61	  EvalIndex: 2.639 Change:0.2%
#
# 1100	  MemLength: 4646 5.4	  ChunkLength: 4.62	  EvalIndex: 2.634 Change:0.2%
#
# 1200	  MemLength: 4722 5.4	  ChunkLength: 4.63	  EvalIndex: 2.635 Change:-0.0%
#
# [Length] Word 5.353 Pred 4.631 Real 7.820	Model_SE 0.002 CI 0.004
# [F1] Model 43.94 Word 38.32
# 8
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3141 5.4	  ChunkLength: 4.28	  EvalIndex: 2.711 Change:35.6%
#
# 200	  MemLength: 3684 5.6	  ChunkLength: 4.53	  EvalIndex: 2.615 Change:3.6%
#
# 300	  MemLength: 4117 5.7	  ChunkLength: 4.68	  EvalIndex: 2.567 Change:1.8%
#
# 400	  MemLength: 4281 5.7	  ChunkLength: 4.75	  EvalIndex: 2.539 Change:1.1%
#
# 500	  MemLength: 4467 5.8	  ChunkLength: 4.81	  EvalIndex: 2.522 Change:0.7%
#
# 600	  MemLength: 4621 5.8	  ChunkLength: 4.85	  EvalIndex: 2.512 Change:0.4%
#
# 700	  MemLength: 4789 5.8	  ChunkLength: 4.88	  EvalIndex: 2.503 Change:0.3%
#
# 800	  MemLength: 4873 5.9	  ChunkLength: 4.91	  EvalIndex: 2.496 Change:0.3%
#
# 900	  MemLength: 4834 5.8	  ChunkLength: 4.92	  EvalIndex: 2.487 Change:0.4%
#
# 1000	  MemLength: 5010 5.9	  ChunkLength: 4.94	  EvalIndex: 2.487 Change:0.0%
#
# 1100	  MemLength: 5145 5.9	  ChunkLength: 4.97	  EvalIndex: 2.483 Change:0.2%
#
# 1200	  MemLength: 5267 5.9	  ChunkLength: 5.00	  EvalIndex: 2.475 Change:0.3%
#
# 1300	  MemLength: 5318 5.9	  ChunkLength: 5.01	  EvalIndex: 2.472 Change:0.1%
#
# 1400	  MemLength: 5439 6.0	  ChunkLength: 5.03	  EvalIndex: 2.466 Change:0.3%
#
# 1500	  MemLength: 5449 5.9	  ChunkLength: 5.03	  EvalIndex: 2.465 Change:0.0%
#
# 1600	  MemLength: 5519 5.9	  ChunkLength: 5.06	  EvalIndex: 2.457 Change:0.3%
#
# 1700	  MemLength: 5652 6.0	  ChunkLength: 5.07	  EvalIndex: 2.459 Change:-0.1%
#
# [Length] Word 5.353 Pred 5.066 Real 7.820	Model_SE 0.002 CI 0.005
# [F1] Model 48.27 Word 38.32
# 9
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3328 5.7	  ChunkLength: 4.42	  EvalIndex: 2.646 Change:37.2%
#
# 200	  MemLength: 3868 5.9	  ChunkLength: 4.71	  EvalIndex: 2.533 Change:4.3%
#
# 300	  MemLength: 4274 5.9	  ChunkLength: 4.88	  EvalIndex: 2.472 Change:2.4%
#
# 400	  MemLength: 4691 6.1	  ChunkLength: 5.00	  EvalIndex: 2.441 Change:1.2%
#
# 500	  MemLength: 4917 6.1	  ChunkLength: 5.06	  EvalIndex: 2.425 Change:0.7%
#
# 600	  MemLength: 5021 6.1	  ChunkLength: 5.11	  EvalIndex: 2.407 Change:0.8%
#
# 700	  MemLength: 5213 6.2	  ChunkLength: 5.16	  EvalIndex: 2.392 Change:0.6%
#
# 800	  MemLength: 5389 6.2	  ChunkLength: 5.20	  EvalIndex: 2.384 Change:0.3%
#
# 900	  MemLength: 5539 6.2	  ChunkLength: 5.24	  EvalIndex: 2.371 Change:0.5%
#
# 1000	  MemLength: 5616 6.2	  ChunkLength: 5.26	  EvalIndex: 2.366 Change:0.2%
#
# 1100	  MemLength: 5723 6.3	  ChunkLength: 5.30	  EvalIndex: 2.354 Change:0.5%
#
# 1200	  MemLength: 5936 6.3	  ChunkLength: 5.32	  EvalIndex: 2.356 Change:-0.1%
#
# [Length] Word 5.353 Pred 5.317 Real 7.820	Model_SE 0.002 CI 0.006
# [F1] Model 49.92 Word 38.32
# 10
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3433 5.9	  ChunkLength: 4.51	  EvalIndex: 2.607 Change:38.1%
#
# 200	  MemLength: 4104 6.1	  ChunkLength: 4.83	  EvalIndex: 2.487 Change:4.6%
#
# 300	  MemLength: 4557 6.2	  ChunkLength: 5.02	  EvalIndex: 2.421 Change:2.7%
#
# 400	  MemLength: 4836 6.3	  ChunkLength: 5.14	  EvalIndex: 2.381 Change:1.6%
#
# 500	  MemLength: 5119 6.4	  ChunkLength: 5.22	  EvalIndex: 2.360 Change:0.9%
#
# 600	  MemLength: 5343 6.5	  ChunkLength: 5.29	  EvalIndex: 2.339 Change:0.9%
#
# 700	  MemLength: 5516 6.5	  ChunkLength: 5.35	  EvalIndex: 2.325 Change:0.6%
#
# 800	  MemLength: 5640 6.5	  ChunkLength: 5.38	  EvalIndex: 2.317 Change:0.3%
#
# 900	  MemLength: 5745 6.5	  ChunkLength: 5.42	  EvalIndex: 2.303 Change:0.6%
#
# 1000	  MemLength: 5853 6.5	  ChunkLength: 5.44	  EvalIndex: 2.300 Change:0.1%
#
# 1100	  MemLength: 6051 6.6	  ChunkLength: 5.49	  EvalIndex: 2.287 Change:0.6%
#
# 1200	  MemLength: 6168 6.6	  ChunkLength: 5.54	  EvalIndex: 2.275 Change:0.6%
#
# 1300	  MemLength: 6443 6.6	  ChunkLength: 5.57	  EvalIndex: 2.273 Change:0.1%
#
# 1400	  MemLength: 6591 6.6	  ChunkLength: 5.59	  EvalIndex: 2.268 Change:0.2%
#
# 1500	  MemLength: 6726 6.7	  ChunkLength: 5.62	  EvalIndex: 2.262 Change:0.3%
#
# 1600	  MemLength: 6799 6.7	  ChunkLength: 5.64	  EvalIndex: 2.258 Change:0.2%
#
# 1700	  MemLength: 6963 6.8	  ChunkLength: 5.66	  EvalIndex: 2.257 Change:0.0%
#
# 1800	  MemLength: 6986 6.7	  ChunkLength: 5.67	  EvalIndex: 2.250 Change:0.3%
#
# 1900	  MemLength: 7179 6.8	  ChunkLength: 5.71	  EvalIndex: 2.245 Change:0.3%
#
# 2000	  MemLength: 7289 6.8	  ChunkLength: 5.73	  EvalIndex: 2.240 Change:0.2%
#
# 2100	  MemLength: 7384 6.8	  ChunkLength: 5.73	  EvalIndex: 2.241 Change:-0.0%
#
# [Length] Word 5.353 Pred 5.730 Real 7.820	Model_SE 0.003 CI 0.007
# [F1] Model 52.02 Word 38.32
# 11
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3390 5.9	  ChunkLength: 4.52	  EvalIndex: 2.592 Change:38.5%
#
# 200	  MemLength: 4082 6.2	  ChunkLength: 4.88	  EvalIndex: 2.456 Change:5.2%
#
# 300	  MemLength: 4627 6.4	  ChunkLength: 5.08	  EvalIndex: 2.396 Change:2.4%
#
# 400	  MemLength: 4974 6.5	  ChunkLength: 5.21	  EvalIndex: 2.359 Change:1.5%
#
# 500	  MemLength: 5369 6.6	  ChunkLength: 5.31	  EvalIndex: 2.334 Change:1.0%
#
# 600	  MemLength: 5645 6.7	  ChunkLength: 5.39	  EvalIndex: 2.312 Change:1.0%
#
# 700	  MemLength: 5821 6.8	  ChunkLength: 5.45	  EvalIndex: 2.294 Change:0.8%
#
# 800	  MemLength: 6017 6.8	  ChunkLength: 5.51	  EvalIndex: 2.280 Change:0.6%
#
# 900	  MemLength: 6211 6.8	  ChunkLength: 5.55	  EvalIndex: 2.269 Change:0.5%
#
# 1000	  MemLength: 6345 6.8	  ChunkLength: 5.59	  EvalIndex: 2.258 Change:0.5%
#
# 1100	  MemLength: 6596 6.9	  ChunkLength: 5.64	  EvalIndex: 2.248 Change:0.4%
#
# 1200	  MemLength: 6731 6.9	  ChunkLength: 5.69	  EvalIndex: 2.234 Change:0.6%
#
# 1300	  MemLength: 6909 7.0	  ChunkLength: 5.71	  EvalIndex: 2.234 Change:-0.0%
#
# [Length] Word 5.353 Pred 5.707 Real 7.820	Model_SE 0.003 CI 0.008
# [F1] Model 51.75 Word 38.32
# 12
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3363 6.0	  ChunkLength: 4.52	  EvalIndex: 2.592 Change:38.5%
#
# 200	  MemLength: 4264 6.4	  ChunkLength: 4.93	  EvalIndex: 2.446 Change:5.7%
#
# 300	  MemLength: 4868 6.6	  ChunkLength: 5.15	  EvalIndex: 2.379 Change:2.7%
#
# 400	  MemLength: 5215 6.7	  ChunkLength: 5.29	  EvalIndex: 2.333 Change:1.9%
#
# 500	  MemLength: 5417 6.7	  ChunkLength: 5.40	  EvalIndex: 2.298 Change:1.5%
#
# 600	  MemLength: 5770 6.8	  ChunkLength: 5.51	  EvalIndex: 2.269 Change:1.2%
#
# 700	  MemLength: 6057 7.0	  ChunkLength: 5.57	  EvalIndex: 2.254 Change:0.7%
#
# 800	  MemLength: 6479 7.1	  ChunkLength: 5.68	  EvalIndex: 2.230 Change:1.1%
#
# 900	  MemLength: 6648 7.1	  ChunkLength: 5.73	  EvalIndex: 2.218 Change:0.5%
#
# 1000	  MemLength: 6782 7.1	  ChunkLength: 5.77	  EvalIndex: 2.207 Change:0.5%
#
# 1100	  MemLength: 6991 7.2	  ChunkLength: 5.83	  EvalIndex: 2.191 Change:0.7%
#
# 1200	  MemLength: 7154 7.2	  ChunkLength: 5.86	  EvalIndex: 2.186 Change:0.2%
#
# 1300	  MemLength: 7201 7.2	  ChunkLength: 5.88	  EvalIndex: 2.181 Change:0.3%
#
# 1400	  MemLength: 7392 7.3	  ChunkLength: 5.91	  EvalIndex: 2.173 Change:0.3%
#
# 1500	  MemLength: 7419 7.2	  ChunkLength: 5.94	  EvalIndex: 2.165 Change:0.4%
#
# 1600	  MemLength: 7554 7.3	  ChunkLength: 5.96	  EvalIndex: 2.162 Change:0.2%
#
# 1700	  MemLength: 7769 7.4	  ChunkLength: 6.00	  EvalIndex: 2.155 Change:0.3%
#
# 1800	  MemLength: 7926 7.3	  ChunkLength: 6.03	  EvalIndex: 2.148 Change:0.3%
#
# 1900	  MemLength: 8009 7.4	  ChunkLength: 6.06	  EvalIndex: 2.140 Change:0.4%
#
# 2000	  MemLength: 8025 7.4	  ChunkLength: 6.08	  EvalIndex: 2.134 Change:0.3%
#
# 2100	  MemLength: 8179 7.4	  ChunkLength: 6.09	  EvalIndex: 2.134 Change:0.0%
#
# 2200	  MemLength: 8182 7.4	  ChunkLength: 6.11	  EvalIndex: 2.127 Change:0.3%
#
# 2300	  MemLength: 8400 7.5	  ChunkLength: 6.13	  EvalIndex: 2.126 Change:0.1%
#
# 2400	  MemLength: 8508 7.4	  ChunkLength: 6.17	  EvalIndex: 2.116 Change:0.4%
#
# 2500	  MemLength: 8678 7.5	  ChunkLength: 6.20	  EvalIndex: 2.110 Change:0.3%
#
# 2600	  MemLength: 8794 7.5	  ChunkLength: 6.23	  EvalIndex: 2.104 Change:0.3%
#
# 2700	  MemLength: 8897 7.5	  ChunkLength: 6.23	  EvalIndex: 2.105 Change:-0.1%
#
# [Length] Word 5.353 Pred 6.227 Real 7.820	Model_SE 0.003 CI 0.009
# [F1] Model 53.35 Word 38.32
# 13
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3493 6.1	  ChunkLength: 4.59	  EvalIndex: 2.566 Change:39.1%
#
# 200	  MemLength: 4435 6.6	  ChunkLength: 4.98	  EvalIndex: 2.432 Change:5.2%
#
# 300	  MemLength: 4909 6.8	  ChunkLength: 5.18	  EvalIndex: 2.366 Change:2.7%
#
# 400	  MemLength: 5437 6.9	  ChunkLength: 5.39	  EvalIndex: 2.304 Change:2.6%
#
# 500	  MemLength: 5677 7.0	  ChunkLength: 5.48	  EvalIndex: 2.277 Change:1.2%
#
# 600	  MemLength: 5854 7.1	  ChunkLength: 5.54	  EvalIndex: 2.261 Change:0.7%
#
# 700	  MemLength: 6090 7.1	  ChunkLength: 5.62	  EvalIndex: 2.239 Change:1.0%
#
# 800	  MemLength: 6546 7.3	  ChunkLength: 5.71	  EvalIndex: 2.221 Change:0.8%
#
# 900	  MemLength: 6744 7.3	  ChunkLength: 5.77	  EvalIndex: 2.206 Change:0.7%
#
# 1000	  MemLength: 6969 7.4	  ChunkLength: 5.82	  EvalIndex: 2.192 Change:0.6%
#
# 1100	  MemLength: 7241 7.4	  ChunkLength: 5.89	  EvalIndex: 2.177 Change:0.7%
#
# 1200	  MemLength: 7352 7.5	  ChunkLength: 5.93	  EvalIndex: 2.166 Change:0.5%
#
# 1300	  MemLength: 7486 7.5	  ChunkLength: 5.95	  EvalIndex: 2.161 Change:0.2%
#
# 1400	  MemLength: 7653 7.6	  ChunkLength: 5.99	  EvalIndex: 2.153 Change:0.4%
#
# 1500	  MemLength: 7640 7.6	  ChunkLength: 6.01	  EvalIndex: 2.148 Change:0.3%
#
# 1600	  MemLength: 7863 7.7	  ChunkLength: 6.04	  EvalIndex: 2.143 Change:0.2%
#
# 1700	  MemLength: 8003 7.7	  ChunkLength: 6.08	  EvalIndex: 2.131 Change:0.6%
#
# 1800	  MemLength: 8068 7.7	  ChunkLength: 6.10	  EvalIndex: 2.126 Change:0.2%
#
# 1900	  MemLength: 8192 7.7	  ChunkLength: 6.13	  EvalIndex: 2.119 Change:0.3%
#
# 2000	  MemLength: 8333 7.7	  ChunkLength: 6.16	  EvalIndex: 2.114 Change:0.3%
#
# 2100	  MemLength: 8474 7.7	  ChunkLength: 6.19	  EvalIndex: 2.110 Change:0.2%
#
# 2200	  MemLength: 8567 7.8	  ChunkLength: 6.19	  EvalIndex: 2.109 Change:0.0%
#
# 2300	  MemLength: 8611 7.8	  ChunkLength: 6.21	  EvalIndex: 2.105 Change:0.2%
#
# 2400	  MemLength: 8796 7.8	  ChunkLength: 6.25	  EvalIndex: 2.097 Change:0.4%
#
# 2500	  MemLength: 9006 7.8	  ChunkLength: 6.28	  EvalIndex: 2.091 Change:0.3%
#
# 2600	  MemLength: 9155 7.9	  ChunkLength: 6.31	  EvalIndex: 2.085 Change:0.3%
#
# 2700	  MemLength: 9211 7.9	  ChunkLength: 6.34	  EvalIndex: 2.078 Change:0.3%
#
# 2800	  MemLength: 9436 7.9	  ChunkLength: 6.38	  EvalIndex: 2.070 Change:0.4%
#
# 2900	  MemLength: 9545 7.9	  ChunkLength: 6.39	  EvalIndex: 2.071 Change:-0.0%
#
# [Length] Word 5.353 Pred 6.380 Real 7.820	Model_SE 0.004 CI 0.010
# [F1] Model 53.55 Word 38.32
# 14
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3512 6.2	  ChunkLength: 4.62	  EvalIndex: 2.552 Change:39.4%
#
# 200	  MemLength: 4391 6.6	  ChunkLength: 5.02	  EvalIndex: 2.410 Change:5.5%
#
# 300	  MemLength: 5039 6.8	  ChunkLength: 5.26	  EvalIndex: 2.336 Change:3.1%
#
# 400	  MemLength: 5558 7.0	  ChunkLength: 5.43	  EvalIndex: 2.290 Change:2.0%
#
# 500	  MemLength: 5879 7.2	  ChunkLength: 5.54	  EvalIndex: 2.261 Change:1.2%
#
# 600	  MemLength: 6187 7.3	  ChunkLength: 5.63	  EvalIndex: 2.236 Change:1.1%
#
# 700	  MemLength: 6481 7.4	  ChunkLength: 5.71	  EvalIndex: 2.217 Change:0.9%
#
# 800	  MemLength: 6811 7.5	  ChunkLength: 5.79	  EvalIndex: 2.198 Change:0.9%
#
# 900	  MemLength: 7097 7.5	  ChunkLength: 5.87	  EvalIndex: 2.180 Change:0.8%
#
# 1000	  MemLength: 7291 7.6	  ChunkLength: 5.92	  EvalIndex: 2.167 Change:0.6%
#
# 1100	  MemLength: 7496 7.6	  ChunkLength: 5.98	  EvalIndex: 2.154 Change:0.6%
#
# 1200	  MemLength: 7761 7.7	  ChunkLength: 6.03	  EvalIndex: 2.143 Change:0.5%
#
# 1300	  MemLength: 7864 7.8	  ChunkLength: 6.05	  EvalIndex: 2.139 Change:0.2%
#
# 1400	  MemLength: 8039 7.8	  ChunkLength: 6.09	  EvalIndex: 2.129 Change:0.5%
#
# 1500	  MemLength: 8226 7.8	  ChunkLength: 6.13	  EvalIndex: 2.122 Change:0.3%
#
# 1600	  MemLength: 8432 7.9	  ChunkLength: 6.18	  EvalIndex: 2.111 Change:0.5%
#
# 1700	  MemLength: 8519 7.9	  ChunkLength: 6.21	  EvalIndex: 2.101 Change:0.5%
#
# 1800	  MemLength: 8594 7.9	  ChunkLength: 6.24	  EvalIndex: 2.095 Change:0.3%
#
# 1900	  MemLength: 8663 7.9	  ChunkLength: 6.24	  EvalIndex: 2.096 Change:-0.0%
#
# [Length] Word 5.353 Pred 6.238 Real 7.820	Model_SE 0.004 CI 0.010
# [F1] Model 52.94 Word 38.32
# 15
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3728 6.2	  ChunkLength: 4.62	  EvalIndex: 2.568 Change:39.1%
#
# 200	  MemLength: 4520 6.7	  ChunkLength: 5.04	  EvalIndex: 2.408 Change:6.2%
#
# 300	  MemLength: 5099 6.9	  ChunkLength: 5.25	  EvalIndex: 2.344 Change:2.7%
#
# 400	  MemLength: 5706 7.1	  ChunkLength: 5.45	  EvalIndex: 2.288 Change:2.4%
#
# 500	  MemLength: 6068 7.3	  ChunkLength: 5.54	  EvalIndex: 2.269 Change:0.8%
#
# 600	  MemLength: 6281 7.4	  ChunkLength: 5.63	  EvalIndex: 2.241 Change:1.2%
#
# 700	  MemLength: 6583 7.4	  ChunkLength: 5.72	  EvalIndex: 2.217 Change:1.1%
#
# 800	  MemLength: 6737 7.5	  ChunkLength: 5.77	  EvalIndex: 2.203 Change:0.6%
#
# 900	  MemLength: 7019 7.6	  ChunkLength: 5.85	  EvalIndex: 2.185 Change:0.8%
#
# 1000	  MemLength: 7223 7.7	  ChunkLength: 5.91	  EvalIndex: 2.170 Change:0.7%
#
# 1100	  MemLength: 7434 7.7	  ChunkLength: 5.96	  EvalIndex: 2.158 Change:0.6%
#
# 1200	  MemLength: 7705 7.8	  ChunkLength: 6.01	  EvalIndex: 2.147 Change:0.5%
#
# 1300	  MemLength: 7942 7.8	  ChunkLength: 6.07	  EvalIndex: 2.134 Change:0.6%
#
# 1400	  MemLength: 8158 7.9	  ChunkLength: 6.13	  EvalIndex: 2.120 Change:0.7%
#
# 1500	  MemLength: 8273 8.0	  ChunkLength: 6.14	  EvalIndex: 2.119 Change:0.1%
#
# 1600	  MemLength: 8766 8.1	  ChunkLength: 6.24	  EvalIndex: 2.100 Change:0.9%
#
# 1700	  MemLength: 8901 8.1	  ChunkLength: 6.26	  EvalIndex: 2.094 Change:0.2%
#
# 1800	  MemLength: 9103 8.2	  ChunkLength: 6.31	  EvalIndex: 2.085 Change:0.5%
#
# 1900	  MemLength: 9472 8.3	  ChunkLength: 6.37	  EvalIndex: 2.074 Change:0.5%
#
# 2000	  MemLength: 9554 8.3	  ChunkLength: 6.39	  EvalIndex: 2.069 Change:0.2%
#
# 2100	  MemLength: 9741 8.3	  ChunkLength: 6.44	  EvalIndex: 2.057 Change:0.6%
#
# 2200	  MemLength: 9928 8.4	  ChunkLength: 6.47	  EvalIndex: 2.053 Change:0.2%
#
# 2300	  MemLength: 10137 8.4	  ChunkLength: 6.52	  EvalIndex: 2.042 Change:0.6%
#
# 2400	  MemLength: 10346 8.5	  ChunkLength: 6.55	  EvalIndex: 2.038 Change:0.2%
#
# 2500	  MemLength: 10314 8.4	  ChunkLength: 6.56	  EvalIndex: 2.032 Change:0.3%
#
# 2600	  MemLength: 10434 8.5	  ChunkLength: 6.56	  EvalIndex: 2.034 Change:-0.1%
#
# [Length] Word 5.353 Pred 6.557 Real 7.820	Model_SE 0.004 CI 0.011
# [F1] Model 53.42 Word 38.32
# 16
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3579 6.2	  ChunkLength: 4.57	  EvalIndex: 2.581 Change:38.7%
#
# 200	  MemLength: 4527 6.7	  ChunkLength: 5.02	  EvalIndex: 2.417 Change:6.4%
#
# 300	  MemLength: 5229 7.1	  ChunkLength: 5.26	  EvalIndex: 2.348 Change:2.9%
#
# 400	  MemLength: 5616 7.2	  ChunkLength: 5.42	  EvalIndex: 2.300 Change:2.0%
#
# 500	  MemLength: 6028 7.4	  ChunkLength: 5.55	  EvalIndex: 2.264 Change:1.6%
#
# 600	  MemLength: 6307 7.5	  ChunkLength: 5.64	  EvalIndex: 2.237 Change:1.2%
#
# 700	  MemLength: 6545 7.6	  ChunkLength: 5.72	  EvalIndex: 2.215 Change:1.0%
#
# 800	  MemLength: 7041 7.7	  ChunkLength: 5.84	  EvalIndex: 2.188 Change:1.2%
#
# 900	  MemLength: 7452 7.8	  ChunkLength: 5.95	  EvalIndex: 2.162 Change:1.2%
#
# 1000	  MemLength: 7561 7.9	  ChunkLength: 5.97	  EvalIndex: 2.157 Change:0.2%
#
# 1100	  MemLength: 7859 8.0	  ChunkLength: 6.05	  EvalIndex: 2.138 Change:0.9%
#
# 1200	  MemLength: 8038 8.0	  ChunkLength: 6.09	  EvalIndex: 2.130 Change:0.3%
#
# 1300	  MemLength: 8180 8.1	  ChunkLength: 6.12	  EvalIndex: 2.123 Change:0.4%
#
# 1400	  MemLength: 8363 8.1	  ChunkLength: 6.17	  EvalIndex: 2.113 Change:0.4%
#
# 1500	  MemLength: 8653 8.2	  ChunkLength: 6.24	  EvalIndex: 2.097 Change:0.8%
#
# 1600	  MemLength: 8772 8.3	  ChunkLength: 6.25	  EvalIndex: 2.095 Change:0.1%
#
# 1700	  MemLength: 8953 8.2	  ChunkLength: 6.29	  EvalIndex: 2.087 Change:0.4%
#
# 1800	  MemLength: 9204 8.4	  ChunkLength: 6.35	  EvalIndex: 2.074 Change:0.6%
#
# 1900	  MemLength: 9188 8.3	  ChunkLength: 6.35	  EvalIndex: 2.072 Change:0.1%
#
# 2000	  MemLength: 9531 8.4	  ChunkLength: 6.42	  EvalIndex: 2.059 Change:0.6%
#
# 2100	  MemLength: 9701 8.5	  ChunkLength: 6.45	  EvalIndex: 2.054 Change:0.3%
#
# 2200	  MemLength: 9703 8.5	  ChunkLength: 6.45	  EvalIndex: 2.053 Change:0.0%
#
# 2300	  MemLength: 9893 8.5	  ChunkLength: 6.49	  EvalIndex: 2.044 Change:0.5%
#
# 2400	  MemLength: 10123 8.6	  ChunkLength: 6.55	  EvalIndex: 2.032 Change:0.6%
#
# 2500	  MemLength: 10341 8.6	  ChunkLength: 6.57	  EvalIndex: 2.030 Change:0.1%
#
# 2600	  MemLength: 10513 8.6	  ChunkLength: 6.60	  EvalIndex: 2.024 Change:0.3%
#
# 2700	  MemLength: 10826 8.7	  ChunkLength: 6.66	  EvalIndex: 2.013 Change:0.5%
#
# 2800	  MemLength: 10899 8.7	  ChunkLength: 6.67	  EvalIndex: 2.010 Change:0.1%
#
# 2900	  MemLength: 11000 8.7	  ChunkLength: 6.70	  EvalIndex: 2.003 Change:0.3%
#
# 3000	  MemLength: 11043 8.8	  ChunkLength: 6.71	  EvalIndex: 2.001 Change:0.1%
#
# 3100	  MemLength: 11045 8.8	  ChunkLength: 6.72	  EvalIndex: 2.000 Change:0.1%
#
# 3200	  MemLength: 11270 8.8	  ChunkLength: 6.75	  EvalIndex: 1.994 Change:0.3%
#
# 3300	  MemLength: 11318 8.8	  ChunkLength: 6.77	  EvalIndex: 1.990 Change:0.2%
#
# 3400	  MemLength: 11318 8.8	  ChunkLength: 6.77	  EvalIndex: 1.988 Change:0.1%
#
# 3500	  MemLength: 11364 8.8	  ChunkLength: 6.78	  EvalIndex: 1.987 Change:0.0%
#
# 3600	  MemLength: 11495 8.9	  ChunkLength: 6.81	  EvalIndex: 1.980 Change:0.4%
#
# 3700	  MemLength: 11531 8.9	  ChunkLength: 6.81	  EvalIndex: 1.980 Change:0.0%
#
# 3800	  MemLength: 11740 8.9	  ChunkLength: 6.87	  EvalIndex: 1.968 Change:0.6%
#
# 3900	  MemLength: 11863 8.9	  ChunkLength: 6.88	  EvalIndex: 1.968 Change:-0.0%
#
# [Length] Word 5.353 Pred 6.869 Real 7.820	Model_SE 0.005 CI 0.012
# [F1] Model 53.84 Word 38.32
# 17
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3611 6.2	  ChunkLength: 4.57	  EvalIndex: 2.586 Change:38.6%
#
# 200	  MemLength: 4551 6.7	  ChunkLength: 5.02	  EvalIndex: 2.419 Change:6.4%
#
# 300	  MemLength: 5085 7.0	  ChunkLength: 5.27	  EvalIndex: 2.337 Change:3.4%
#
# 400	  MemLength: 5613 7.2	  ChunkLength: 5.46	  EvalIndex: 2.282 Change:2.3%
#
# 500	  MemLength: 5961 7.3	  ChunkLength: 5.55	  EvalIndex: 2.258 Change:1.1%
#
# 600	  MemLength: 6386 7.5	  ChunkLength: 5.68	  EvalIndex: 2.224 Change:1.5%
#
# 700	  MemLength: 6797 7.6	  ChunkLength: 5.77	  EvalIndex: 2.208 Change:0.7%
#
# 800	  MemLength: 7175 7.8	  ChunkLength: 5.88	  EvalIndex: 2.178 Change:1.3%
#
# 900	  MemLength: 7283 7.8	  ChunkLength: 5.91	  EvalIndex: 2.171 Change:0.4%
#
# 1000	  MemLength: 7604 7.9	  ChunkLength: 5.99	  EvalIndex: 2.152 Change:0.9%
#
# 1100	  MemLength: 7640 7.9	  ChunkLength: 6.02	  EvalIndex: 2.144 Change:0.4%
#
# 1200	  MemLength: 7881 7.9	  ChunkLength: 6.08	  EvalIndex: 2.130 Change:0.6%
#
# 1300	  MemLength: 8202 8.1	  ChunkLength: 6.14	  EvalIndex: 2.116 Change:0.7%
#
# 1400	  MemLength: 8358 8.1	  ChunkLength: 6.17	  EvalIndex: 2.111 Change:0.2%
#
# 1500	  MemLength: 8582 8.2	  ChunkLength: 6.22	  EvalIndex: 2.102 Change:0.4%
#
# 1600	  MemLength: 8741 8.2	  ChunkLength: 6.27	  EvalIndex: 2.087 Change:0.7%
#
# 1700	  MemLength: 8986 8.3	  ChunkLength: 6.31	  EvalIndex: 2.082 Change:0.2%
#
# 1800	  MemLength: 9079 8.4	  ChunkLength: 6.33	  EvalIndex: 2.078 Change:0.2%
#
# 1900	  MemLength: 9265 8.4	  ChunkLength: 6.36	  EvalIndex: 2.071 Change:0.3%
#
# 2000	  MemLength: 9415 8.5	  ChunkLength: 6.39	  EvalIndex: 2.065 Change:0.3%
#
# 2100	  MemLength: 9562 8.5	  ChunkLength: 6.42	  EvalIndex: 2.058 Change:0.3%
#
# 2200	  MemLength: 9696 8.6	  ChunkLength: 6.45	  EvalIndex: 2.054 Change:0.2%
#
# 2300	  MemLength: 9819 8.6	  ChunkLength: 6.47	  EvalIndex: 2.049 Change:0.3%
#
# 2400	  MemLength: 9919 8.6	  ChunkLength: 6.52	  EvalIndex: 2.037 Change:0.6%
#
# 2500	  MemLength: 10095 8.6	  ChunkLength: 6.54	  EvalIndex: 2.034 Change:0.1%
#
# 2600	  MemLength: 10318 8.7	  ChunkLength: 6.59	  EvalIndex: 2.024 Change:0.5%
#
# 2700	  MemLength: 10411 8.7	  ChunkLength: 6.61	  EvalIndex: 2.020 Change:0.2%
#
# 2800	  MemLength: 10472 8.7	  ChunkLength: 6.63	  EvalIndex: 2.013 Change:0.4%
#
# 2900	  MemLength: 10671 8.8	  ChunkLength: 6.66	  EvalIndex: 2.009 Change:0.2%
#
# 3000	  MemLength: 10808 8.8	  ChunkLength: 6.69	  EvalIndex: 2.003 Change:0.3%
#
# 3100	  MemLength: 10987 8.8	  ChunkLength: 6.71	  EvalIndex: 1.999 Change:0.2%
#
# 3200	  MemLength: 11085 8.9	  ChunkLength: 6.74	  EvalIndex: 1.994 Change:0.3%
#
# 3300	  MemLength: 11190 8.9	  ChunkLength: 6.77	  EvalIndex: 1.987 Change:0.4%
#
# 3400	  MemLength: 11227 8.9	  ChunkLength: 6.77	  EvalIndex: 1.987 Change:0.0%
#
# 3500	  MemLength: 11269 8.9	  ChunkLength: 6.78	  EvalIndex: 1.985 Change:0.1%
#
# 3600	  MemLength: 11315 8.9	  ChunkLength: 6.81	  EvalIndex: 1.978 Change:0.3%
#
# 3700	  MemLength: 11418 9.0	  ChunkLength: 6.82	  EvalIndex: 1.976 Change:0.1%
#
# 3800	  MemLength: 11598 9.0	  ChunkLength: 6.86	  EvalIndex: 1.969 Change:0.4%
#
# 3900	  MemLength: 11721 9.0	  ChunkLength: 6.88	  EvalIndex: 1.965 Change:0.2%
#
# 4000	  MemLength: 11828 9.0	  ChunkLength: 6.90	  EvalIndex: 1.960 Change:0.3%
#
# 4100	  MemLength: 11978 9.1	  ChunkLength: 6.92	  EvalIndex: 1.959 Change:0.1%
#
# 4200	  MemLength: 12116 9.1	  ChunkLength: 6.94	  EvalIndex: 1.953 Change:0.3%
#
# 4300	  MemLength: 12254 9.1	  ChunkLength: 6.97	  EvalIndex: 1.949 Change:0.2%
#
# 4400	  MemLength: 12367 9.1	  ChunkLength: 6.99	  EvalIndex: 1.945 Change:0.2%
#
# 4500	  MemLength: 12388 9.1	  ChunkLength: 7.00	  EvalIndex: 1.942 Change:0.1%
#
# 4600	  MemLength: 12402 9.2	  ChunkLength: 7.02	  EvalIndex: 1.937 Change:0.3%
#
# 4700	  MemLength: 12568 9.2	  ChunkLength: 7.04	  EvalIndex: 1.935 Change:0.1%
#
# 4800	  MemLength: 12595 9.2	  ChunkLength: 7.05	  EvalIndex: 1.932 Change:0.1%
#
# 4900	  MemLength: 12698 9.2	  ChunkLength: 7.06	  EvalIndex: 1.931 Change:0.0%
#
# 5000	  MemLength: 12732 9.2	  ChunkLength: 7.07	  EvalIndex: 1.929 Change:0.1%
#
# 5100	  MemLength: 12776 9.2	  ChunkLength: 7.09	  EvalIndex: 1.925 Change:0.2%
#
# 5200	  MemLength: 12820 9.2	  ChunkLength: 7.10	  EvalIndex: 1.922 Change:0.2%
#
# 5300	  MemLength: 13009 9.2	  ChunkLength: 7.13	  EvalIndex: 1.916 Change:0.3%
#
# 5400	  MemLength: 13089 9.3	  ChunkLength: 7.13	  EvalIndex: 1.918 Change:-0.1%
#
# [Length] Word 5.353 Pred 7.125 Real 7.820	Model_SE 0.005 CI 0.013
# [F1] Model 53.84 Word 38.32
# 18
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3587 6.1	  ChunkLength: 4.62	  EvalIndex: 2.557 Change:39.3%
#
# 200	  MemLength: 4453 6.7	  ChunkLength: 5.00	  EvalIndex: 2.423 Change:5.3%
#
# 300	  MemLength: 5074 7.0	  ChunkLength: 5.25	  EvalIndex: 2.344 Change:3.3%
#
# 400	  MemLength: 5753 7.3	  ChunkLength: 5.45	  EvalIndex: 2.291 Change:2.2%
#
# 500	  MemLength: 6269 7.6	  ChunkLength: 5.61	  EvalIndex: 2.250 Change:1.8%
#
# 600	  MemLength: 6520 7.6	  ChunkLength: 5.71	  EvalIndex: 2.220 Change:1.3%
#
# 700	  MemLength: 6870 7.8	  ChunkLength: 5.79	  EvalIndex: 2.201 Change:0.9%
#
# 800	  MemLength: 7366 7.9	  ChunkLength: 5.92	  EvalIndex: 2.171 Change:1.4%
#
# 900	  MemLength: 7552 8.0	  ChunkLength: 5.96	  EvalIndex: 2.161 Change:0.5%
#
# 1000	  MemLength: 7768 8.1	  ChunkLength: 6.02	  EvalIndex: 2.146 Change:0.7%
#
# 1100	  MemLength: 7971 8.1	  ChunkLength: 6.07	  EvalIndex: 2.133 Change:0.6%
#
# 1200	  MemLength: 8335 8.2	  ChunkLength: 6.15	  EvalIndex: 2.119 Change:0.7%
#
# 1300	  MemLength: 8491 8.3	  ChunkLength: 6.19	  EvalIndex: 2.108 Change:0.5%
#
# 1400	  MemLength: 8612 8.4	  ChunkLength: 6.21	  EvalIndex: 2.104 Change:0.2%
#
# 1500	  MemLength: 8740 8.4	  ChunkLength: 6.25	  EvalIndex: 2.094 Change:0.4%
#
# 1600	  MemLength: 8869 8.5	  ChunkLength: 6.27	  EvalIndex: 2.091 Change:0.1%
#
# 1700	  MemLength: 9159 8.5	  ChunkLength: 6.33	  EvalIndex: 2.080 Change:0.5%
#
# 1800	  MemLength: 9302 8.6	  ChunkLength: 6.35	  EvalIndex: 2.075 Change:0.3%
#
# 1900	  MemLength: 9413 8.6	  ChunkLength: 6.39	  EvalIndex: 2.067 Change:0.4%
#
# 2000	  MemLength: 9587 8.7	  ChunkLength: 6.42	  EvalIndex: 2.059 Change:0.4%
#
# 2100	  MemLength: 9721 8.7	  ChunkLength: 6.46	  EvalIndex: 2.050 Change:0.5%
#
# 2200	  MemLength: 9927 8.7	  ChunkLength: 6.50	  EvalIndex: 2.043 Change:0.3%
#
# 2300	  MemLength: 10145 8.8	  ChunkLength: 6.55	  EvalIndex: 2.033 Change:0.5%
#
# 2400	  MemLength: 10420 8.9	  ChunkLength: 6.58	  EvalIndex: 2.028 Change:0.2%
#
# 2500	  MemLength: 10441 8.8	  ChunkLength: 6.61	  EvalIndex: 2.019 Change:0.4%
#
# 2600	  MemLength: 10584 8.9	  ChunkLength: 6.63	  EvalIndex: 2.016 Change:0.1%
#
# 2700	  MemLength: 10627 8.9	  ChunkLength: 6.64	  EvalIndex: 2.014 Change:0.1%
#
# 2800	  MemLength: 10854 9.0	  ChunkLength: 6.68	  EvalIndex: 2.008 Change:0.3%
#
# 2900	  MemLength: 10825 9.0	  ChunkLength: 6.69	  EvalIndex: 2.004 Change:0.2%
#
# 3000	  MemLength: 11015 9.0	  ChunkLength: 6.72	  EvalIndex: 2.000 Change:0.2%
#
# 3100	  MemLength: 11122 9.0	  ChunkLength: 6.74	  EvalIndex: 1.994 Change:0.3%
#
# 3200	  MemLength: 11338 9.1	  ChunkLength: 6.79	  EvalIndex: 1.984 Change:0.5%
#
# 3300	  MemLength: 11435 9.1	  ChunkLength: 6.80	  EvalIndex: 1.983 Change:0.1%
#
# 3400	  MemLength: 11569 9.1	  ChunkLength: 6.83	  EvalIndex: 1.978 Change:0.3%
#
# 3500	  MemLength: 11748 9.2	  ChunkLength: 6.85	  EvalIndex: 1.973 Change:0.2%
#
# 3600	  MemLength: 11821 9.2	  ChunkLength: 6.87	  EvalIndex: 1.968 Change:0.2%
#
# 3700	  MemLength: 12060 9.3	  ChunkLength: 6.92	  EvalIndex: 1.960 Change:0.4%
#
# 3800	  MemLength: 12183 9.3	  ChunkLength: 6.94	  EvalIndex: 1.955 Change:0.3%
#
# 3900	  MemLength: 12179 9.3	  ChunkLength: 6.95	  EvalIndex: 1.952 Change:0.1%
#
# 4000	  MemLength: 12276 9.3	  ChunkLength: 6.97	  EvalIndex: 1.950 Change:0.1%
#
# 4100	  MemLength: 12274 9.3	  ChunkLength: 6.97	  EvalIndex: 1.949 Change:0.0%
#
# 4200	  MemLength: 12495 9.3	  ChunkLength: 7.01	  EvalIndex: 1.942 Change:0.4%
#
# 4300	  MemLength: 12595 9.3	  ChunkLength: 7.04	  EvalIndex: 1.935 Change:0.4%
#
# 4400	  MemLength: 12638 9.4	  ChunkLength: 7.05	  EvalIndex: 1.933 Change:0.1%
#
# 4500	  MemLength: 12617 9.4	  ChunkLength: 7.05	  EvalIndex: 1.932 Change:0.1%
#
# 4600	  MemLength: 12737 9.4	  ChunkLength: 7.06	  EvalIndex: 1.932 Change:0.0%
#
# 4700	  MemLength: 12760 9.4	  ChunkLength: 7.06	  EvalIndex: 1.931 Change:0.1%
#
# 4800	  MemLength: 12827 9.4	  ChunkLength: 7.08	  EvalIndex: 1.928 Change:0.2%
#
# 4900	  MemLength: 13051 9.4	  ChunkLength: 7.12	  EvalIndex: 1.920 Change:0.4%
#
# 5000	  MemLength: 13073 9.5	  ChunkLength: 7.12	  EvalIndex: 1.919 Change:0.1%
#
# 5100	  MemLength: 13125 9.5	  ChunkLength: 7.13	  EvalIndex: 1.919 Change:-0.0%
#
# [Length] Word 5.353 Pred 7.125 Real 7.820	Model_SE 0.005 CI 0.013
# [F1] Model 53.64 Word 38.32
# 19
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3847 6.4	  ChunkLength: 4.66	  EvalIndex: 2.554 Change:39.4%
#
# 200	  MemLength: 4780 6.9	  ChunkLength: 5.07	  EvalIndex: 2.411 Change:5.6%
#
# 300	  MemLength: 5349 7.1	  ChunkLength: 5.30	  EvalIndex: 2.339 Change:3.0%
#
# 400	  MemLength: 5691 7.3	  ChunkLength: 5.45	  EvalIndex: 2.288 Change:2.2%
#
# 500	  MemLength: 6129 7.5	  ChunkLength: 5.58	  EvalIndex: 2.253 Change:1.5%
#
# 600	  MemLength: 6557 7.7	  ChunkLength: 5.69	  EvalIndex: 2.228 Change:1.1%
#
# 700	  MemLength: 6910 7.8	  ChunkLength: 5.80	  EvalIndex: 2.199 Change:1.3%
#
# 800	  MemLength: 7227 7.9	  ChunkLength: 5.88	  EvalIndex: 2.180 Change:0.8%
#
# 900	  MemLength: 7526 8.0	  ChunkLength: 5.96	  EvalIndex: 2.160 Change:0.9%
#
# 1000	  MemLength: 7734 8.1	  ChunkLength: 6.01	  EvalIndex: 2.151 Change:0.4%
#
# 1100	  MemLength: 7945 8.2	  ChunkLength: 6.06	  EvalIndex: 2.139 Change:0.5%
#
# 1200	  MemLength: 8125 8.2	  ChunkLength: 6.10	  EvalIndex: 2.130 Change:0.5%
#
# 1300	  MemLength: 8285 8.2	  ChunkLength: 6.15	  EvalIndex: 2.115 Change:0.7%
#
# 1400	  MemLength: 8499 8.3	  ChunkLength: 6.20	  EvalIndex: 2.105 Change:0.5%
#
# 1500	  MemLength: 8681 8.4	  ChunkLength: 6.25	  EvalIndex: 2.094 Change:0.5%
#
# 1600	  MemLength: 8830 8.4	  ChunkLength: 6.28	  EvalIndex: 2.087 Change:0.3%
#
# 1700	  MemLength: 8934 8.5	  ChunkLength: 6.31	  EvalIndex: 2.082 Change:0.3%
#
# 1800	  MemLength: 9025 8.5	  ChunkLength: 6.34	  EvalIndex: 2.072 Change:0.5%
#
# 1900	  MemLength: 9142 8.5	  ChunkLength: 6.36	  EvalIndex: 2.070 Change:0.1%
#
# 2000	  MemLength: 9502 8.7	  ChunkLength: 6.43	  EvalIndex: 2.057 Change:0.6%
#
# 2100	  MemLength: 9660 8.7	  ChunkLength: 6.46	  EvalIndex: 2.050 Change:0.3%
#
# 2200	  MemLength: 9911 8.8	  ChunkLength: 6.49	  EvalIndex: 2.044 Change:0.3%
#
# 2300	  MemLength: 10120 8.8	  ChunkLength: 6.53	  EvalIndex: 2.037 Change:0.4%
#
# 2400	  MemLength: 10323 8.9	  ChunkLength: 6.58	  EvalIndex: 2.028 Change:0.5%
#
# 2500	  MemLength: 10394 8.9	  ChunkLength: 6.58	  EvalIndex: 2.027 Change:0.0%
#
# 2600	  MemLength: 10574 9.0	  ChunkLength: 6.62	  EvalIndex: 2.018 Change:0.4%
#
# 2700	  MemLength: 10711 9.0	  ChunkLength: 6.65	  EvalIndex: 2.013 Change:0.3%
#
# 2800	  MemLength: 10844 9.0	  ChunkLength: 6.67	  EvalIndex: 2.008 Change:0.2%
#
# 2900	  MemLength: 10880 9.0	  ChunkLength: 6.69	  EvalIndex: 2.005 Change:0.2%
#
# 3000	  MemLength: 10977 9.1	  ChunkLength: 6.73	  EvalIndex: 1.996 Change:0.4%
#
# 3100	  MemLength: 11120 9.1	  ChunkLength: 6.74	  EvalIndex: 1.994 Change:0.1%
#
# 3200	  MemLength: 11249 9.2	  ChunkLength: 6.76	  EvalIndex: 1.992 Change:0.1%
#
# 3300	  MemLength: 11369 9.2	  ChunkLength: 6.80	  EvalIndex: 1.982 Change:0.5%
#
# 3400	  MemLength: 11638 9.2	  ChunkLength: 6.84	  EvalIndex: 1.975 Change:0.4%
#
# 3500	  MemLength: 11740 9.2	  ChunkLength: 6.86	  EvalIndex: 1.971 Change:0.2%
#
# 3600	  MemLength: 11876 9.3	  ChunkLength: 6.90	  EvalIndex: 1.963 Change:0.4%
#
# 3700	  MemLength: 11927 9.3	  ChunkLength: 6.90	  EvalIndex: 1.962 Change:0.1%
#
# 3800	  MemLength: 12001 9.3	  ChunkLength: 6.92	  EvalIndex: 1.958 Change:0.2%
#
# 3900	  MemLength: 12179 9.3	  ChunkLength: 6.94	  EvalIndex: 1.955 Change:0.1%
#
# 4000	  MemLength: 12182 9.3	  ChunkLength: 6.95	  EvalIndex: 1.953 Change:0.1%
#
# 4100	  MemLength: 12338 9.4	  ChunkLength: 6.97	  EvalIndex: 1.949 Change:0.2%
#
# 4200	  MemLength: 12389 9.4	  ChunkLength: 6.99	  EvalIndex: 1.945 Change:0.2%
#
# 4300	  MemLength: 12540 9.4	  ChunkLength: 7.03	  EvalIndex: 1.937 Change:0.4%
#
# 4400	  MemLength: 12655 9.4	  ChunkLength: 7.04	  EvalIndex: 1.935 Change:0.1%
#
# 4500	  MemLength: 12792 9.5	  ChunkLength: 7.08	  EvalIndex: 1.927 Change:0.5%
#
# 4600	  MemLength: 12835 9.5	  ChunkLength: 7.08	  EvalIndex: 1.928 Change:-0.1%
#
# [Length] Word 5.353 Pred 7.076 Real 7.820	Model_SE 0.005 CI 0.013
# [F1] Model 53.38 Word 38.32
# 20
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3739 6.3	  ChunkLength: 4.66	  EvalIndex: 2.546 Change:39.6%
#
# 200	  MemLength: 4693 6.8	  ChunkLength: 5.04	  EvalIndex: 2.421 Change:4.9%
#
# 300	  MemLength: 5108 7.0	  ChunkLength: 5.24	  EvalIndex: 2.349 Change:3.0%
#
# 400	  MemLength: 5559 7.2	  ChunkLength: 5.42	  EvalIndex: 2.297 Change:2.2%
#
# 500	  MemLength: 5853 7.3	  ChunkLength: 5.53	  EvalIndex: 2.263 Change:1.5%
#
# 600	  MemLength: 6355 7.5	  ChunkLength: 5.66	  EvalIndex: 2.233 Change:1.3%
#
# 700	  MemLength: 6624 7.7	  ChunkLength: 5.74	  EvalIndex: 2.210 Change:1.0%
#
# 800	  MemLength: 6963 7.8	  ChunkLength: 5.82	  EvalIndex: 2.192 Change:0.8%
#
# 900	  MemLength: 7205 8.0	  ChunkLength: 5.89	  EvalIndex: 2.176 Change:0.7%
#
# 1000	  MemLength: 7526 8.0	  ChunkLength: 5.97	  EvalIndex: 2.157 Change:0.9%
#
# 1100	  MemLength: 7871 8.2	  ChunkLength: 6.05	  EvalIndex: 2.138 Change:0.9%
#
# 1200	  MemLength: 8144 8.3	  ChunkLength: 6.10	  EvalIndex: 2.128 Change:0.5%
#
# 1300	  MemLength: 8347 8.3	  ChunkLength: 6.15	  EvalIndex: 2.120 Change:0.4%
#
# 1400	  MemLength: 8706 8.5	  ChunkLength: 6.21	  EvalIndex: 2.108 Change:0.6%
#
# 1500	  MemLength: 8876 8.5	  ChunkLength: 6.26	  EvalIndex: 2.096 Change:0.5%
#
# 1600	  MemLength: 8971 8.6	  ChunkLength: 6.29	  EvalIndex: 2.089 Change:0.4%
#
# 1700	  MemLength: 9333 8.7	  ChunkLength: 6.36	  EvalIndex: 2.075 Change:0.6%
#
# 1800	  MemLength: 9682 8.8	  ChunkLength: 6.43	  EvalIndex: 2.061 Change:0.7%
#
# 1900	  MemLength: 9747 8.8	  ChunkLength: 6.44	  EvalIndex: 2.057 Change:0.2%
#
# 2000	  MemLength: 9888 8.9	  ChunkLength: 6.46	  EvalIndex: 2.055 Change:0.1%
#
# 2100	  MemLength: 10163 8.9	  ChunkLength: 6.53	  EvalIndex: 2.038 Change:0.8%
#
# 2200	  MemLength: 10378 9.0	  ChunkLength: 6.57	  EvalIndex: 2.031 Change:0.3%
#
# 2300	  MemLength: 10556 9.1	  ChunkLength: 6.59	  EvalIndex: 2.028 Change:0.2%
#
# 2400	  MemLength: 10748 9.1	  ChunkLength: 6.63	  EvalIndex: 2.018 Change:0.5%
#
# 2500	  MemLength: 10943 9.2	  ChunkLength: 6.69	  EvalIndex: 2.007 Change:0.6%
#
# 2600	  MemLength: 11150 9.2	  ChunkLength: 6.72	  EvalIndex: 2.000 Change:0.3%
#
# 2700	  MemLength: 11224 9.2	  ChunkLength: 6.73	  EvalIndex: 1.998 Change:0.1%
#
# 2800	  MemLength: 11314 9.3	  ChunkLength: 6.76	  EvalIndex: 1.991 Change:0.4%
#
# 2900	  MemLength: 11404 9.3	  ChunkLength: 6.77	  EvalIndex: 1.991 Change:-0.0%
#
# [Length] Word 5.353 Pred 6.757 Real 7.820	Model_SE 0.005 CI 0.013
# [F1] Model 52.99 Word 38.32
# 21
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3846 6.4	  ChunkLength: 4.67	  EvalIndex: 2.549 Change:39.5%
#
# 200	  MemLength: 4647 6.8	  ChunkLength: 5.08	  EvalIndex: 2.398 Change:5.9%
#
# 300	  MemLength: 5128 7.1	  ChunkLength: 5.28	  EvalIndex: 2.334 Change:2.7%
#
# 400	  MemLength: 5871 7.5	  ChunkLength: 5.50	  EvalIndex: 2.276 Change:2.5%
#
# 500	  MemLength: 6372 7.6	  ChunkLength: 5.67	  EvalIndex: 2.230 Change:2.0%
#
# 600	  MemLength: 6840 7.9	  ChunkLength: 5.76	  EvalIndex: 2.211 Change:0.8%
#
# 700	  MemLength: 7135 8.0	  ChunkLength: 5.85	  EvalIndex: 2.188 Change:1.1%
#
# 800	  MemLength: 7429 8.1	  ChunkLength: 5.94	  EvalIndex: 2.166 Change:1.0%
#
# 900	  MemLength: 7616 8.2	  ChunkLength: 6.00	  EvalIndex: 2.151 Change:0.7%
#
# 1000	  MemLength: 7828 8.3	  ChunkLength: 6.04	  EvalIndex: 2.142 Change:0.4%
#
# 1100	  MemLength: 8194 8.3	  ChunkLength: 6.13	  EvalIndex: 2.121 Change:1.0%
#
# 1200	  MemLength: 8500 8.5	  ChunkLength: 6.19	  EvalIndex: 2.110 Change:0.5%
#
# 1300	  MemLength: 8631 8.5	  ChunkLength: 6.23	  EvalIndex: 2.098 Change:0.5%
#
# 1400	  MemLength: 8815 8.6	  ChunkLength: 6.26	  EvalIndex: 2.092 Change:0.3%
#
# 1500	  MemLength: 8867 8.6	  ChunkLength: 6.29	  EvalIndex: 2.087 Change:0.3%
#
# 1600	  MemLength: 9341 8.8	  ChunkLength: 6.37	  EvalIndex: 2.070 Change:0.8%
#
# 1700	  MemLength: 9543 8.9	  ChunkLength: 6.41	  EvalIndex: 2.061 Change:0.4%
#
# 1800	  MemLength: 9756 8.9	  ChunkLength: 6.47	  EvalIndex: 2.049 Change:0.6%
#
# 1900	  MemLength: 9883 8.9	  ChunkLength: 6.49	  EvalIndex: 2.045 Change:0.2%
#
# 2000	  MemLength: 10175 9.0	  ChunkLength: 6.55	  EvalIndex: 2.031 Change:0.7%
#
# 2100	  MemLength: 10436 9.1	  ChunkLength: 6.59	  EvalIndex: 2.025 Change:0.3%
#
# 2200	  MemLength: 10570 9.1	  ChunkLength: 6.63	  EvalIndex: 2.017 Change:0.4%
#
# 2300	  MemLength: 10763 9.1	  ChunkLength: 6.66	  EvalIndex: 2.010 Change:0.3%
#
# 2400	  MemLength: 11004 9.2	  ChunkLength: 6.70	  EvalIndex: 2.005 Change:0.3%
#
# 2500	  MemLength: 11163 9.3	  ChunkLength: 6.74	  EvalIndex: 1.996 Change:0.4%
#
# 2600	  MemLength: 11249 9.4	  ChunkLength: 6.75	  EvalIndex: 1.995 Change:0.1%
#
# 2700	  MemLength: 11394 9.3	  ChunkLength: 6.78	  EvalIndex: 1.988 Change:0.4%
#
# 2800	  MemLength: 11462 9.4	  ChunkLength: 6.81	  EvalIndex: 1.981 Change:0.3%
#
# 2900	  MemLength: 11526 9.4	  ChunkLength: 6.81	  EvalIndex: 1.981 Change:0.0%
#
# 3000	  MemLength: 11716 9.5	  ChunkLength: 6.84	  EvalIndex: 1.976 Change:0.3%
#
# 3100	  MemLength: 11921 9.5	  ChunkLength: 6.88	  EvalIndex: 1.967 Change:0.4%
#
# 3200	  MemLength: 12076 9.5	  ChunkLength: 6.90	  EvalIndex: 1.964 Change:0.2%
#
# 3300	  MemLength: 12244 9.6	  ChunkLength: 6.95	  EvalIndex: 1.955 Change:0.4%
#
# 3400	  MemLength: 12317 9.6	  ChunkLength: 6.97	  EvalIndex: 1.948 Change:0.4%
#
# 3500	  MemLength: 12592 9.7	  ChunkLength: 7.01	  EvalIndex: 1.942 Change:0.3%
#
# 3600	  MemLength: 12796 9.7	  ChunkLength: 7.06	  EvalIndex: 1.931 Change:0.5%
#
# 3700	  MemLength: 12827 9.8	  ChunkLength: 7.05	  EvalIndex: 1.935 Change:-0.2%
#
# [Length] Word 5.353 Pred 7.045 Real 7.820	Model_SE 0.005 CI 0.014
# [F1] Model 53.24 Word 38.32
# 22
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3629 6.2	  ChunkLength: 4.65	  EvalIndex: 2.541 Change:39.7%
#
# 200	  MemLength: 4511 6.7	  ChunkLength: 5.05	  EvalIndex: 2.406 Change:5.3%
#
# 300	  MemLength: 5229 7.1	  ChunkLength: 5.31	  EvalIndex: 2.326 Change:3.3%
#
# 400	  MemLength: 5629 7.3	  ChunkLength: 5.45	  EvalIndex: 2.284 Change:1.8%
#
# 500	  MemLength: 6087 7.6	  ChunkLength: 5.58	  EvalIndex: 2.251 Change:1.5%
#
# 600	  MemLength: 6518 7.7	  ChunkLength: 5.70	  EvalIndex: 2.222 Change:1.3%
#
# 700	  MemLength: 6905 7.9	  ChunkLength: 5.80	  EvalIndex: 2.199 Change:1.0%
#
# 800	  MemLength: 7174 8.0	  ChunkLength: 5.87	  EvalIndex: 2.184 Change:0.7%
#
# 900	  MemLength: 7438 8.1	  ChunkLength: 5.94	  EvalIndex: 2.164 Change:0.9%
#
# 1000	  MemLength: 7667 8.2	  ChunkLength: 6.00	  EvalIndex: 2.151 Change:0.6%
#
# 1100	  MemLength: 7859 8.3	  ChunkLength: 6.06	  EvalIndex: 2.137 Change:0.7%
#
# 1200	  MemLength: 8026 8.4	  ChunkLength: 6.11	  EvalIndex: 2.125 Change:0.6%
#
# 1300	  MemLength: 8134 8.3	  ChunkLength: 6.12	  EvalIndex: 2.123 Change:0.1%
#
# 1400	  MemLength: 8320 8.4	  ChunkLength: 6.17	  EvalIndex: 2.110 Change:0.6%
#
# 1500	  MemLength: 8640 8.5	  ChunkLength: 6.24	  EvalIndex: 2.097 Change:0.6%
#
# 1600	  MemLength: 9018 8.6	  ChunkLength: 6.31	  EvalIndex: 2.083 Change:0.6%
#
# 1700	  MemLength: 9220 8.7	  ChunkLength: 6.34	  EvalIndex: 2.077 Change:0.3%
#
# 1800	  MemLength: 9399 8.8	  ChunkLength: 6.39	  EvalIndex: 2.066 Change:0.5%
#
# 1900	  MemLength: 9580 8.9	  ChunkLength: 6.42	  EvalIndex: 2.061 Change:0.3%
#
# 2000	  MemLength: 9831 8.9	  ChunkLength: 6.47	  EvalIndex: 2.050 Change:0.5%
#
# 2100	  MemLength: 10011 9.0	  ChunkLength: 6.50	  EvalIndex: 2.046 Change:0.2%
#
# 2200	  MemLength: 10136 9.0	  ChunkLength: 6.52	  EvalIndex: 2.040 Change:0.3%
#
# 2300	  MemLength: 10147 9.0	  ChunkLength: 6.53	  EvalIndex: 2.039 Change:0.0%
#
# 2400	  MemLength: 10308 9.1	  ChunkLength: 6.56	  EvalIndex: 2.032 Change:0.4%
#
# 2500	  MemLength: 10474 9.1	  ChunkLength: 6.60	  EvalIndex: 2.024 Change:0.4%
#
# 2600	  MemLength: 10653 9.1	  ChunkLength: 6.65	  EvalIndex: 2.013 Change:0.5%
#
# 2700	  MemLength: 10816 9.2	  ChunkLength: 6.68	  EvalIndex: 2.006 Change:0.4%
#
# 2800	  MemLength: 10969 9.2	  ChunkLength: 6.72	  EvalIndex: 1.999 Change:0.4%
#
# 2900	  MemLength: 11267 9.3	  ChunkLength: 6.76	  EvalIndex: 1.990 Change:0.4%
#
# 3000	  MemLength: 11397 9.4	  ChunkLength: 6.78	  EvalIndex: 1.988 Change:0.1%
#
# 3100	  MemLength: 11633 9.4	  ChunkLength: 6.82	  EvalIndex: 1.979 Change:0.5%
#
# 3200	  MemLength: 11851 9.5	  ChunkLength: 6.88	  EvalIndex: 1.967 Change:0.6%
#
# 3300	  MemLength: 11967 9.5	  ChunkLength: 6.90	  EvalIndex: 1.964 Change:0.2%
#
# 3400	  MemLength: 12063 9.6	  ChunkLength: 6.91	  EvalIndex: 1.962 Change:0.1%
#
# 3500	  MemLength: 12213 9.6	  ChunkLength: 6.94	  EvalIndex: 1.955 Change:0.4%
#
# 3600	  MemLength: 12311 9.6	  ChunkLength: 6.97	  EvalIndex: 1.948 Change:0.4%
#
# 3700	  MemLength: 12432 9.6	  ChunkLength: 6.99	  EvalIndex: 1.946 Change:0.1%
#
# 3800	  MemLength: 12590 9.6	  ChunkLength: 7.02	  EvalIndex: 1.941 Change:0.3%
#
# 3900	  MemLength: 12636 9.7	  ChunkLength: 7.03	  EvalIndex: 1.939 Change:0.1%
#
# 4000	  MemLength: 12755 9.7	  ChunkLength: 7.06	  EvalIndex: 1.932 Change:0.4%
#
# 4100	  MemLength: 12896 9.8	  ChunkLength: 7.07	  EvalIndex: 1.930 Change:0.1%
#
# 4200	  MemLength: 13177 9.8	  ChunkLength: 7.12	  EvalIndex: 1.922 Change:0.4%
#
# 4300	  MemLength: 13231 9.8	  ChunkLength: 7.14	  EvalIndex: 1.917 Change:0.3%
#
# 4400	  MemLength: 13377 9.9	  ChunkLength: 7.16	  EvalIndex: 1.916 Change:0.1%
#
# 4500	  MemLength: 13456 9.9	  ChunkLength: 7.18	  EvalIndex: 1.910 Change:0.3%
#
# 4600	  MemLength: 13590 9.9	  ChunkLength: 7.21	  EvalIndex: 1.905 Change:0.2%
#
# 4700	  MemLength: 13756 9.9	  ChunkLength: 7.25	  EvalIndex: 1.896 Change:0.5%
#
# 4800	  MemLength: 13783 9.9	  ChunkLength: 7.24	  EvalIndex: 1.898 Change:-0.1%
#
# [Length] Word 5.353 Pred 7.238 Real 7.820	Model_SE 0.006 CI 0.014
# [F1] Model 53.39 Word 38.32
# 23
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3552 6.1	  ChunkLength: 4.64	  EvalIndex: 2.542 Change:39.7%
#
# 200	  MemLength: 4507 6.8	  ChunkLength: 5.07	  EvalIndex: 2.396 Change:5.7%
#
# 300	  MemLength: 4893 7.0	  ChunkLength: 5.27	  EvalIndex: 2.325 Change:3.0%
#
# 400	  MemLength: 5364 7.2	  ChunkLength: 5.44	  EvalIndex: 2.276 Change:2.1%
#
# 500	  MemLength: 5687 7.5	  ChunkLength: 5.55	  EvalIndex: 2.246 Change:1.3%
#
# 600	  MemLength: 6072 7.5	  ChunkLength: 5.67	  EvalIndex: 2.218 Change:1.3%
#
# 700	  MemLength: 6536 7.9	  ChunkLength: 5.77	  EvalIndex: 2.198 Change:0.9%
#
# 800	  MemLength: 6847 8.0	  ChunkLength: 5.86	  EvalIndex: 2.173 Change:1.1%
#
# 900	  MemLength: 7148 8.1	  ChunkLength: 5.94	  EvalIndex: 2.156 Change:0.8%
#
# 1000	  MemLength: 7630 8.3	  ChunkLength: 6.03	  EvalIndex: 2.139 Change:0.8%
#
# 1100	  MemLength: 7920 8.5	  ChunkLength: 6.10	  EvalIndex: 2.125 Change:0.7%
#
# 1200	  MemLength: 8111 8.5	  ChunkLength: 6.14	  EvalIndex: 2.115 Change:0.5%
#
# 1300	  MemLength: 8524 8.7	  ChunkLength: 6.22	  EvalIndex: 2.098 Change:0.8%
#
# 1400	  MemLength: 8818 8.8	  ChunkLength: 6.29	  EvalIndex: 2.084 Change:0.7%
#
# 1500	  MemLength: 8975 8.9	  ChunkLength: 6.31	  EvalIndex: 2.081 Change:0.1%
#
# 1600	  MemLength: 9311 8.9	  ChunkLength: 6.39	  EvalIndex: 2.064 Change:0.8%
#
# 1700	  MemLength: 9444 9.0	  ChunkLength: 6.41	  EvalIndex: 2.059 Change:0.3%
#
# 1800	  MemLength: 9648 9.0	  ChunkLength: 6.47	  EvalIndex: 2.047 Change:0.6%
#
# 1900	  MemLength: 9748 9.0	  ChunkLength: 6.49	  EvalIndex: 2.042 Change:0.2%
#
# 2000	  MemLength: 10011 9.1	  ChunkLength: 6.56	  EvalIndex: 2.027 Change:0.7%
#
# 2100	  MemLength: 10208 9.2	  ChunkLength: 6.59	  EvalIndex: 2.021 Change:0.3%
#
# 2200	  MemLength: 10340 9.2	  ChunkLength: 6.62	  EvalIndex: 2.015 Change:0.3%
#
# 2300	  MemLength: 10500 9.3	  ChunkLength: 6.65	  EvalIndex: 2.010 Change:0.3%
#
# 2400	  MemLength: 10686 9.3	  ChunkLength: 6.68	  EvalIndex: 2.002 Change:0.4%
#
# 2500	  MemLength: 10957 9.4	  ChunkLength: 6.73	  EvalIndex: 1.994 Change:0.4%
#
# 2600	  MemLength: 11010 9.4	  ChunkLength: 6.76	  EvalIndex: 1.986 Change:0.4%
#
# 2700	  MemLength: 11090 9.4	  ChunkLength: 6.78	  EvalIndex: 1.983 Change:0.2%
#
# 2800	  MemLength: 11189 9.5	  ChunkLength: 6.79	  EvalIndex: 1.980 Change:0.1%
#
# 2900	  MemLength: 11380 9.5	  ChunkLength: 6.82	  EvalIndex: 1.974 Change:0.3%
#
# 3000	  MemLength: 11483 9.5	  ChunkLength: 6.84	  EvalIndex: 1.970 Change:0.2%
#
# 3100	  MemLength: 11674 9.6	  ChunkLength: 6.88	  EvalIndex: 1.963 Change:0.4%
#
# 3200	  MemLength: 11786 9.6	  ChunkLength: 6.90	  EvalIndex: 1.959 Change:0.2%
#
# 3300	  MemLength: 11817 9.6	  ChunkLength: 6.93	  EvalIndex: 1.953 Change:0.3%
#
# 3400	  MemLength: 11939 9.7	  ChunkLength: 6.94	  EvalIndex: 1.952 Change:0.1%
#
# 3500	  MemLength: 12043 9.7	  ChunkLength: 6.96	  EvalIndex: 1.947 Change:0.3%
#
# 3600	  MemLength: 12153 9.8	  ChunkLength: 6.98	  EvalIndex: 1.944 Change:0.1%
#
# 3700	  MemLength: 12387 9.8	  ChunkLength: 7.03	  EvalIndex: 1.934 Change:0.5%
#
# 3800	  MemLength: 12444 9.8	  ChunkLength: 7.03	  EvalIndex: 1.934 Change:-0.0%
#
# [Length] Word 5.353 Pred 7.026 Real 7.820	Model_SE 0.005 CI 0.014
# [F1] Model 53.15 Word 38.32
# 24
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3684 6.3	  ChunkLength: 4.66	  EvalIndex: 2.540 Change:39.7%
#
# 200	  MemLength: 4541 6.8	  ChunkLength: 5.06	  EvalIndex: 2.403 Change:5.4%
#
# 300	  MemLength: 5060 7.1	  ChunkLength: 5.29	  EvalIndex: 2.328 Change:3.1%
#
# 400	  MemLength: 5482 7.2	  ChunkLength: 5.44	  EvalIndex: 2.281 Change:2.0%
#
# 500	  MemLength: 5777 7.4	  ChunkLength: 5.55	  EvalIndex: 2.250 Change:1.4%
#
# 600	  MemLength: 6357 7.7	  ChunkLength: 5.69	  EvalIndex: 2.219 Change:1.4%
#
# 700	  MemLength: 6788 7.9	  ChunkLength: 5.80	  EvalIndex: 2.196 Change:1.1%
#
# 800	  MemLength: 7220 8.1	  ChunkLength: 5.90	  EvalIndex: 2.171 Change:1.1%
#
# 900	  MemLength: 7419 8.2	  ChunkLength: 5.97	  EvalIndex: 2.154 Change:0.8%
#
# 1000	  MemLength: 7754 8.3	  ChunkLength: 6.03	  EvalIndex: 2.141 Change:0.6%
#
# 1100	  MemLength: 7938 8.3	  ChunkLength: 6.09	  EvalIndex: 2.129 Change:0.6%
#
# 1200	  MemLength: 8216 8.5	  ChunkLength: 6.15	  EvalIndex: 2.113 Change:0.7%
#
# 1300	  MemLength: 8248 8.5	  ChunkLength: 6.19	  EvalIndex: 2.103 Change:0.5%
#
# 1400	  MemLength: 8597 8.6	  ChunkLength: 6.26	  EvalIndex: 2.088 Change:0.7%
#
# 1500	  MemLength: 8892 8.7	  ChunkLength: 6.31	  EvalIndex: 2.078 Change:0.5%
#
# 1600	  MemLength: 9015 8.8	  ChunkLength: 6.34	  EvalIndex: 2.072 Change:0.3%
#
# 1700	  MemLength: 9338 8.8	  ChunkLength: 6.39	  EvalIndex: 2.063 Change:0.4%
#
# 1800	  MemLength: 9383 8.9	  ChunkLength: 6.41	  EvalIndex: 2.058 Change:0.2%
#
# 1900	  MemLength: 9793 9.0	  ChunkLength: 6.49	  EvalIndex: 2.044 Change:0.7%
#
# 2000	  MemLength: 9902 9.0	  ChunkLength: 6.52	  EvalIndex: 2.037 Change:0.3%
#
# 2100	  MemLength: 10209 9.1	  ChunkLength: 6.57	  EvalIndex: 2.027 Change:0.5%
#
# 2200	  MemLength: 10398 9.2	  ChunkLength: 6.61	  EvalIndex: 2.019 Change:0.4%
#
# 2300	  MemLength: 10482 9.3	  ChunkLength: 6.64	  EvalIndex: 2.011 Change:0.4%
#
# 2400	  MemLength: 10593 9.2	  ChunkLength: 6.66	  EvalIndex: 2.007 Change:0.2%
#
# 2500	  MemLength: 10853 9.4	  ChunkLength: 6.70	  EvalIndex: 2.000 Change:0.3%
#
# 2600	  MemLength: 11040 9.4	  ChunkLength: 6.74	  EvalIndex: 1.992 Change:0.4%
#
# 2700	  MemLength: 11178 9.5	  ChunkLength: 6.77	  EvalIndex: 1.988 Change:0.2%
#
# 2800	  MemLength: 11312 9.5	  ChunkLength: 6.79	  EvalIndex: 1.982 Change:0.3%
#
# 2900	  MemLength: 11654 9.6	  ChunkLength: 6.86	  EvalIndex: 1.970 Change:0.6%
#
# 3000	  MemLength: 11822 9.7	  ChunkLength: 6.89	  EvalIndex: 1.963 Change:0.4%
#
# 3100	  MemLength: 11940 9.7	  ChunkLength: 6.92	  EvalIndex: 1.958 Change:0.3%
#
# 3200	  MemLength: 12054 9.8	  ChunkLength: 6.95	  EvalIndex: 1.952 Change:0.3%
#
# 3300	  MemLength: 12297 9.9	  ChunkLength: 6.98	  EvalIndex: 1.947 Change:0.3%
#
# 3400	  MemLength: 12339 9.8	  ChunkLength: 6.99	  EvalIndex: 1.943 Change:0.2%
#
# 3500	  MemLength: 12424 9.9	  ChunkLength: 7.02	  EvalIndex: 1.937 Change:0.3%
#
# 3600	  MemLength: 12518 9.9	  ChunkLength: 7.03	  EvalIndex: 1.938 Change:-0.0%
#
# [Length] Word 5.353 Pred 7.021 Real 7.820	Model_SE 0.005 CI 0.014
# [F1] Model 53.05 Word 38.32
# 25
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3658 6.3	  ChunkLength: 4.66	  EvalIndex: 2.538 Change:39.8%
#
# 200	  MemLength: 4595 6.8	  ChunkLength: 5.06	  EvalIndex: 2.406 Change:5.2%
#
# ...
#
# 2700	  MemLength: 11305 9.5	  ChunkLength: 6.79	  EvalIndex: 1.982 Change:0.6%
#
# 2800	  MemLength: 11600 9.5	  ChunkLength: 6.84	  EvalIndex: 1.974 Change:0.4%
#
# 2900	  MemLength: 11847 9.6	  ChunkLength: 6.87	  EvalIndex: 1.968 Change:0.3%
#
# 3000	  MemLength: 11964 9.6	  ChunkLength: 6.91	  EvalIndex: 1.961 Change:0.4%
#
# 3100	  MemLength: 11958 9.6	  ChunkLength: 6.91	  EvalIndex: 1.961 Change:-0.0%
#
# [Length] Word 5.353 Pred 6.902 Real 7.820	Model_SE 0.005 CI 0.014
# [F1] Model 53.18 Word 38.32
# 26
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3658 6.3	  ChunkLength: 4.66	  EvalIndex: 2.538 Change:39.8%
#
# 200	  MemLength: 4681 7.0	  ChunkLength: 5.09	  EvalIndex: 2.397 Change:5.5%
#
# 300	  MemLength: 5298 7.3	  ChunkLength: 5.31	  EvalIndex: 2.328 Change:2.9%
#
# 400	  MemLength: 5919 7.7	  ChunkLength: 5.50	  EvalIndex: 2.280 Change:2.1%
#
# 500	  MemLength: 6399 7.8	  ChunkLength: 5.63	  EvalIndex: 2.244 Change:1.6%
#
# 600	  MemLength: 6753 8.0	  ChunkLength: 5.74	  EvalIndex: 2.214 Change:1.3%
#
# 700	  MemLength: 7034 8.2	  ChunkLength: 5.83	  EvalIndex: 2.194 Change:0.9%
#
# 800	  MemLength: 7549 8.4	  ChunkLength: 5.94	  EvalIndex: 2.170 Change:1.1%
#
# 900	  MemLength: 7792 8.5	  ChunkLength: 5.99	  EvalIndex: 2.158 Change:0.5%
#
# 1000	  MemLength: 8059 8.6	  ChunkLength: 6.07	  EvalIndex: 2.139 Change:0.9%
#
# 1100	  MemLength: 8376 8.7	  ChunkLength: 6.13	  EvalIndex: 2.126 Change:0.6%
#
# 1200	  MemLength: 8453 8.8	  ChunkLength: 6.16	  EvalIndex: 2.118 Change:0.4%
#
# 1300	  MemLength: 8783 8.9	  ChunkLength: 6.24	  EvalIndex: 2.101 Change:0.8%
#
# 1400	  MemLength: 9015 8.9	  ChunkLength: 6.28	  EvalIndex: 2.092 Change:0.4%
#
# 1500	  MemLength: 9272 9.1	  ChunkLength: 6.34	  EvalIndex: 2.079 Change:0.6%
#
# 1600	  MemLength: 9533 9.1	  ChunkLength: 6.39	  EvalIndex: 2.070 Change:0.4%
#
# 1700	  MemLength: 9552 9.2	  ChunkLength: 6.40	  EvalIndex: 2.067 Change:0.2%
#
# 1800	  MemLength: 9684 9.2	  ChunkLength: 6.43	  EvalIndex: 2.059 Change:0.3%
#
# 1900	  MemLength: 9775 9.2	  ChunkLength: 6.46	  EvalIndex: 2.053 Change:0.3%
#
# 2000	  MemLength: 10188 9.3	  ChunkLength: 6.53	  EvalIndex: 2.038 Change:0.7%
#
# 2100	  MemLength: 10331 9.4	  ChunkLength: 6.56	  EvalIndex: 2.033 Change:0.2%
#
# 2200	  MemLength: 10440 9.4	  ChunkLength: 6.59	  EvalIndex: 2.026 Change:0.3%
#
# 2300	  MemLength: 10585 9.4	  ChunkLength: 6.62	  EvalIndex: 2.019 Change:0.4%
#
# 2400	  MemLength: 10638 9.5	  ChunkLength: 6.65	  EvalIndex: 2.011 Change:0.4%
#
# 2500	  MemLength: 10761 9.5	  ChunkLength: 6.67	  EvalIndex: 2.009 Change:0.1%
#
# 2600	  MemLength: 11018 9.6	  ChunkLength: 6.71	  EvalIndex: 2.001 Change:0.4%
#
# 2700	  MemLength: 11144 9.6	  ChunkLength: 6.75	  EvalIndex: 1.992 Change:0.4%
#
# 2800	  MemLength: 11430 9.7	  ChunkLength: 6.78	  EvalIndex: 1.987 Change:0.2%
#
# 2900	  MemLength: 11514 9.7	  ChunkLength: 6.81	  EvalIndex: 1.981 Change:0.3%
#
# 3000	  MemLength: 11762 9.8	  ChunkLength: 6.85	  EvalIndex: 1.974 Change:0.4%
#
# 3100	  MemLength: 11844 9.8	  ChunkLength: 6.87	  EvalIndex: 1.969 Change:0.3%
#
# 3200	  MemLength: 11993 9.9	  ChunkLength: 6.90	  EvalIndex: 1.965 Change:0.2%
#
# 3300	  MemLength: 12171 9.9	  ChunkLength: 6.93	  EvalIndex: 1.958 Change:0.4%
#
# 3400	  MemLength: 12447 10.0	  ChunkLength: 6.98	  EvalIndex: 1.948 Change:0.5%
#
# 3500	  MemLength: 12621 10.0	  ChunkLength: 7.04	  EvalIndex: 1.935 Change:0.7%
#
# 3600	  MemLength: 12740 10.1	  ChunkLength: 7.05	  EvalIndex: 1.935 Change:-0.0%
#
# [Length] Word 5.353 Pred 7.035 Real 7.820	Model_SE 0.006 CI 0.014
# [F1] Model 53.03 Word 38.32
# 27
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3677 6.3	  ChunkLength: 4.67	  EvalIndex: 2.535 Change:39.8%
#
# 200	  MemLength: 4479 6.8	  ChunkLength: 5.05	  EvalIndex: 2.401 Change:5.3%
#
# 300	  MemLength: 5222 7.3	  ChunkLength: 5.29	  EvalIndex: 2.335 Change:2.8%
#
# 400	  MemLength: 5683 7.4	  ChunkLength: 5.47	  EvalIndex: 2.282 Change:2.3%
#
# 500	  MemLength: 6148 7.8	  ChunkLength: 5.61	  EvalIndex: 2.244 Change:1.6%
#
# 600	  MemLength: 6635 8.0	  ChunkLength: 5.73	  EvalIndex: 2.214 Change:1.4%
#
# 700	  MemLength: 6920 8.1	  ChunkLength: 5.83	  EvalIndex: 2.188 Change:1.2%
#
# 800	  MemLength: 7124 8.1	  ChunkLength: 5.89	  EvalIndex: 2.171 Change:0.8%
#
# 900	  MemLength: 7520 8.5	  ChunkLength: 5.96	  EvalIndex: 2.162 Change:0.4%
#
# 1000	  MemLength: 7939 8.6	  ChunkLength: 6.06	  EvalIndex: 2.137 Change:1.1%
#
# 1100	  MemLength: 8149 8.6	  ChunkLength: 6.11	  EvalIndex: 2.126 Change:0.5%
#
# 1200	  MemLength: 8560 8.8	  ChunkLength: 6.20	  EvalIndex: 2.108 Change:0.8%
#
# 1300	  MemLength: 8827 8.9	  ChunkLength: 6.25	  EvalIndex: 2.098 Change:0.5%
#
# 1400	  MemLength: 9151 9.0	  ChunkLength: 6.31	  EvalIndex: 2.085 Change:0.6%
#
# 1500	  MemLength: 9309 9.1	  ChunkLength: 6.35	  EvalIndex: 2.077 Change:0.4%
#
# 1600	  MemLength: 9400 9.1	  ChunkLength: 6.38	  EvalIndex: 2.070 Change:0.3%
#
# 1700	  MemLength: 9602 9.2	  ChunkLength: 6.42	  EvalIndex: 2.061 Change:0.4%
#
# 1800	  MemLength: 9755 9.2	  ChunkLength: 6.46	  EvalIndex: 2.053 Change:0.4%
#
# 1900	  MemLength: 9928 9.3	  ChunkLength: 6.48	  EvalIndex: 2.050 Change:0.1%
#
# 2000	  MemLength: 10079 9.3	  ChunkLength: 6.52	  EvalIndex: 2.039 Change:0.5%
#
# 2100	  MemLength: 10335 9.4	  ChunkLength: 6.57	  EvalIndex: 2.029 Change:0.5%
#
# 2200	  MemLength: 10476 9.4	  ChunkLength: 6.60	  EvalIndex: 2.024 Change:0.2%
#
# 2300	  MemLength: 10799 9.5	  ChunkLength: 6.67	  EvalIndex: 2.009 Change:0.8%
#
# 2400	  MemLength: 10921 9.6	  ChunkLength: 6.70	  EvalIndex: 2.004 Change:0.3%
#
# 2500	  MemLength: 11033 9.6	  ChunkLength: 6.72	  EvalIndex: 1.999 Change:0.2%
#
# 2600	  MemLength: 11239 9.6	  ChunkLength: 6.75	  EvalIndex: 1.993 Change:0.3%
#
# 2700	  MemLength: 11424 9.7	  ChunkLength: 6.80	  EvalIndex: 1.982 Change:0.6%
#
# 2800	  MemLength: 11421 9.7	  ChunkLength: 6.81	  EvalIndex: 1.978 Change:0.2%
#
# 2900	  MemLength: 11708 9.8	  ChunkLength: 6.86	  EvalIndex: 1.971 Change:0.4%
#
# 3000	  MemLength: 11793 9.8	  ChunkLength: 6.89	  EvalIndex: 1.964 Change:0.3%
#
# 3100	  MemLength: 11926 9.9	  ChunkLength: 6.91	  EvalIndex: 1.960 Change:0.2%
#
# 3200	  MemLength: 12087 9.9	  ChunkLength: 6.92	  EvalIndex: 1.960 Change:0.0%
#
# 3300	  MemLength: 12083 9.9	  ChunkLength: 6.93	  EvalIndex: 1.956 Change:0.2%
#
# 3400	  MemLength: 12162 9.9	  ChunkLength: 6.96	  EvalIndex: 1.950 Change:0.3%
#
# 3500	  MemLength: 12322 10.0	  ChunkLength: 6.98	  EvalIndex: 1.948 Change:0.1%
#
# 3600	  MemLength: 12459 10.0	  ChunkLength: 7.00	  EvalIndex: 1.944 Change:0.2%
#
# 3700	  MemLength: 12512 10.0	  ChunkLength: 7.03	  EvalIndex: 1.935 Change:0.5%
#
# 3800	  MemLength: 12695 10.1	  ChunkLength: 7.04	  EvalIndex: 1.937 Change:-0.1%
#
# [Length] Word 5.353 Pred 7.033 Real 7.820	Model_SE 0.006 CI 0.014
# [F1] Model 52.96 Word 38.32
# 28
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3677 6.3	  ChunkLength: 4.67	  EvalIndex: 2.535 Change:39.8%
#
# 200	  MemLength: 4436 6.8	  ChunkLength: 5.03	  EvalIndex: 2.406 Change:5.1%
#
# 300	  MemLength: 5102 7.2	  ChunkLength: 5.27	  EvalIndex: 2.338 Change:2.8%
#
# 400	  MemLength: 5731 7.6	  ChunkLength: 5.45	  EvalIndex: 2.291 Change:2.0%
#
# 500	  MemLength: 6254 7.8	  ChunkLength: 5.63	  EvalIndex: 2.240 Change:2.2%
#
# 600	  MemLength: 6644 8.0	  ChunkLength: 5.74	  EvalIndex: 2.213 Change:1.2%
#
# 700	  MemLength: 6990 8.1	  ChunkLength: 5.83	  EvalIndex: 2.189 Change:1.1%
#
# 800	  MemLength: 7206 8.2	  ChunkLength: 5.90	  EvalIndex: 2.172 Change:0.8%
#
# 900	  MemLength: 7558 8.4	  ChunkLength: 5.99	  EvalIndex: 2.152 Change:0.9%
#
# 1000	  MemLength: 8096 8.6	  ChunkLength: 6.09	  EvalIndex: 2.130 Change:1.0%
#
# 1100	  MemLength: 8416 8.6	  ChunkLength: 6.16	  EvalIndex: 2.115 Change:0.7%
#
# 1200	  MemLength: 8775 8.8	  ChunkLength: 6.23	  EvalIndex: 2.102 Change:0.6%
#
# 1300	  MemLength: 9150 9.0	  ChunkLength: 6.31	  EvalIndex: 2.086 Change:0.7%
#
# 1400	  MemLength: 9432 9.0	  ChunkLength: 6.37	  EvalIndex: 2.074 Change:0.6%
#
# 1500	  MemLength: 9743 9.1	  ChunkLength: 6.43	  EvalIndex: 2.062 Change:0.6%
#
# 1600	  MemLength: 9960 9.2	  ChunkLength: 6.46	  EvalIndex: 2.055 Change:0.3%
#
# 1700	  MemLength: 10185 9.4	  ChunkLength: 6.50	  EvalIndex: 2.048 Change:0.4%
#
# 1800	  MemLength: 10391 9.4	  ChunkLength: 6.56	  EvalIndex: 2.035 Change:0.6%
#
# 1900	  MemLength: 10553 9.4	  ChunkLength: 6.59	  EvalIndex: 2.029 Change:0.3%
#
# 2000	  MemLength: 10964 9.5	  ChunkLength: 6.66	  EvalIndex: 2.015 Change:0.7%
#
# 2100	  MemLength: 11055 9.6	  ChunkLength: 6.70	  EvalIndex: 2.006 Change:0.4%
#
# 2200	  MemLength: 11143 9.7	  ChunkLength: 6.70	  EvalIndex: 2.006 Change:0.0%
#
# 2300	  MemLength: 11313 9.7	  ChunkLength: 6.74	  EvalIndex: 1.999 Change:0.3%
#
# 2400	  MemLength: 11316 9.7	  ChunkLength: 6.75	  EvalIndex: 1.996 Change:0.2%
#
# 2500	  MemLength: 11456 9.8	  ChunkLength: 6.77	  EvalIndex: 1.992 Change:0.2%
#
# 2600	  MemLength: 11568 9.8	  ChunkLength: 6.79	  EvalIndex: 1.987 Change:0.3%
#
# 2700	  MemLength: 11673 9.8	  ChunkLength: 6.81	  EvalIndex: 1.984 Change:0.2%
#
# 2800	  MemLength: 11966 9.9	  ChunkLength: 6.87	  EvalIndex: 1.972 Change:0.6%
#
# 2900	  MemLength: 11985 9.9	  ChunkLength: 6.88	  EvalIndex: 1.970 Change:0.1%
#
# 3000	  MemLength: 12088 9.9	  ChunkLength: 6.91	  EvalIndex: 1.962 Change:0.4%
#
# 3100	  MemLength: 12267 10.0	  ChunkLength: 6.93	  EvalIndex: 1.960 Change:0.1%
#
# 3200	  MemLength: 12427 10.0	  ChunkLength: 6.97	  EvalIndex: 1.951 Change:0.5%
#
# 3300	  MemLength: 12601 10.1	  ChunkLength: 7.00	  EvalIndex: 1.947 Change:0.2%
#
# 3400	  MemLength: 12634 10.1	  ChunkLength: 7.01	  EvalIndex: 1.943 Change:0.2%
#
# 3500	  MemLength: 12714 10.1	  ChunkLength: 7.02	  EvalIndex: 1.942 Change:0.0%
#
# 3600	  MemLength: 12768 10.1	  ChunkLength: 7.04	  EvalIndex: 1.936 Change:0.3%
#
# 3700	  MemLength: 12909 10.2	  ChunkLength: 7.06	  EvalIndex: 1.935 Change:0.1%
#
# 3800	  MemLength: 12988 10.2	  ChunkLength: 7.08	  EvalIndex: 1.929 Change:0.3%
#
# 3900	  MemLength: 13119 10.2	  ChunkLength: 7.11	  EvalIndex: 1.925 Change:0.2%
#
# 4000	  MemLength: 13272 10.3	  ChunkLength: 7.14	  EvalIndex: 1.917 Change:0.4%
#
# 4100	  MemLength: 13442 10.3	  ChunkLength: 7.18	  EvalIndex: 1.909 Change:0.4%
#
# 4200	  MemLength: 13457 10.3	  ChunkLength: 7.19	  EvalIndex: 1.907 Change:0.1%
#
# 4300	  MemLength: 13545 10.3	  ChunkLength: 7.20	  EvalIndex: 1.907 Change:-0.0%
#
# [Length] Word 5.353 Pred 7.186 Real 7.820	Model_SE 0.006 CI 0.015
# [F1] Model 53.10 Word 38.32
# 29
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3677 6.3	  ChunkLength: 4.67	  EvalIndex: 2.535 Change:39.8%
#
# 200	  MemLength: 4436 6.8	  ChunkLength: 5.03	  EvalIndex: 2.406 Change:5.1%
#
# 300	  MemLength: 5036 7.1	  ChunkLength: 5.25	  EvalIndex: 2.342 Change:2.7%
#
# 400	  MemLength: 5621 7.5	  ChunkLength: 5.43	  EvalIndex: 2.294 Change:2.1%
#
# 500	  MemLength: 6067 7.7	  ChunkLength: 5.56	  EvalIndex: 2.262 Change:1.4%
#
# 600	  MemLength: 6653 8.0	  ChunkLength: 5.70	  EvalIndex: 2.229 Change:1.4%
#
# 700	  MemLength: 6837 8.1	  ChunkLength: 5.78	  EvalIndex: 2.204 Change:1.1%
#
# 800	  MemLength: 7025 8.1	  ChunkLength: 5.83	  EvalIndex: 2.191 Change:0.6%
#
# 900	  MemLength: 7455 8.3	  ChunkLength: 5.95	  EvalIndex: 2.164 Change:1.2%
#
# 1000	  MemLength: 7638 8.3	  ChunkLength: 6.00	  EvalIndex: 2.151 Change:0.6%
#
# 1100	  MemLength: 7792 8.4	  ChunkLength: 6.04	  EvalIndex: 2.140 Change:0.5%
#
# 1200	  MemLength: 8100 8.5	  ChunkLength: 6.10	  EvalIndex: 2.129 Change:0.5%
#
# 1300	  MemLength: 8244 8.6	  ChunkLength: 6.14	  EvalIndex: 2.120 Change:0.4%
#
# 1400	  MemLength: 8362 8.7	  ChunkLength: 6.18	  EvalIndex: 2.108 Change:0.6%
#
# 1500	  MemLength: 8571 8.8	  ChunkLength: 6.20	  EvalIndex: 2.106 Change:0.1%
#
# 1600	  MemLength: 8705 8.8	  ChunkLength: 6.25	  EvalIndex: 2.093 Change:0.6%
#
# 1700	  MemLength: 9009 8.9	  ChunkLength: 6.33	  EvalIndex: 2.076 Change:0.8%
#
# 1800	  MemLength: 9261 9.0	  ChunkLength: 6.37	  EvalIndex: 2.068 Change:0.4%
#
# 1900	  MemLength: 9309 9.0	  ChunkLength: 6.38	  EvalIndex: 2.067 Change:0.0%
#
# 2000	  MemLength: 9609 9.1	  ChunkLength: 6.44	  EvalIndex: 2.053 Change:0.7%
#
# 2100	  MemLength: 9792 9.2	  ChunkLength: 6.48	  EvalIndex: 2.045 Change:0.4%
#
# 2200	  MemLength: 9872 9.3	  ChunkLength: 6.49	  EvalIndex: 2.045 Change:0.0%
#
# 2300	  MemLength: 9923 9.3	  ChunkLength: 6.51	  EvalIndex: 2.040 Change:0.2%
#
# 2400	  MemLength: 10323 9.4	  ChunkLength: 6.59	  EvalIndex: 2.022 Change:0.9%
#
# 2500	  MemLength: 10527 9.4	  ChunkLength: 6.62	  EvalIndex: 2.018 Change:0.2%
#
# 2600	  MemLength: 10734 9.5	  ChunkLength: 6.67	  EvalIndex: 2.007 Change:0.5%
#
# 2700	  MemLength: 10912 9.6	  ChunkLength: 6.70	  EvalIndex: 2.002 Change:0.3%
#
# 2800	  MemLength: 11061 9.6	  ChunkLength: 6.75	  EvalIndex: 1.991 Change:0.5%
#
# 2900	  MemLength: 11238 9.7	  ChunkLength: 6.77	  EvalIndex: 1.988 Change:0.1%
#
# 3000	  MemLength: 11357 9.7	  ChunkLength: 6.79	  EvalIndex: 1.985 Change:0.2%
#
# 3100	  MemLength: 11463 9.7	  ChunkLength: 6.82	  EvalIndex: 1.977 Change:0.4%
#
# 3200	  MemLength: 11625 9.8	  ChunkLength: 6.84	  EvalIndex: 1.976 Change:0.0%
#
# 3300	  MemLength: 11747 9.9	  ChunkLength: 6.87	  EvalIndex: 1.969 Change:0.3%
#
# 3400	  MemLength: 12019 10.0	  ChunkLength: 6.93	  EvalIndex: 1.956 Change:0.6%
#
# 3500	  MemLength: 12128 10.0	  ChunkLength: 6.94	  EvalIndex: 1.956 Change:0.0%
#
# 3600	  MemLength: 12238 10.0	  ChunkLength: 6.97	  EvalIndex: 1.948 Change:0.4%
#
# 3700	  MemLength: 12513 10.1	  ChunkLength: 7.02	  EvalIndex: 1.939 Change:0.5%
#
# 3800	  MemLength: 12651 10.1	  ChunkLength: 7.05	  EvalIndex: 1.934 Change:0.3%
#
# 3900	  MemLength: 12834 10.2	  ChunkLength: 7.08	  EvalIndex: 1.928 Change:0.3%
#
# 4000	  MemLength: 12926 10.2	  ChunkLength: 7.11	  EvalIndex: 1.922 Change:0.3%
#
# 4100	  MemLength: 13035 10.3	  ChunkLength: 7.11	  EvalIndex: 1.923 Change:-0.1%
#
# [Length] Word 5.353 Pred 7.099 Real 7.820	Model_SE 0.006 CI 0.015
# [F1] Model 52.99 Word 38.32
# 30
# 0	  MemLength: 540 3.4	  ChunkLength: 2.15	  EvalIndex: 4.213
#
# 100	  MemLength: 3677 6.3	  ChunkLength: 4.67	  EvalIndex: 2.535 Change:39.8%
#
# 200	  MemLength: 4412 6.8	  ChunkLength: 5.02	  EvalIndex: 2.411 Change:4.9%
#
# 300	  MemLength: 5049 7.1	  ChunkLength: 5.27	  EvalIndex: 2.333 Change:3.2%
#
# 400	  MemLength: 5684 7.4	  ChunkLength: 5.46	  EvalIndex: 2.283 Change:2.1%
#
# 500	  MemLength: 5830 7.5	  ChunkLength: 5.57	  EvalIndex: 2.246 Change:1.6%
#
# 600	  MemLength: 6347 7.7	  ChunkLength: 5.71	  EvalIndex: 2.211 Change:1.6%
#
# 700	  MemLength: 6826 8.0	  ChunkLength: 5.80	  EvalIndex: 2.196 Change:0.7%
#
# 800	  MemLength: 7430 8.2	  ChunkLength: 5.92	  EvalIndex: 2.173 Change:1.0%
#
# 900	  MemLength: 7733 8.4	  ChunkLength: 6.00	  EvalIndex: 2.154 Change:0.9%
#
# 1000	  MemLength: 7964 8.5	  ChunkLength: 6.07	  EvalIndex: 2.137 Change:0.8%
#
# 1100	  MemLength: 8130 8.5	  ChunkLength: 6.11	  EvalIndex: 2.124 Change:0.6%
#
# 1200	  MemLength: 8231 8.6	  ChunkLength: 6.14	  EvalIndex: 2.118 Change:0.3%
#
# 1300	  MemLength: 8472 8.6	  ChunkLength: 6.22	  EvalIndex: 2.099 Change:0.9%
#
# 1400	  MemLength: 8791 8.8	  ChunkLength: 6.27	  EvalIndex: 2.089 Change:0.5%
#
# 1500	  MemLength: 9032 8.9	  ChunkLength: 6.32	  EvalIndex: 2.080 Change:0.4%
#
# 1600	  MemLength: 9136 8.9	  ChunkLength: 6.35	  EvalIndex: 2.073 Change:0.3%
#
# 1700	  MemLength: 9495 9.0	  ChunkLength: 6.43	  EvalIndex: 2.056 Change:0.8%
#
# 1800	  MemLength: 9497 9.0	  ChunkLength: 6.43	  EvalIndex: 2.056 Change:0.0%
#
# 1900	  MemLength: 9804 9.1	  ChunkLength: 6.48	  EvalIndex: 2.045 Change:0.5%
#
# 2000	  MemLength: 9881 9.1	  ChunkLength: 6.50	  EvalIndex: 2.041 Change:0.2%
#
# 2100	  MemLength: 10095 9.2	  ChunkLength: 6.55	  EvalIndex: 2.031 Change:0.5%
#
# 2200	  MemLength: 10134 9.2	  ChunkLength: 6.57	  EvalIndex: 2.026 Change:0.3%
#
# 2300	  MemLength: 10311 9.3	  ChunkLength: 6.61	  EvalIndex: 2.018 Change:0.4%
#
# 2400	  MemLength: 10455 9.3	  ChunkLength: 6.64	  EvalIndex: 2.011 Change:0.4%
#
# 2500	  MemLength: 10670 9.4	  ChunkLength: 6.67	  EvalIndex: 2.005 Change:0.3%
#
# 2600	  MemLength: 10812 9.4	  ChunkLength: 6.72	  EvalIndex: 1.995 Change:0.5%
#
# 2700	  MemLength: 10929 9.5	  ChunkLength: 6.72	  EvalIndex: 1.996 Change:-0.0%
#
# [Length] Word 5.353 Pred 6.720 Real 7.820	Model_SE 0.005 CI 0.013
# [F1] Model 52.81 Word 38.32

# %%
importlib.reload(LiB)
model = LiB.model

'Define the train/test set'
corpus_train = sents_with_line_ends_without_repeat_nl
corpus_test = sents_with_line_ends_without_repeat_nl

'New and init a memory'
for i in range(5,31):
    print()
    print(i)
    m_geco_nl_t = model(corpus_train, corpus_test, lexicon_in=0.25, lexicon_out=0.0001, update_rate=0.2, life=3)
    m_geco_nl_t.logs['note'] = 0
    m_geco_nl_t.max_len = i

    'RUN!!!'
    for epoch_id in range(0,10001):
        m_geco_nl_t.run(epoch_id, article_length=200, test_interval=100);
        if epoch_id>0 and epoch_id % 100==0:
            if m_geco_nl_t.logs['eval_index'][-1] > m_geco_nl_t.logs['eval_index'][-2]:
                break
    f1 = m_geco_nl_t.predict_eye_fixations(geco_res['L1'], show_length=True);
# Out:
# 5
# 0	  MemLength: 606 3.8	  ChunkLength: 2.30	  EvalIndex: 4.012
#
# 100	  MemLength: 2356 4.6	  ChunkLength: 3.65	  EvalIndex: 3.068 Change:23.5%
#
# 200	  MemLength: 2614 4.5	  ChunkLength: 3.72	  EvalIndex: 3.052 Change:0.5%
#
# 300	  MemLength: 2925 4.7	  ChunkLength: 3.78	  EvalIndex: 3.048 Change:0.2%
#
# 400	  MemLength: 2974 4.7	  ChunkLength: 3.79	  EvalIndex: 3.041 Change:0.2%
#
# 500	  MemLength: 2930 4.5	  ChunkLength: 3.80	  EvalIndex: 3.030 Change:0.3%
#
# 600	  MemLength: 3061 4.6	  ChunkLength: 3.82	  EvalIndex: 3.034 Change:-0.1%
#
# [Length] Word 5.596 Pred 3.818 Real 8.194	Model_SE 0.001 CI 0.004
# [F1] Model 31.27 Word 38.68
# 6
# 0	  MemLength: 608 3.8	  ChunkLength: 2.38	  EvalIndex: 3.888
#
# 100	  MemLength: 2817 5.0	  ChunkLength: 3.93	  EvalIndex: 2.918 Change:24.9%
#
# 200	  MemLength: 3028 4.9	  ChunkLength: 4.02	  EvalIndex: 2.874 Change:1.5%
#
# 300	  MemLength: 3290 5.1	  ChunkLength: 4.08	  EvalIndex: 2.865 Change:0.3%
#
# 400	  MemLength: 3431 5.1	  ChunkLength: 4.11	  EvalIndex: 2.855 Change:0.4%
#
# 500	  MemLength: 3498 5.1	  ChunkLength: 4.13	  EvalIndex: 2.848 Change:0.2%
#
# 600	  MemLength: 3667 5.1	  ChunkLength: 4.15	  EvalIndex: 2.853 Change:-0.2%
#
# [Length] Word 5.596 Pred 4.149 Real 8.194	Model_SE 0.002 CI 0.004
# [F1] Model 35.74 Word 38.68
# 7
# 0	  MemLength: 611 3.8	  ChunkLength: 2.34	  EvalIndex: 3.955
#
# 100	  MemLength: 3177 5.4	  ChunkLength: 4.30	  EvalIndex: 2.707 Change:31.6%
#
# 200	  MemLength: 3495 5.5	  ChunkLength: 4.43	  EvalIndex: 2.658 Change:1.8%
#
# 300	  MemLength: 3728 5.5	  ChunkLength: 4.51	  EvalIndex: 2.633 Change:0.9%
#
# 400	  MemLength: 4005 5.6	  ChunkLength: 4.57	  EvalIndex: 2.618 Change:0.6%
#
# 500	  MemLength: 3995 5.5	  ChunkLength: 4.60	  EvalIndex: 2.599 Change:0.7%
#
# 600	  MemLength: 4133 5.5	  ChunkLength: 4.61	  EvalIndex: 2.604 Change:-0.2%
#
# [Length] Word 5.596 Pred 4.612 Real 8.194	Model_SE 0.002 CI 0.005
# [F1] Model 41.75 Word 38.68
# 8
# 0	  MemLength: 606 3.8	  ChunkLength: 2.35	  EvalIndex: 3.927
#
# 100	  MemLength: 3283 5.6	  ChunkLength: 4.50	  EvalIndex: 2.597 Change:33.9%
#
# 200	  MemLength: 3832 5.8	  ChunkLength: 4.71	  EvalIndex: 2.527 Change:2.7%
#
# 300	  MemLength: 4189 5.9	  ChunkLength: 4.82	  EvalIndex: 2.495 Change:1.3%
#
# 400	  MemLength: 4433 5.9	  ChunkLength: 4.90	  EvalIndex: 2.472 Change:0.9%
#
# 500	  MemLength: 4800 6.0	  ChunkLength: 4.98	  EvalIndex: 2.458 Change:0.6%
#
# 600	  MemLength: 4928 6.0	  ChunkLength: 5.02	  EvalIndex: 2.446 Change:0.5%
#
# 700	  MemLength: 5079 6.0	  ChunkLength: 5.04	  EvalIndex: 2.442 Change:0.2%
#
# 800	  MemLength: 5150 6.0	  ChunkLength: 5.07	  EvalIndex: 2.430 Change:0.5%
#
# 900	  MemLength: 5190 6.0	  ChunkLength: 5.09	  EvalIndex: 2.425 Change:0.2%
#
# 1000	  MemLength: 5400 6.0	  ChunkLength: 5.12	  EvalIndex: 2.423 Change:0.1%
#
# 1100	  MemLength: 5490 6.1	  ChunkLength: 5.13	  EvalIndex: 2.420 Change:0.1%
#
# 1200	  MemLength: 5508 6.1	  ChunkLength: 5.14	  EvalIndex: 2.417 Change:0.2%
#
# 1300	  MemLength: 5632 6.1	  ChunkLength: 5.17	  EvalIndex: 2.410 Change:0.3%
#
# 1400	  MemLength: 5640 6.1	  ChunkLength: 5.18	  EvalIndex: 2.408 Change:0.1%
#
# 1500	  MemLength: 5707 6.1	  ChunkLength: 5.19	  EvalIndex: 2.404 Change:0.1%
#
# 1600	  MemLength: 5858 6.2	  ChunkLength: 5.20	  EvalIndex: 2.407 Change:-0.1%
#
# [Length] Word 5.596 Pred 5.199 Real 8.194	Model_SE 0.002 CI 0.006
# [F1] Model 46.74 Word 38.68
# 9
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.916
#
# 100	  MemLength: 3460 5.9	  ChunkLength: 4.60	  EvalIndex: 2.557 Change:34.7%
#
# 200	  MemLength: 4117 6.1	  ChunkLength: 4.89	  EvalIndex: 2.453 Change:4.1%
#
# 300	  MemLength: 4678 6.2	  ChunkLength: 5.07	  EvalIndex: 2.404 Change:2.0%
#
# 400	  MemLength: 5044 6.3	  ChunkLength: 5.15	  EvalIndex: 2.386 Change:0.8%
#
# 500	  MemLength: 5179 6.3	  ChunkLength: 5.21	  EvalIndex: 2.368 Change:0.8%
#
# 600	  MemLength: 5503 6.3	  ChunkLength: 5.28	  EvalIndex: 2.352 Change:0.7%
#
# 700	  MemLength: 5576 6.4	  ChunkLength: 5.31	  EvalIndex: 2.342 Change:0.4%
#
# 800	  MemLength: 5735 6.4	  ChunkLength: 5.34	  EvalIndex: 2.336 Change:0.2%
#
# 900	  MemLength: 5875 6.4	  ChunkLength: 5.38	  EvalIndex: 2.326 Change:0.4%
#
# 1000	  MemLength: 6007 6.4	  ChunkLength: 5.41	  EvalIndex: 2.321 Change:0.2%
#
# 1100	  MemLength: 6152 6.5	  ChunkLength: 5.44	  EvalIndex: 2.316 Change:0.2%
#
# 1200	  MemLength: 6266 6.5	  ChunkLength: 5.46	  EvalIndex: 2.312 Change:0.2%
#
# 1300	  MemLength: 6421 6.5	  ChunkLength: 5.49	  EvalIndex: 2.304 Change:0.3%
#
# 1400	  MemLength: 6574 6.6	  ChunkLength: 5.51	  EvalIndex: 2.300 Change:0.2%
#
# 1500	  MemLength: 6705 6.6	  ChunkLength: 5.53	  EvalIndex: 2.297 Change:0.1%
#
# 1600	  MemLength: 6792 6.6	  ChunkLength: 5.55	  EvalIndex: 2.294 Change:0.1%
#
# 1700	  MemLength: 6844 6.6	  ChunkLength: 5.56	  EvalIndex: 2.290 Change:0.2%
#
# 1800	  MemLength: 6847 6.5	  ChunkLength: 5.57	  EvalIndex: 2.288 Change:0.1%
#
# 1900	  MemLength: 6973 6.6	  ChunkLength: 5.58	  EvalIndex: 2.288 Change:-0.0%
#
# [Length] Word 5.596 Pred 5.576 Real 8.194	Model_SE 0.003 CI 0.007
# [F1] Model 49.10 Word 38.68
# 10
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.916
#
# 100	  MemLength: 3715 6.1	  ChunkLength: 4.73	  EvalIndex: 2.509 Change:35.9%
#
# 200	  MemLength: 4228 6.3	  ChunkLength: 4.99	  EvalIndex: 2.413 Change:3.8%
#
# 300	  MemLength: 4778 6.5	  ChunkLength: 5.16	  EvalIndex: 2.369 Change:1.9%
#
# 400	  MemLength: 5062 6.5	  ChunkLength: 5.28	  EvalIndex: 2.330 Change:1.6%
#
# 500	  MemLength: 5241 6.6	  ChunkLength: 5.35	  EvalIndex: 2.308 Change:0.9%
#
# 600	  MemLength: 5513 6.6	  ChunkLength: 5.42	  EvalIndex: 2.294 Change:0.6%
#
# 700	  MemLength: 5752 6.7	  ChunkLength: 5.47	  EvalIndex: 2.284 Change:0.4%
#
# 800	  MemLength: 5976 6.7	  ChunkLength: 5.53	  EvalIndex: 2.270 Change:0.6%
#
# 900	  MemLength: 6198 6.8	  ChunkLength: 5.58	  EvalIndex: 2.258 Change:0.5%
#
# 1000	  MemLength: 6392 6.9	  ChunkLength: 5.60	  EvalIndex: 2.256 Change:0.1%
#
# 1100	  MemLength: 6431 6.8	  ChunkLength: 5.64	  EvalIndex: 2.245 Change:0.5%
#
# 1200	  MemLength: 6643 6.9	  ChunkLength: 5.67	  EvalIndex: 2.241 Change:0.2%
#
# 1300	  MemLength: 6752 6.9	  ChunkLength: 5.70	  EvalIndex: 2.232 Change:0.4%
#
# 1400	  MemLength: 6928 6.9	  ChunkLength: 5.72	  EvalIndex: 2.232 Change:0.0%
#
# 1500	  MemLength: 7012 6.9	  ChunkLength: 5.74	  EvalIndex: 2.226 Change:0.3%
#
# 1600	  MemLength: 7038 6.9	  ChunkLength: 5.75	  EvalIndex: 2.224 Change:0.1%
#
# 1700	  MemLength: 7242 6.9	  ChunkLength: 5.78	  EvalIndex: 2.216 Change:0.4%
#
# 1800	  MemLength: 7330 7.0	  ChunkLength: 5.80	  EvalIndex: 2.213 Change:0.1%
#
# 1900	  MemLength: 7365 7.0	  ChunkLength: 5.83	  EvalIndex: 2.205 Change:0.4%
#
# 2000	  MemLength: 7502 7.0	  ChunkLength: 5.83	  EvalIndex: 2.209 Change:-0.2%
#
# [Length] Word 5.596 Pred 5.825 Real 8.194	Model_SE 0.003 CI 0.008
# [F1] Model 50.39 Word 38.68
# 11
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.909
#
# 100	  MemLength: 3704 6.3	  ChunkLength: 4.76	  EvalIndex: 2.492 Change:36.2%
#
# 200	  MemLength: 4342 6.4	  ChunkLength: 5.09	  EvalIndex: 2.373 Change:4.8%
#
# 300	  MemLength: 4963 6.7	  ChunkLength: 5.31	  EvalIndex: 2.312 Change:2.6%
#
# 400	  MemLength: 5330 6.8	  ChunkLength: 5.43	  EvalIndex: 2.281 Change:1.4%
#
# 500	  MemLength: 5640 6.8	  ChunkLength: 5.52	  EvalIndex: 2.257 Change:1.1%
#
# 600	  MemLength: 5864 6.9	  ChunkLength: 5.60	  EvalIndex: 2.236 Change:0.9%
#
# 700	  MemLength: 6020 7.0	  ChunkLength: 5.64	  EvalIndex: 2.226 Change:0.4%
#
# 800	  MemLength: 6192 7.0	  ChunkLength: 5.70	  EvalIndex: 2.210 Change:0.7%
#
# 900	  MemLength: 6384 7.1	  ChunkLength: 5.74	  EvalIndex: 2.204 Change:0.3%
#
# 1000	  MemLength: 6516 7.1	  ChunkLength: 5.76	  EvalIndex: 2.199 Change:0.2%
#
# 1100	  MemLength: 6659 7.1	  ChunkLength: 5.80	  EvalIndex: 2.192 Change:0.3%
#
# 1200	  MemLength: 6772 7.1	  ChunkLength: 5.84	  EvalIndex: 2.180 Change:0.5%
#
# 1300	  MemLength: 7090 7.2	  ChunkLength: 5.90	  EvalIndex: 2.169 Change:0.5%
#
# 1400	  MemLength: 7248 7.2	  ChunkLength: 5.93	  EvalIndex: 2.164 Change:0.2%
#
# 1500	  MemLength: 7371 7.2	  ChunkLength: 5.95	  EvalIndex: 2.158 Change:0.3%
#
# 1600	  MemLength: 7413 7.2	  ChunkLength: 5.97	  EvalIndex: 2.153 Change:0.2%
#
# 1700	  MemLength: 7516 7.3	  ChunkLength: 5.99	  EvalIndex: 2.149 Change:0.2%
#
# 1800	  MemLength: 7655 7.3	  ChunkLength: 6.02	  EvalIndex: 2.142 Change:0.3%
#
# 1900	  MemLength: 7823 7.3	  ChunkLength: 6.05	  EvalIndex: 2.139 Change:0.2%
#
# 2000	  MemLength: 7867 7.3	  ChunkLength: 6.06	  EvalIndex: 2.137 Change:0.1%
#
# 2100	  MemLength: 7983 7.3	  ChunkLength: 6.08	  EvalIndex: 2.131 Change:0.3%
#
# 2200	  MemLength: 8131 7.3	  ChunkLength: 6.11	  EvalIndex: 2.126 Change:0.3%
#
# 2300	  MemLength: 8175 7.3	  ChunkLength: 6.12	  EvalIndex: 2.122 Change:0.2%
#
# 2400	  MemLength: 8372 7.4	  ChunkLength: 6.15	  EvalIndex: 2.118 Change:0.2%
#
# 2500	  MemLength: 8393 7.4	  ChunkLength: 6.16	  EvalIndex: 2.115 Change:0.2%
#
# 2600	  MemLength: 8585 7.4	  ChunkLength: 6.18	  EvalIndex: 2.113 Change:0.1%
#
# 2700	  MemLength: 8631 7.4	  ChunkLength: 6.20	  EvalIndex: 2.108 Change:0.2%
#
# 2800	  MemLength: 8785 7.5	  ChunkLength: 6.22	  EvalIndex: 2.106 Change:0.1%
#
# 2900	  MemLength: 8847 7.5	  ChunkLength: 6.23	  EvalIndex: 2.103 Change:0.1%
#
# 3000	  MemLength: 8911 7.5	  ChunkLength: 6.25	  EvalIndex: 2.100 Change:0.1%
#
# 3100	  MemLength: 9078 7.5	  ChunkLength: 6.27	  EvalIndex: 2.098 Change:0.1%
#
# 3200	  MemLength: 9110 7.5	  ChunkLength: 6.29	  EvalIndex: 2.093 Change:0.2%
#
# 3300	  MemLength: 9268 7.5	  ChunkLength: 6.31	  EvalIndex: 2.090 Change:0.1%
#
# 3400	  MemLength: 9353 7.5	  ChunkLength: 6.32	  EvalIndex: 2.087 Change:0.1%
#
# 3500	  MemLength: 9383 7.5	  ChunkLength: 6.33	  EvalIndex: 2.085 Change:0.1%
#
# 3600	  MemLength: 9446 7.6	  ChunkLength: 6.34	  EvalIndex: 2.084 Change:0.0%
#
# 3700	  MemLength: 9492 7.5	  ChunkLength: 6.34	  EvalIndex: 2.083 Change:0.1%
#
# 3800	  MemLength: 9690 7.6	  ChunkLength: 6.36	  EvalIndex: 2.081 Change:0.1%
#
# 3900	  MemLength: 9776 7.6	  ChunkLength: 6.38	  EvalIndex: 2.077 Change:0.2%
#
# 4000	  MemLength: 9804 7.6	  ChunkLength: 6.39	  EvalIndex: 2.074 Change:0.2%
#
# 4100	  MemLength: 9902 7.6	  ChunkLength: 6.41	  EvalIndex: 2.071 Change:0.1%
#
# 4200	  MemLength: 10027 7.6	  ChunkLength: 6.42	  EvalIndex: 2.069 Change:0.1%
#
# 4300	  MemLength: 10055 7.6	  ChunkLength: 6.43	  EvalIndex: 2.068 Change:0.1%
#
# 4400	  MemLength: 10094 7.6	  ChunkLength: 6.44	  EvalIndex: 2.064 Change:0.2%
#
# 4500	  MemLength: 10191 7.7	  ChunkLength: 6.45	  EvalIndex: 2.065 Change:-0.0%
#
# [Length] Word 5.596 Pred 6.444 Real 8.194	Model_SE 0.004 CI 0.010
# [F1] Model 52.73 Word 38.68
# 12
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.909
#
# 100	  MemLength: 3906 6.4	  ChunkLength: 4.82	  EvalIndex: 2.477 Change:36.6%
#
# 200	  MemLength: 4788 6.7	  ChunkLength: 5.18	  EvalIndex: 2.358 Change:4.8%
#
# 300	  MemLength: 5558 7.0	  ChunkLength: 5.43	  EvalIndex: 2.289 Change:2.9%
#
# 400	  MemLength: 6096 7.1	  ChunkLength: 5.59	  EvalIndex: 2.249 Change:1.8%
#
# 500	  MemLength: 6441 7.2	  ChunkLength: 5.70	  EvalIndex: 2.222 Change:1.2%
#
# 600	  MemLength: 6711 7.3	  ChunkLength: 5.76	  EvalIndex: 2.205 Change:0.7%
#
# 700	  MemLength: 7098 7.4	  ChunkLength: 5.85	  EvalIndex: 2.185 Change:0.9%
#
# 800	  MemLength: 7133 7.3	  ChunkLength: 5.89	  EvalIndex: 2.172 Change:0.6%
#
# 900	  MemLength: 7388 7.5	  ChunkLength: 5.93	  EvalIndex: 2.167 Change:0.2%
#
# 1000	  MemLength: 7812 7.5	  ChunkLength: 6.02	  EvalIndex: 2.149 Change:0.8%
#
# 1100	  MemLength: 8063 7.6	  ChunkLength: 6.06	  EvalIndex: 2.140 Change:0.4%
#
# 1200	  MemLength: 8196 7.6	  ChunkLength: 6.09	  EvalIndex: 2.136 Change:0.2%
#
# 1300	  MemLength: 8430 7.6	  ChunkLength: 6.14	  EvalIndex: 2.124 Change:0.6%
#
# 1400	  MemLength: 8581 7.7	  ChunkLength: 6.17	  EvalIndex: 2.117 Change:0.3%
#
# 1500	  MemLength: 8699 7.7	  ChunkLength: 6.19	  EvalIndex: 2.113 Change:0.2%
#
# 1600	  MemLength: 8931 7.7	  ChunkLength: 6.23	  EvalIndex: 2.107 Change:0.3%
#
# 1700	  MemLength: 9167 7.8	  ChunkLength: 6.29	  EvalIndex: 2.094 Change:0.6%
#
# 1800	  MemLength: 9253 7.8	  ChunkLength: 6.31	  EvalIndex: 2.087 Change:0.3%
#
# 1900	  MemLength: 9459 7.8	  ChunkLength: 6.34	  EvalIndex: 2.083 Change:0.2%
#
# 2000	  MemLength: 9498 7.8	  ChunkLength: 6.36	  EvalIndex: 2.078 Change:0.2%
#
# 2100	  MemLength: 9581 7.8	  ChunkLength: 6.38	  EvalIndex: 2.073 Change:0.3%
#
# 2200	  MemLength: 9814 7.9	  ChunkLength: 6.41	  EvalIndex: 2.068 Change:0.2%
#
# 2300	  MemLength: 9847 7.9	  ChunkLength: 6.43	  EvalIndex: 2.064 Change:0.2%
#
# 2400	  MemLength: 9946 7.9	  ChunkLength: 6.44	  EvalIndex: 2.062 Change:0.1%
#
# 2500	  MemLength: 10115 7.9	  ChunkLength: 6.47	  EvalIndex: 2.056 Change:0.3%
#
# 2600	  MemLength: 10160 7.9	  ChunkLength: 6.48	  EvalIndex: 2.054 Change:0.1%
#
# 2700	  MemLength: 10243 7.9	  ChunkLength: 6.50	  EvalIndex: 2.051 Change:0.1%
#
# 2800	  MemLength: 10219 7.9	  ChunkLength: 6.49	  EvalIndex: 2.052 Change:-0.1%
#
# [Length] Word 5.596 Pred 6.486 Real 8.194	Model_SE 0.004 CI 0.011
# [F1] Model 52.60 Word 38.68
# 13
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.909
#
# 100	  MemLength: 3437 6.2	  ChunkLength: 4.80	  EvalIndex: 2.447 Change:37.4%
#
# 200	  MemLength: 4495 6.8	  ChunkLength: 5.19	  EvalIndex: 2.338 Change:4.4%
#
# 300	  MemLength: 4967 7.0	  ChunkLength: 5.37	  EvalIndex: 2.285 Change:2.3%
#
# 400	  MemLength: 5482 7.1	  ChunkLength: 5.54	  EvalIndex: 2.242 Change:1.9%
#
# 500	  MemLength: 5888 7.3	  ChunkLength: 5.64	  EvalIndex: 2.219 Change:1.0%
#
# 600	  MemLength: 6160 7.3	  ChunkLength: 5.74	  EvalIndex: 2.192 Change:1.2%
#
# 700	  MemLength: 6785 7.5	  ChunkLength: 5.86	  EvalIndex: 2.170 Change:1.0%
#
# 800	  MemLength: 6921 7.6	  ChunkLength: 5.92	  EvalIndex: 2.155 Change:0.7%
#
# 900	  MemLength: 7057 7.6	  ChunkLength: 5.96	  EvalIndex: 2.147 Change:0.4%
#
# 1000	  MemLength: 7291 7.6	  ChunkLength: 6.01	  EvalIndex: 2.133 Change:0.6%
#
# 1100	  MemLength: 7447 7.7	  ChunkLength: 6.06	  EvalIndex: 2.123 Change:0.5%
#
# 1200	  MemLength: 7735 7.8	  ChunkLength: 6.11	  EvalIndex: 2.114 Change:0.5%
#
# 1300	  MemLength: 7964 7.8	  ChunkLength: 6.16	  EvalIndex: 2.104 Change:0.4%
#
# 1400	  MemLength: 8204 7.9	  ChunkLength: 6.20	  EvalIndex: 2.098 Change:0.3%
#
# 1500	  MemLength: 8412 7.9	  ChunkLength: 6.25	  EvalIndex: 2.085 Change:0.6%
#
# 1600	  MemLength: 8507 7.9	  ChunkLength: 6.27	  EvalIndex: 2.083 Change:0.1%
#
# 1700	  MemLength: 8717 8.0	  ChunkLength: 6.30	  EvalIndex: 2.078 Change:0.2%
#
# 1800	  MemLength: 8918 8.0	  ChunkLength: 6.35	  EvalIndex: 2.068 Change:0.5%
#
# 1900	  MemLength: 9059 8.0	  ChunkLength: 6.38	  EvalIndex: 2.061 Change:0.3%
#
# 2000	  MemLength: 9274 8.0	  ChunkLength: 6.42	  EvalIndex: 2.053 Change:0.4%
#
# 2100	  MemLength: 9439 8.1	  ChunkLength: 6.45	  EvalIndex: 2.049 Change:0.2%
#
# 2200	  MemLength: 9582 8.1	  ChunkLength: 6.48	  EvalIndex: 2.043 Change:0.3%
#
# 2300	  MemLength: 9732 8.2	  ChunkLength: 6.50	  EvalIndex: 2.039 Change:0.2%
#
# 2400	  MemLength: 9771 8.1	  ChunkLength: 6.51	  EvalIndex: 2.035 Change:0.2%
#
# 2500	  MemLength: 9940 8.2	  ChunkLength: 6.54	  EvalIndex: 2.029 Change:0.3%
#
# 2600	  MemLength: 10034 8.2	  ChunkLength: 6.56	  EvalIndex: 2.025 Change:0.2%
#
# 2700	  MemLength: 10104 8.2	  ChunkLength: 6.58	  EvalIndex: 2.022 Change:0.2%
#
# 2800	  MemLength: 10267 8.3	  ChunkLength: 6.60	  EvalIndex: 2.019 Change:0.2%
#
# 2900	  MemLength: 10381 8.2	  ChunkLength: 6.62	  EvalIndex: 2.014 Change:0.2%
#
# 3000	  MemLength: 10551 8.2	  ChunkLength: 6.65	  EvalIndex: 2.009 Change:0.3%
#
# 3100	  MemLength: 10612 8.3	  ChunkLength: 6.68	  EvalIndex: 2.003 Change:0.3%
#
# 3200	  MemLength: 10717 8.3	  ChunkLength: 6.69	  EvalIndex: 2.001 Change:0.1%
#
# 3300	  MemLength: 10858 8.3	  ChunkLength: 6.72	  EvalIndex: 1.996 Change:0.2%
#
# 3400	  MemLength: 10944 8.3	  ChunkLength: 6.73	  EvalIndex: 1.994 Change:0.1%
#
# 3500	  MemLength: 11117 8.4	  ChunkLength: 6.76	  EvalIndex: 1.989 Change:0.2%
#
# 3600	  MemLength: 11130 8.3	  ChunkLength: 6.77	  EvalIndex: 1.985 Change:0.2%
#
# 3700	  MemLength: 11370 8.4	  ChunkLength: 6.81	  EvalIndex: 1.978 Change:0.3%
#
# 3800	  MemLength: 11513 8.4	  ChunkLength: 6.83	  EvalIndex: 1.975 Change:0.2%
#
# 3900	  MemLength: 11566 8.4	  ChunkLength: 6.84	  EvalIndex: 1.973 Change:0.1%
#
# 4000	  MemLength: 11650 8.4	  ChunkLength: 6.85	  EvalIndex: 1.973 Change:-0.0%
#
# [Length] Word 5.596 Pred 6.840 Real 8.194	Model_SE 0.005 CI 0.012
# [F1] Model 53.16 Word 38.68
# 14
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.909
#
# 100	  MemLength: 3917 6.6	  ChunkLength: 4.84	  EvalIndex: 2.466 Change:36.9%
#
# 200	  MemLength: 4866 7.0	  ChunkLength: 5.23	  EvalIndex: 2.343 Change:5.0%
#
# 300	  MemLength: 5475 7.2	  ChunkLength: 5.46	  EvalIndex: 2.274 Change:2.9%
#
# 400	  MemLength: 5913 7.3	  ChunkLength: 5.61	  EvalIndex: 2.235 Change:1.7%
#
# 500	  MemLength: 6340 7.5	  ChunkLength: 5.73	  EvalIndex: 2.205 Change:1.3%
#
# 600	  MemLength: 6569 7.6	  ChunkLength: 5.79	  EvalIndex: 2.189 Change:0.7%
#
# 700	  MemLength: 6852 7.6	  ChunkLength: 5.88	  EvalIndex: 2.168 Change:0.9%
#
# 800	  MemLength: 7413 7.8	  ChunkLength: 5.98	  EvalIndex: 2.149 Change:0.9%
#
# 900	  MemLength: 7494 7.8	  ChunkLength: 6.02	  EvalIndex: 2.138 Change:0.5%
#
# 1000	  MemLength: 7789 7.9	  ChunkLength: 6.08	  EvalIndex: 2.125 Change:0.6%
#
# 1100	  MemLength: 7996 8.0	  ChunkLength: 6.14	  EvalIndex: 2.112 Change:0.6%
#
# 1200	  MemLength: 8166 8.0	  ChunkLength: 6.19	  EvalIndex: 2.101 Change:0.5%
#
# 1300	  MemLength: 8484 8.1	  ChunkLength: 6.24	  EvalIndex: 2.092 Change:0.5%
#
# 1400	  MemLength: 8776 8.1	  ChunkLength: 6.30	  EvalIndex: 2.081 Change:0.5%
#
# 1500	  MemLength: 8893 8.1	  ChunkLength: 6.33	  EvalIndex: 2.073 Change:0.4%
#
# 1600	  MemLength: 8934 8.2	  ChunkLength: 6.35	  EvalIndex: 2.068 Change:0.2%
#
# 1700	  MemLength: 9003 8.2	  ChunkLength: 6.36	  EvalIndex: 2.065 Change:0.2%
#
# 1800	  MemLength: 9205 8.2	  ChunkLength: 6.40	  EvalIndex: 2.057 Change:0.4%
#
# 1900	  MemLength: 9324 8.2	  ChunkLength: 6.43	  EvalIndex: 2.052 Change:0.2%
#
# 2000	  MemLength: 9563 8.3	  ChunkLength: 6.48	  EvalIndex: 2.042 Change:0.5%
#
# 2100	  MemLength: 9617 8.3	  ChunkLength: 6.49	  EvalIndex: 2.039 Change:0.2%
#
# 2200	  MemLength: 9789 8.3	  ChunkLength: 6.53	  EvalIndex: 2.031 Change:0.4%
#
# 2300	  MemLength: 9870 8.4	  ChunkLength: 6.54	  EvalIndex: 2.028 Change:0.1%
#
# 2400	  MemLength: 10053 8.4	  ChunkLength: 6.58	  EvalIndex: 2.021 Change:0.4%
#
# 2500	  MemLength: 10210 8.4	  ChunkLength: 6.61	  EvalIndex: 2.015 Change:0.3%
#
# 2600	  MemLength: 10467 8.4	  ChunkLength: 6.66	  EvalIndex: 2.006 Change:0.4%
#
# 2700	  MemLength: 10592 8.4	  ChunkLength: 6.67	  EvalIndex: 2.005 Change:0.1%
#
# 2800	  MemLength: 10619 8.5	  ChunkLength: 6.68	  EvalIndex: 2.003 Change:0.1%
#
# 2900	  MemLength: 10658 8.5	  ChunkLength: 6.69	  EvalIndex: 1.999 Change:0.2%
#
# 3000	  MemLength: 10762 8.5	  ChunkLength: 6.71	  EvalIndex: 1.997 Change:0.1%
#
# 3100	  MemLength: 10843 8.5	  ChunkLength: 6.72	  EvalIndex: 1.994 Change:0.1%
#
# 3200	  MemLength: 10953 8.5	  ChunkLength: 6.75	  EvalIndex: 1.989 Change:0.3%
#
# 3300	  MemLength: 11154 8.6	  ChunkLength: 6.77	  EvalIndex: 1.985 Change:0.2%
#
# 3400	  MemLength: 11192 8.6	  ChunkLength: 6.78	  EvalIndex: 1.983 Change:0.1%
#
# 3500	  MemLength: 11278 8.6	  ChunkLength: 6.79	  EvalIndex: 1.982 Change:0.1%
#
# 3600	  MemLength: 11486 8.6	  ChunkLength: 6.83	  EvalIndex: 1.975 Change:0.3%
#
# 3700	  MemLength: 11522 8.6	  ChunkLength: 6.84	  EvalIndex: 1.972 Change:0.1%
#
# 3800	  MemLength: 11501 8.6	  ChunkLength: 6.84	  EvalIndex: 1.973 Change:-0.0%
#
# [Length] Word 5.596 Pred 6.833 Real 8.194	Model_SE 0.005 CI 0.012
# [F1] Model 52.85 Word 38.68
# 15
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.909
#
# 100	  MemLength: 3987 6.7	  ChunkLength: 4.82	  EvalIndex: 2.479 Change:36.6%
#
# 200	  MemLength: 5075 7.2	  ChunkLength: 5.25	  EvalIndex: 2.344 Change:5.5%
#
# 300	  MemLength: 5647 7.3	  ChunkLength: 5.48	  EvalIndex: 2.275 Change:3.0%
#
# 400	  MemLength: 6062 7.5	  ChunkLength: 5.62	  EvalIndex: 2.237 Change:1.6%
#
# 500	  MemLength: 6594 7.7	  ChunkLength: 5.76	  EvalIndex: 2.202 Change:1.6%
#
# 600	  MemLength: 6775 7.8	  ChunkLength: 5.83	  EvalIndex: 2.183 Change:0.8%
#
# 700	  MemLength: 7010 7.8	  ChunkLength: 5.91	  EvalIndex: 2.163 Change:0.9%
#
# 800	  MemLength: 7277 7.9	  ChunkLength: 5.98	  EvalIndex: 2.144 Change:0.9%
#
# 900	  MemLength: 7727 8.0	  ChunkLength: 6.07	  EvalIndex: 2.128 Change:0.7%
#
# 1000	  MemLength: 7991 8.1	  ChunkLength: 6.13	  EvalIndex: 2.114 Change:0.7%
#
# 1100	  MemLength: 8259 8.2	  ChunkLength: 6.19	  EvalIndex: 2.104 Change:0.5%
#
# 1200	  MemLength: 8329 8.2	  ChunkLength: 6.21	  EvalIndex: 2.098 Change:0.3%
#
# 1300	  MemLength: 8669 8.2	  ChunkLength: 6.28	  EvalIndex: 2.085 Change:0.6%
#
# 1400	  MemLength: 8973 8.3	  ChunkLength: 6.34	  EvalIndex: 2.071 Change:0.6%
#
# 1500	  MemLength: 9071 8.3	  ChunkLength: 6.37	  EvalIndex: 2.064 Change:0.4%
#
# 1600	  MemLength: 9249 8.4	  ChunkLength: 6.40	  EvalIndex: 2.057 Change:0.3%
#
# 1700	  MemLength: 9274 8.4	  ChunkLength: 6.42	  EvalIndex: 2.052 Change:0.2%
#
# 1800	  MemLength: 9490 8.4	  ChunkLength: 6.47	  EvalIndex: 2.043 Change:0.5%
#
# 1900	  MemLength: 9590 8.4	  ChunkLength: 6.49	  EvalIndex: 2.039 Change:0.2%
#
# 2000	  MemLength: 9698 8.5	  ChunkLength: 6.52	  EvalIndex: 2.031 Change:0.4%
#
# 2100	  MemLength: 9941 8.5	  ChunkLength: 6.56	  EvalIndex: 2.025 Change:0.3%
#
# 2200	  MemLength: 10071 8.6	  ChunkLength: 6.58	  EvalIndex: 2.021 Change:0.2%
#
# 2300	  MemLength: 10188 8.6	  ChunkLength: 6.61	  EvalIndex: 2.014 Change:0.3%
#
# 2400	  MemLength: 10348 8.6	  ChunkLength: 6.64	  EvalIndex: 2.010 Change:0.2%
#
# 2500	  MemLength: 10458 8.6	  ChunkLength: 6.67	  EvalIndex: 2.003 Change:0.3%
#
# 2600	  MemLength: 10782 8.7	  ChunkLength: 6.71	  EvalIndex: 1.995 Change:0.4%
#
# 2700	  MemLength: 11060 8.8	  ChunkLength: 6.75	  EvalIndex: 1.989 Change:0.3%
#
# 2800	  MemLength: 11012 8.7	  ChunkLength: 6.76	  EvalIndex: 1.987 Change:0.1%
#
# 2900	  MemLength: 11144 8.8	  ChunkLength: 6.78	  EvalIndex: 1.982 Change:0.2%
#
# 3000	  MemLength: 11326 8.8	  ChunkLength: 6.81	  EvalIndex: 1.977 Change:0.3%
#
# 3100	  MemLength: 11453 8.8	  ChunkLength: 6.84	  EvalIndex: 1.970 Change:0.3%
#
# 3200	  MemLength: 11744 8.9	  ChunkLength: 6.90	  EvalIndex: 1.961 Change:0.5%
#
# 3300	  MemLength: 11882 8.9	  ChunkLength: 6.92	  EvalIndex: 1.956 Change:0.2%
#
# 3400	  MemLength: 12020 8.9	  ChunkLength: 6.94	  EvalIndex: 1.954 Change:0.1%
#
# 3500	  MemLength: 12105 8.9	  ChunkLength: 6.96	  EvalIndex: 1.950 Change:0.2%
#
# 3600	  MemLength: 12384 9.0	  ChunkLength: 7.01	  EvalIndex: 1.940 Change:0.5%
#
# 3700	  MemLength: 12341 9.0	  ChunkLength: 7.00	  EvalIndex: 1.942 Change:-0.1%
#
# [Length] Word 5.596 Pred 6.993 Real 8.194	Model_SE 0.005 CI 0.013
# [F1] Model 52.93 Word 38.68
# 16
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.909
#
# 100	  MemLength: 3772 6.5	  ChunkLength: 4.83	  EvalIndex: 2.459 Change:37.1%
#
# 200	  MemLength: 4674 7.0	  ChunkLength: 5.20	  EvalIndex: 2.343 Change:4.7%
#
# 300	  MemLength: 5566 7.3	  ChunkLength: 5.48	  EvalIndex: 2.273 Change:3.0%
#
# 400	  MemLength: 6069 7.6	  ChunkLength: 5.63	  EvalIndex: 2.231 Change:1.8%
#
# 500	  MemLength: 6494 7.7	  ChunkLength: 5.78	  EvalIndex: 2.189 Change:1.9%
#
# 600	  MemLength: 7006 8.0	  ChunkLength: 5.88	  EvalIndex: 2.171 Change:0.8%
#
# 700	  MemLength: 7265 8.0	  ChunkLength: 5.97	  EvalIndex: 2.150 Change:1.0%
#
# 800	  MemLength: 7451 8.0	  ChunkLength: 6.02	  EvalIndex: 2.137 Change:0.6%
#
# 900	  MemLength: 7978 8.2	  ChunkLength: 6.12	  EvalIndex: 2.118 Change:0.9%
#
# 1000	  MemLength: 8184 8.2	  ChunkLength: 6.17	  EvalIndex: 2.106 Change:0.6%
#
# 1100	  MemLength: 8372 8.3	  ChunkLength: 6.22	  EvalIndex: 2.095 Change:0.5%
#
# 1200	  MemLength: 8437 8.3	  ChunkLength: 6.25	  EvalIndex: 2.086 Change:0.4%
#
# 1300	  MemLength: 8845 8.4	  ChunkLength: 6.33	  EvalIndex: 2.072 Change:0.7%
#
# 1400	  MemLength: 8969 8.5	  ChunkLength: 6.36	  EvalIndex: 2.065 Change:0.3%
#
# 1500	  MemLength: 9232 8.6	  ChunkLength: 6.41	  EvalIndex: 2.055 Change:0.5%
#
# 1600	  MemLength: 9349 8.6	  ChunkLength: 6.43	  EvalIndex: 2.051 Change:0.2%
#
# 1700	  MemLength: 9622 8.7	  ChunkLength: 6.48	  EvalIndex: 2.040 Change:0.5%
#
# 1800	  MemLength: 9898 8.8	  ChunkLength: 6.53	  EvalIndex: 2.033 Change:0.3%
#
# 1900	  MemLength: 10204 8.8	  ChunkLength: 6.58	  EvalIndex: 2.023 Change:0.5%
#
# 2000	  MemLength: 10255 8.8	  ChunkLength: 6.60	  EvalIndex: 2.020 Change:0.1%
#
# 2100	  MemLength: 10336 8.8	  ChunkLength: 6.62	  EvalIndex: 2.014 Change:0.3%
#
# 2200	  MemLength: 10565 8.8	  ChunkLength: 6.67	  EvalIndex: 2.005 Change:0.4%
#
# 2300	  MemLength: 10675 8.9	  ChunkLength: 6.69	  EvalIndex: 2.001 Change:0.2%
#
# 2400	  MemLength: 10875 8.9	  ChunkLength: 6.72	  EvalIndex: 1.994 Change:0.3%
#
# 2500	  MemLength: 11202 9.0	  ChunkLength: 6.78	  EvalIndex: 1.985 Change:0.5%
#
# 2600	  MemLength: 11216 9.0	  ChunkLength: 6.79	  EvalIndex: 1.983 Change:0.1%
#
# 2700	  MemLength: 11331 9.0	  ChunkLength: 6.81	  EvalIndex: 1.977 Change:0.3%
#
# 2800	  MemLength: 11564 9.0	  ChunkLength: 6.85	  EvalIndex: 1.969 Change:0.4%
#
# 2900	  MemLength: 11696 9.1	  ChunkLength: 6.87	  EvalIndex: 1.966 Change:0.1%
#
# 3000	  MemLength: 11891 9.1	  ChunkLength: 6.91	  EvalIndex: 1.960 Change:0.3%
#
# 3100	  MemLength: 12027 9.1	  ChunkLength: 6.94	  EvalIndex: 1.954 Change:0.3%
#
# 3200	  MemLength: 12284 9.2	  ChunkLength: 6.98	  EvalIndex: 1.947 Change:0.3%
#
# 3300	  MemLength: 12392 9.2	  ChunkLength: 6.99	  EvalIndex: 1.944 Change:0.1%
#
# 3400	  MemLength: 12595 9.2	  ChunkLength: 7.03	  EvalIndex: 1.937 Change:0.4%
#
# 3500	  MemLength: 12678 9.3	  ChunkLength: 7.05	  EvalIndex: 1.933 Change:0.2%
#
# 3600	  MemLength: 12822 9.3	  ChunkLength: 7.07	  EvalIndex: 1.930 Change:0.1%
#
# 3700	  MemLength: 12958 9.3	  ChunkLength: 7.10	  EvalIndex: 1.925 Change:0.2%
#
# 3800	  MemLength: 12999 9.3	  ChunkLength: 7.11	  EvalIndex: 1.921 Change:0.2%
#
# 3900	  MemLength: 13090 9.3	  ChunkLength: 7.13	  EvalIndex: 1.918 Change:0.1%
#
# 4000	  MemLength: 13135 9.3	  ChunkLength: 7.14	  EvalIndex: 1.917 Change:0.1%
#
# 4100	  MemLength: 13348 9.4	  ChunkLength: 7.18	  EvalIndex: 1.909 Change:0.4%
#
# 4200	  MemLength: 13506 9.4	  ChunkLength: 7.21	  EvalIndex: 1.903 Change:0.3%
#
# 4300	  MemLength: 13654 9.4	  ChunkLength: 7.24	  EvalIndex: 1.897 Change:0.3%
#
# 4400	  MemLength: 13639 9.4	  ChunkLength: 7.24	  EvalIndex: 1.898 Change:-0.0%
#
# [Length] Word 5.596 Pred 7.228 Real 8.194	Model_SE 0.006 CI 0.014
# [F1] Model 52.88 Word 38.68
# 17
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.909
#
# 100	  MemLength: 3958 6.7	  ChunkLength: 4.87	  EvalIndex: 2.454 Change:37.2%
#
# 200	  MemLength: 4767 7.1	  ChunkLength: 5.26	  EvalIndex: 2.325 Change:5.3%
#
# 300	  MemLength: 5337 7.3	  ChunkLength: 5.47	  EvalIndex: 2.265 Change:2.6%
#
# 400	  MemLength: 5855 7.5	  ChunkLength: 5.64	  EvalIndex: 2.220 Change:2.0%
#
# 500	  MemLength: 6303 7.7	  ChunkLength: 5.77	  EvalIndex: 2.189 Change:1.4%
#
# 600	  MemLength: 6785 7.9	  ChunkLength: 5.87	  EvalIndex: 2.170 Change:0.9%
#
# 700	  MemLength: 7076 8.0	  ChunkLength: 5.95	  EvalIndex: 2.150 Change:0.9%
#
# 800	  MemLength: 7742 8.2	  ChunkLength: 6.07	  EvalIndex: 2.128 Change:1.0%
#
# 900	  MemLength: 7944 8.3	  ChunkLength: 6.12	  EvalIndex: 2.116 Change:0.5%
#
# 1000	  MemLength: 8213 8.4	  ChunkLength: 6.19	  EvalIndex: 2.102 Change:0.7%
#
# 1100	  MemLength: 8384 8.5	  ChunkLength: 6.22	  EvalIndex: 2.094 Change:0.3%
#
# 1200	  MemLength: 8734 8.6	  ChunkLength: 6.29	  EvalIndex: 2.080 Change:0.7%
#
# 1300	  MemLength: 8953 8.7	  ChunkLength: 6.35	  EvalIndex: 2.068 Change:0.6%
#
# 1400	  MemLength: 9046 8.7	  ChunkLength: 6.37	  EvalIndex: 2.065 Change:0.1%
#
# 1500	  MemLength: 9386 8.7	  ChunkLength: 6.45	  EvalIndex: 2.047 Change:0.8%
#
# 1600	  MemLength: 9549 8.8	  ChunkLength: 6.48	  EvalIndex: 2.041 Change:0.3%
#
# 1700	  MemLength: 9690 8.8	  ChunkLength: 6.51	  EvalIndex: 2.034 Change:0.3%
#
# 1800	  MemLength: 9946 8.9	  ChunkLength: 6.55	  EvalIndex: 2.026 Change:0.4%
#
# 1900	  MemLength: 9980 8.9	  ChunkLength: 6.57	  EvalIndex: 2.023 Change:0.1%
#
# 2000	  MemLength: 10206 8.9	  ChunkLength: 6.61	  EvalIndex: 2.014 Change:0.4%
#
# 2100	  MemLength: 10386 9.0	  ChunkLength: 6.64	  EvalIndex: 2.009 Change:0.2%
#
# 2200	  MemLength: 10703 9.1	  ChunkLength: 6.69	  EvalIndex: 2.000 Change:0.5%
#
# 2300	  MemLength: 10955 9.1	  ChunkLength: 6.74	  EvalIndex: 1.991 Change:0.5%
#
# 2400	  MemLength: 11101 9.1	  ChunkLength: 6.78	  EvalIndex: 1.981 Change:0.5%
#
# 2500	  MemLength: 11108 9.1	  ChunkLength: 6.78	  EvalIndex: 1.981 Change:0.0%
#
# 2600	  MemLength: 11464 9.2	  ChunkLength: 6.84	  EvalIndex: 1.971 Change:0.5%
#
# 2700	  MemLength: 11526 9.1	  ChunkLength: 6.87	  EvalIndex: 1.965 Change:0.3%
#
# 2800	  MemLength: 11821 9.2	  ChunkLength: 6.91	  EvalIndex: 1.959 Change:0.3%
#
# 2900	  MemLength: 11921 9.3	  ChunkLength: 6.92	  EvalIndex: 1.956 Change:0.1%
#
# 3000	  MemLength: 12006 9.3	  ChunkLength: 6.94	  EvalIndex: 1.952 Change:0.2%
#
# 3100	  MemLength: 12213 9.3	  ChunkLength: 6.99	  EvalIndex: 1.944 Change:0.5%
#
# 3200	  MemLength: 12449 9.3	  ChunkLength: 7.02	  EvalIndex: 1.938 Change:0.3%
#
# 3300	  MemLength: 12546 9.4	  ChunkLength: 7.04	  EvalIndex: 1.935 Change:0.2%
#
# 3400	  MemLength: 12554 9.3	  ChunkLength: 7.05	  EvalIndex: 1.931 Change:0.2%
#
# 3500	  MemLength: 12832 9.4	  ChunkLength: 7.10	  EvalIndex: 1.923 Change:0.4%
#
# 3600	  MemLength: 12921 9.4	  ChunkLength: 7.11	  EvalIndex: 1.920 Change:0.2%
#
# 3700	  MemLength: 13096 9.5	  ChunkLength: 7.14	  EvalIndex: 1.915 Change:0.3%
#
# 3800	  MemLength: 13203 9.5	  ChunkLength: 7.17	  EvalIndex: 1.909 Change:0.3%
#
# 3900	  MemLength: 13427 9.5	  ChunkLength: 7.21	  EvalIndex: 1.902 Change:0.3%
#
# 4000	  MemLength: 13628 9.5	  ChunkLength: 7.25	  EvalIndex: 1.894 Change:0.5%
#
# 4100	  MemLength: 13816 9.5	  ChunkLength: 7.28	  EvalIndex: 1.889 Change:0.3%
#
# 4200	  MemLength: 14030 9.6	  ChunkLength: 7.31	  EvalIndex: 1.885 Change:0.2%
#
# 4300	  MemLength: 14032 9.6	  ChunkLength: 7.32	  EvalIndex: 1.883 Change:0.1%
#
# 4400	  MemLength: 14171 9.6	  ChunkLength: 7.34	  EvalIndex: 1.878 Change:0.3%
#
# 4500	  MemLength: 14233 9.7	  ChunkLength: 7.35	  EvalIndex: 1.878 Change:0.0%
#
# 4600	  MemLength: 14311 9.6	  ChunkLength: 7.38	  EvalIndex: 1.871 Change:0.4%
#
# 4700	  MemLength: 14406 9.7	  ChunkLength: 7.39	  EvalIndex: 1.868 Change:0.2%
#
# 4800	  MemLength: 14476 9.7	  ChunkLength: 7.40	  EvalIndex: 1.867 Change:0.1%
#
# 4900	  MemLength: 14483 9.7	  ChunkLength: 7.40	  EvalIndex: 1.867 Change:-0.0%
#
# [Length] Word 5.596 Pred 7.398 Real 8.194	Model_SE 0.006 CI 0.015
# [F1] Model 52.97 Word 38.68
# 18
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.909
#
# 100	  MemLength: 3687 6.4	  ChunkLength: 4.87	  EvalIndex: 2.434 Change:37.7%
#
# 200	  MemLength: 4510 7.0	  ChunkLength: 5.22	  EvalIndex: 2.325 Change:4.5%
#
# 300	  MemLength: 5469 7.4	  ChunkLength: 5.48	  EvalIndex: 2.265 Change:2.6%
#
# 400	  MemLength: 5949 7.7	  ChunkLength: 5.66	  EvalIndex: 2.216 Change:2.1%
#
# 500	  MemLength: 6491 7.9	  ChunkLength: 5.80	  EvalIndex: 2.183 Change:1.5%
#
# 600	  MemLength: 6725 8.0	  ChunkLength: 5.87	  EvalIndex: 2.164 Change:0.9%
#
# 700	  MemLength: 7098 8.1	  ChunkLength: 5.96	  EvalIndex: 2.145 Change:0.9%
#
# 800	  MemLength: 7803 8.3	  ChunkLength: 6.09	  EvalIndex: 2.123 Change:1.0%
#
# 900	  MemLength: 8253 8.4	  ChunkLength: 6.19	  EvalIndex: 2.102 Change:1.0%
#
# 1000	  MemLength: 8558 8.6	  ChunkLength: 6.25	  EvalIndex: 2.089 Change:0.6%
#
# 1100	  MemLength: 8726 8.6	  ChunkLength: 6.31	  EvalIndex: 2.076 Change:0.6%
#
# 1200	  MemLength: 8939 8.7	  ChunkLength: 6.35	  EvalIndex: 2.068 Change:0.4%
#
# 1300	  MemLength: 9104 8.7	  ChunkLength: 6.39	  EvalIndex: 2.059 Change:0.5%
#
# 1400	  MemLength: 9344 8.8	  ChunkLength: 6.44	  EvalIndex: 2.049 Change:0.5%
#
# 1500	  MemLength: 9525 8.8	  ChunkLength: 6.48	  EvalIndex: 2.041 Change:0.4%
#
# 1600	  MemLength: 9634 8.9	  ChunkLength: 6.50	  EvalIndex: 2.035 Change:0.3%
#
# 1700	  MemLength: 9886 9.0	  ChunkLength: 6.54	  EvalIndex: 2.028 Change:0.3%
#
# 1800	  MemLength: 10146 9.0	  ChunkLength: 6.59	  EvalIndex: 2.021 Change:0.4%
#
# 1900	  MemLength: 10371 9.1	  ChunkLength: 6.64	  EvalIndex: 2.010 Change:0.5%
#
# 2000	  MemLength: 10600 9.1	  ChunkLength: 6.68	  EvalIndex: 2.002 Change:0.4%
#
# 2100	  MemLength: 10885 9.2	  ChunkLength: 6.73	  EvalIndex: 1.993 Change:0.5%
#
# 2200	  MemLength: 10954 9.2	  ChunkLength: 6.74	  EvalIndex: 1.992 Change:0.1%
#
# 2300	  MemLength: 11311 9.2	  ChunkLength: 6.80	  EvalIndex: 1.981 Change:0.6%
#
# 2400	  MemLength: 11349 9.3	  ChunkLength: 6.82	  EvalIndex: 1.976 Change:0.2%
#
# 2500	  MemLength: 11434 9.3	  ChunkLength: 6.83	  EvalIndex: 1.973 Change:0.2%
#
# 2600	  MemLength: 11621 9.3	  ChunkLength: 6.86	  EvalIndex: 1.967 Change:0.3%
#
# 2700	  MemLength: 11736 9.3	  ChunkLength: 6.88	  EvalIndex: 1.964 Change:0.1%
#
# 2800	  MemLength: 11985 9.4	  ChunkLength: 6.93	  EvalIndex: 1.955 Change:0.5%
#
# 2900	  MemLength: 12053 9.4	  ChunkLength: 6.95	  EvalIndex: 1.950 Change:0.3%
#
# 3000	  MemLength: 12145 9.5	  ChunkLength: 6.96	  EvalIndex: 1.949 Change:0.0%
#
# 3100	  MemLength: 12308 9.5	  ChunkLength: 6.99	  EvalIndex: 1.945 Change:0.2%
#
# 3200	  MemLength: 12477 9.5	  ChunkLength: 7.01	  EvalIndex: 1.940 Change:0.3%
#
# 3300	  MemLength: 12518 9.5	  ChunkLength: 7.02	  EvalIndex: 1.938 Change:0.1%
#
# 3400	  MemLength: 12701 9.5	  ChunkLength: 7.06	  EvalIndex: 1.932 Change:0.3%
#
# 3500	  MemLength: 12986 9.6	  ChunkLength: 7.11	  EvalIndex: 1.921 Change:0.5%
#
# 3600	  MemLength: 13102 9.6	  ChunkLength: 7.13	  EvalIndex: 1.918 Change:0.2%
#
# 3700	  MemLength: 13138 9.6	  ChunkLength: 7.14	  EvalIndex: 1.917 Change:0.1%
#
# 3800	  MemLength: 13220 9.6	  ChunkLength: 7.16	  EvalIndex: 1.912 Change:0.3%
#
# 3900	  MemLength: 13368 9.7	  ChunkLength: 7.18	  EvalIndex: 1.909 Change:0.1%
#
# 4000	  MemLength: 13457 9.6	  ChunkLength: 7.21	  EvalIndex: 1.903 Change:0.3%
#
# 4100	  MemLength: 13576 9.7	  ChunkLength: 7.22	  EvalIndex: 1.901 Change:0.1%
#
# 4200	  MemLength: 13806 9.7	  ChunkLength: 7.26	  EvalIndex: 1.893 Change:0.4%
#
# 4300	  MemLength: 14021 9.8	  ChunkLength: 7.30	  EvalIndex: 1.886 Change:0.4%
#
# 4400	  MemLength: 14200 9.8	  ChunkLength: 7.33	  EvalIndex: 1.881 Change:0.3%
#
# 4500	  MemLength: 14356 9.8	  ChunkLength: 7.35	  EvalIndex: 1.878 Change:0.2%
#
# 4600	  MemLength: 14564 9.9	  ChunkLength: 7.39	  EvalIndex: 1.871 Change:0.3%
#
# 4700	  MemLength: 14772 9.9	  ChunkLength: 7.42	  EvalIndex: 1.866 Change:0.3%
#
# 4800	  MemLength: 15080 9.9	  ChunkLength: 7.48	  EvalIndex: 1.855 Change:0.6%
#
# 4900	  MemLength: 15127 10.0	  ChunkLength: 7.50	  EvalIndex: 1.852 Change:0.2%
#
# 5000	  MemLength: 15178 10.0	  ChunkLength: 7.51	  EvalIndex: 1.849 Change:0.2%
#
# 5100	  MemLength: 15263 10.0	  ChunkLength: 7.52	  EvalIndex: 1.847 Change:0.1%
#
# 5200	  MemLength: 15357 10.0	  ChunkLength: 7.55	  EvalIndex: 1.841 Change:0.3%
#
# 5300	  MemLength: 15416 10.0	  ChunkLength: 7.56	  EvalIndex: 1.840 Change:0.1%
#
# 5400	  MemLength: 15563 10.1	  ChunkLength: 7.58	  EvalIndex: 1.837 Change:0.2%
#
# 5500	  MemLength: 15610 10.1	  ChunkLength: 7.59	  EvalIndex: 1.836 Change:0.1%
#
# 5600	  MemLength: 15785 10.1	  ChunkLength: 7.62	  EvalIndex: 1.829 Change:0.3%
#
# 5700	  MemLength: 15861 10.1	  ChunkLength: 7.64	  EvalIndex: 1.826 Change:0.2%
#
# 5800	  MemLength: 16017 10.1	  ChunkLength: 7.66	  EvalIndex: 1.823 Change:0.2%
#
# 5900	  MemLength: 16074 10.1	  ChunkLength: 7.68	  EvalIndex: 1.820 Change:0.2%
#
# 6000	  MemLength: 16137 10.1	  ChunkLength: 7.69	  EvalIndex: 1.817 Change:0.1%
#
# 6100	  MemLength: 16205 10.1	  ChunkLength: 7.71	  EvalIndex: 1.813 Change:0.3%
#
# 6200	  MemLength: 16263 10.1	  ChunkLength: 7.72	  EvalIndex: 1.813 Change:-0.0%
#
# [Length] Word 5.596 Pred 7.708 Real 8.194	Model_SE 0.007 CI 0.017
# [F1] Model 52.89 Word 38.68
# 19
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.909
#
# 100	  MemLength: 3872 6.7	  ChunkLength: 4.84	  EvalIndex: 2.464 Change:37.0%
#
# 200	  MemLength: 4849 7.1	  ChunkLength: 5.28	  EvalIndex: 2.321 Change:5.8%
#
# 300	  MemLength: 5516 7.4	  ChunkLength: 5.51	  EvalIndex: 2.255 Change:2.9%
#
# 400	  MemLength: 5979 7.7	  ChunkLength: 5.66	  EvalIndex: 2.217 Change:1.7%
#
# 500	  MemLength: 6479 7.9	  ChunkLength: 5.81	  EvalIndex: 2.180 Change:1.7%
#
# 600	  MemLength: 6870 8.1	  ChunkLength: 5.91	  EvalIndex: 2.159 Change:1.0%
#
# 700	  MemLength: 7113 8.2	  ChunkLength: 5.98	  EvalIndex: 2.140 Change:0.9%
#
# 800	  MemLength: 7479 8.3	  ChunkLength: 6.07	  EvalIndex: 2.121 Change:0.9%
#
# 900	  MemLength: 7607 8.4	  ChunkLength: 6.10	  EvalIndex: 2.113 Change:0.4%
#
# 1000	  MemLength: 7811 8.4	  ChunkLength: 6.15	  EvalIndex: 2.101 Change:0.6%
#
# 1100	  MemLength: 8025 8.5	  ChunkLength: 6.21	  EvalIndex: 2.088 Change:0.6%
#
# 1200	  MemLength: 8193 8.6	  ChunkLength: 6.25	  EvalIndex: 2.080 Change:0.4%
#
# 1300	  MemLength: 8445 8.6	  ChunkLength: 6.30	  EvalIndex: 2.069 Change:0.5%
#
# 1400	  MemLength: 8891 8.7	  ChunkLength: 6.39	  EvalIndex: 2.054 Change:0.7%
#
# 1500	  MemLength: 9115 8.8	  ChunkLength: 6.42	  EvalIndex: 2.048 Change:0.3%
#
# 1600	  MemLength: 9307 8.9	  ChunkLength: 6.47	  EvalIndex: 2.039 Change:0.4%
#
# 1700	  MemLength: 9533 8.9	  ChunkLength: 6.52	  EvalIndex: 2.029 Change:0.5%
#
# 1800	  MemLength: 9793 9.0	  ChunkLength: 6.56	  EvalIndex: 2.022 Change:0.4%
#
# 1900	  MemLength: 9825 9.1	  ChunkLength: 6.57	  EvalIndex: 2.018 Change:0.2%
#
# 2000	  MemLength: 10047 9.1	  ChunkLength: 6.62	  EvalIndex: 2.009 Change:0.5%
#
# 2100	  MemLength: 10299 9.1	  ChunkLength: 6.67	  EvalIndex: 1.999 Change:0.5%
#
# 2200	  MemLength: 10537 9.2	  ChunkLength: 6.72	  EvalIndex: 1.989 Change:0.5%
#
# 2300	  MemLength: 10774 9.2	  ChunkLength: 6.75	  EvalIndex: 1.984 Change:0.2%
#
# 2400	  MemLength: 10897 9.3	  ChunkLength: 6.78	  EvalIndex: 1.978 Change:0.3%
#
# 2500	  MemLength: 11206 9.4	  ChunkLength: 6.83	  EvalIndex: 1.969 Change:0.4%
#
# 2600	  MemLength: 11306 9.4	  ChunkLength: 6.86	  EvalIndex: 1.964 Change:0.3%
#
# 2700	  MemLength: 11487 9.4	  ChunkLength: 6.89	  EvalIndex: 1.958 Change:0.3%
#
# 2800	  MemLength: 11641 9.5	  ChunkLength: 6.91	  EvalIndex: 1.955 Change:0.2%
#
# 2900	  MemLength: 11780 9.5	  ChunkLength: 6.94	  EvalIndex: 1.948 Change:0.4%
#
# 3000	  MemLength: 11858 9.5	  ChunkLength: 6.96	  EvalIndex: 1.945 Change:0.1%
#
# 3100	  MemLength: 11955 9.5	  ChunkLength: 6.98	  EvalIndex: 1.942 Change:0.2%
#
# 3200	  MemLength: 12320 9.6	  ChunkLength: 7.04	  EvalIndex: 1.931 Change:0.5%
#
# 3300	  MemLength: 12423 9.7	  ChunkLength: 7.05	  EvalIndex: 1.931 Change:0.0%
#
# 3400	  MemLength: 12513 9.7	  ChunkLength: 7.07	  EvalIndex: 1.925 Change:0.3%
#
# 3500	  MemLength: 12584 9.7	  ChunkLength: 7.09	  EvalIndex: 1.922 Change:0.2%
#
# 3600	  MemLength: 12883 9.8	  ChunkLength: 7.14	  EvalIndex: 1.913 Change:0.5%
#
# 3700	  MemLength: 12990 9.7	  ChunkLength: 7.16	  EvalIndex: 1.908 Change:0.2%
#
# 3800	  MemLength: 13175 9.8	  ChunkLength: 7.19	  EvalIndex: 1.903 Change:0.3%
#
# 3900	  MemLength: 13382 9.8	  ChunkLength: 7.23	  EvalIndex: 1.896 Change:0.4%
#
# 4000	  MemLength: 13543 9.9	  ChunkLength: 7.26	  EvalIndex: 1.891 Change:0.3%
#
# 4100	  MemLength: 13767 9.9	  ChunkLength: 7.30	  EvalIndex: 1.883 Change:0.4%
#
# 4200	  MemLength: 13887 9.9	  ChunkLength: 7.32	  EvalIndex: 1.879 Change:0.2%
#
# 4300	  MemLength: 14113 9.9	  ChunkLength: 7.37	  EvalIndex: 1.870 Change:0.4%
#
# 4400	  MemLength: 14302 10.0	  ChunkLength: 7.40	  EvalIndex: 1.866 Change:0.3%
#
# 4500	  MemLength: 14580 10.0	  ChunkLength: 7.45	  EvalIndex: 1.857 Change:0.5%
#
# 4600	  MemLength: 14753 10.0	  ChunkLength: 7.49	  EvalIndex: 1.849 Change:0.4%
#
# 4700	  MemLength: 14866 10.1	  ChunkLength: 7.50	  EvalIndex: 1.847 Change:0.1%
#
# 4800	  MemLength: 15011 10.1	  ChunkLength: 7.53	  EvalIndex: 1.843 Change:0.2%
#
# 4900	  MemLength: 15104 10.1	  ChunkLength: 7.55	  EvalIndex: 1.840 Change:0.2%
#
# 5000	  MemLength: 15275 10.2	  ChunkLength: 7.58	  EvalIndex: 1.834 Change:0.3%
#
# 5100	  MemLength: 15287 10.2	  ChunkLength: 7.58	  EvalIndex: 1.834 Change:-0.0%
#
# [Length] Word 5.596 Pred 7.571 Real 8.194	Model_SE 0.007 CI 0.017
# [F1] Model 52.68 Word 38.68
# 20
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.909
#
# 100	  MemLength: 3599 6.4	  ChunkLength: 4.82	  EvalIndex: 2.451 Change:37.3%
#
# 200	  MemLength: 4702 7.1	  ChunkLength: 5.25	  EvalIndex: 2.325 Change:5.1%
#
# 300	  MemLength: 5340 7.4	  ChunkLength: 5.48	  EvalIndex: 2.262 Change:2.7%
#
# 400	  MemLength: 5756 7.6	  ChunkLength: 5.62	  EvalIndex: 2.222 Change:1.8%
#
# 500	  MemLength: 6370 7.9	  ChunkLength: 5.79	  EvalIndex: 2.182 Change:1.8%
#
# 600	  MemLength: 6632 8.0	  ChunkLength: 5.87	  EvalIndex: 2.164 Change:0.8%
#
# 700	  MemLength: 7168 8.2	  ChunkLength: 5.99	  EvalIndex: 2.138 Change:1.2%
#
# 800	  MemLength: 7421 8.3	  ChunkLength: 6.06	  EvalIndex: 2.121 Change:0.8%
#
# 900	  MemLength: 7676 8.4	  ChunkLength: 6.13	  EvalIndex: 2.106 Change:0.7%
#
# 1000	  MemLength: 7922 8.5	  ChunkLength: 6.19	  EvalIndex: 2.093 Change:0.6%
#
# 1100	  MemLength: 8200 8.6	  ChunkLength: 6.25	  EvalIndex: 2.080 Change:0.6%
#
# 1200	  MemLength: 8336 8.6	  ChunkLength: 6.28	  EvalIndex: 2.074 Change:0.3%
#
# 1300	  MemLength: 8779 8.8	  ChunkLength: 6.37	  EvalIndex: 2.058 Change:0.8%
#
# 1400	  MemLength: 8939 8.8	  ChunkLength: 6.41	  EvalIndex: 2.049 Change:0.4%
#
# 1500	  MemLength: 9141 8.9	  ChunkLength: 6.45	  EvalIndex: 2.041 Change:0.4%
#
# 1600	  MemLength: 9331 9.0	  ChunkLength: 6.50	  EvalIndex: 2.030 Change:0.5%
#
# 1700	  MemLength: 9551 9.0	  ChunkLength: 6.54	  EvalIndex: 2.022 Change:0.4%
#
# 1800	  MemLength: 9930 9.1	  ChunkLength: 6.60	  EvalIndex: 2.011 Change:0.6%
#
# 1900	  MemLength: 10299 9.2	  ChunkLength: 6.67	  EvalIndex: 1.999 Change:0.6%
#
# 2000	  MemLength: 10637 9.3	  ChunkLength: 6.73	  EvalIndex: 1.988 Change:0.6%
#
# 2100	  MemLength: 10728 9.3	  ChunkLength: 6.74	  EvalIndex: 1.985 Change:0.1%
#
# 2200	  MemLength: 11035 9.4	  ChunkLength: 6.81	  EvalIndex: 1.973 Change:0.6%
#
# 2300	  MemLength: 11186 9.5	  ChunkLength: 6.83	  EvalIndex: 1.968 Change:0.3%
#
# 2400	  MemLength: 11273 9.5	  ChunkLength: 6.86	  EvalIndex: 1.963 Change:0.2%
#
# 2500	  MemLength: 11693 9.5	  ChunkLength: 6.93	  EvalIndex: 1.950 Change:0.6%
#
# 2600	  MemLength: 11862 9.6	  ChunkLength: 6.96	  EvalIndex: 1.945 Change:0.3%
#
# 2700	  MemLength: 11969 9.6	  ChunkLength: 6.98	  EvalIndex: 1.940 Change:0.3%
#
# 2800	  MemLength: 12321 9.7	  ChunkLength: 7.04	  EvalIndex: 1.930 Change:0.5%
#
# 2900	  MemLength: 12405 9.7	  ChunkLength: 7.06	  EvalIndex: 1.926 Change:0.2%
#
# 3000	  MemLength: 12687 9.8	  ChunkLength: 7.11	  EvalIndex: 1.918 Change:0.4%
#
# 3100	  MemLength: 12755 9.8	  ChunkLength: 7.12	  EvalIndex: 1.915 Change:0.2%
#
# 3200	  MemLength: 12874 9.8	  ChunkLength: 7.15	  EvalIndex: 1.909 Change:0.3%
#
# 3300	  MemLength: 13069 9.9	  ChunkLength: 7.19	  EvalIndex: 1.901 Change:0.4%
#
# 3400	  MemLength: 13209 9.9	  ChunkLength: 7.20	  EvalIndex: 1.902 Change:-0.0%
#
# [Length] Word 5.596 Pred 7.188 Real 8.194	Model_SE 0.006 CI 0.016
# [F1] Model 52.17 Word 38.68
# 21
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.909
#
# 100	  MemLength: 3908 6.7	  ChunkLength: 4.89	  EvalIndex: 2.441 Change:37.6%
#
# 200	  MemLength: 4965 7.2	  ChunkLength: 5.32	  EvalIndex: 2.308 Change:5.4%
#
# 300	  MemLength: 5660 7.6	  ChunkLength: 5.55	  EvalIndex: 2.247 Change:2.6%
#
# 400	  MemLength: 5918 7.7	  ChunkLength: 5.68	  EvalIndex: 2.208 Change:1.8%
#
# 500	  MemLength: 6435 7.9	  ChunkLength: 5.82	  EvalIndex: 2.175 Change:1.5%
#
# 600	  MemLength: 6634 8.0	  ChunkLength: 5.89	  EvalIndex: 2.156 Change:0.8%
#
# 700	  MemLength: 7016 8.2	  ChunkLength: 5.98	  EvalIndex: 2.137 Change:0.9%
#
# 800	  MemLength: 7222 8.2	  ChunkLength: 6.05	  EvalIndex: 2.117 Change:0.9%
#
# 900	  MemLength: 7661 8.3	  ChunkLength: 6.13	  EvalIndex: 2.104 Change:0.6%
#
# 1000	  MemLength: 7884 8.5	  ChunkLength: 6.19	  EvalIndex: 2.092 Change:0.6%
#
# 1100	  MemLength: 8109 8.5	  ChunkLength: 6.24	  EvalIndex: 2.080 Change:0.6%
#
# 1200	  MemLength: 8295 8.6	  ChunkLength: 6.30	  EvalIndex: 2.067 Change:0.6%
#
# 1300	  MemLength: 8403 8.7	  ChunkLength: 6.33	  EvalIndex: 2.060 Change:0.4%
#
# 1400	  MemLength: 8727 8.8	  ChunkLength: 6.40	  EvalIndex: 2.045 Change:0.7%
#
# 1500	  MemLength: 8891 8.8	  ChunkLength: 6.43	  EvalIndex: 2.040 Change:0.3%
#
# 1600	  MemLength: 9222 9.0	  ChunkLength: 6.50	  EvalIndex: 2.028 Change:0.6%
#
# 1700	  MemLength: 9432 9.0	  ChunkLength: 6.54	  EvalIndex: 2.020 Change:0.4%
#
# 1800	  MemLength: 9661 9.1	  ChunkLength: 6.59	  EvalIndex: 2.010 Change:0.5%
#
# 1900	  MemLength: 9896 9.2	  ChunkLength: 6.64	  EvalIndex: 1.999 Change:0.5%
#
# 2000	  MemLength: 10340 9.3	  ChunkLength: 6.71	  EvalIndex: 1.988 Change:0.5%
#
# 2100	  MemLength: 10565 9.3	  ChunkLength: 6.74	  EvalIndex: 1.982 Change:0.3%
#
# 2200	  MemLength: 10647 9.4	  ChunkLength: 6.76	  EvalIndex: 1.979 Change:0.2%
#
# 2300	  MemLength: 10831 9.4	  ChunkLength: 6.80	  EvalIndex: 1.972 Change:0.3%
#
# 2400	  MemLength: 11063 9.5	  ChunkLength: 6.83	  EvalIndex: 1.966 Change:0.3%
#
# 2500	  MemLength: 11209 9.5	  ChunkLength: 6.87	  EvalIndex: 1.958 Change:0.4%
#
# 2600	  MemLength: 11560 9.7	  ChunkLength: 6.93	  EvalIndex: 1.949 Change:0.5%
#
# 2700	  MemLength: 11666 9.6	  ChunkLength: 6.96	  EvalIndex: 1.942 Change:0.4%
#
# 2800	  MemLength: 11917 9.7	  ChunkLength: 7.00	  EvalIndex: 1.934 Change:0.4%
#
# 2900	  MemLength: 12195 9.8	  ChunkLength: 7.05	  EvalIndex: 1.924 Change:0.5%
#
# 3000	  MemLength: 12288 9.8	  ChunkLength: 7.07	  EvalIndex: 1.922 Change:0.1%
#
# 3100	  MemLength: 12422 9.8	  ChunkLength: 7.09	  EvalIndex: 1.919 Change:0.2%
#
# 3200	  MemLength: 12511 9.8	  ChunkLength: 7.11	  EvalIndex: 1.914 Change:0.3%
#
# 3300	  MemLength: 12624 9.9	  ChunkLength: 7.13	  EvalIndex: 1.911 Change:0.1%
#
# 3400	  MemLength: 12769 9.9	  ChunkLength: 7.16	  EvalIndex: 1.906 Change:0.3%
#
# 3500	  MemLength: 12901 10.0	  ChunkLength: 7.19	  EvalIndex: 1.900 Change:0.3%
#
# 3600	  MemLength: 13078 10.0	  ChunkLength: 7.22	  EvalIndex: 1.895 Change:0.3%
#
# 3700	  MemLength: 13324 10.0	  ChunkLength: 7.27	  EvalIndex: 1.885 Change:0.6%
#
# 3800	  MemLength: 13393 10.1	  ChunkLength: 7.28	  EvalIndex: 1.884 Change:0.0%
#
# 3900	  MemLength: 13606 10.1	  ChunkLength: 7.31	  EvalIndex: 1.877 Change:0.4%
#
# 4000	  MemLength: 13723 10.1	  ChunkLength: 7.34	  EvalIndex: 1.873 Change:0.3%
#
# 4100	  MemLength: 13969 10.1	  ChunkLength: 7.38	  EvalIndex: 1.865 Change:0.4%
#
# 4200	  MemLength: 14242 10.2	  ChunkLength: 7.43	  EvalIndex: 1.857 Change:0.4%
#
# 4300	  MemLength: 14368 10.3	  ChunkLength: 7.45	  EvalIndex: 1.854 Change:0.2%
#
# 4400	  MemLength: 14426 10.2	  ChunkLength: 7.46	  EvalIndex: 1.852 Change:0.1%
#
# 4500	  MemLength: 14557 10.3	  ChunkLength: 7.48	  EvalIndex: 1.849 Change:0.2%
#
# 4600	  MemLength: 14669 10.3	  ChunkLength: 7.50	  EvalIndex: 1.845 Change:0.2%
#
# 4700	  MemLength: 14839 10.3	  ChunkLength: 7.54	  EvalIndex: 1.837 Change:0.4%
#
# 4800	  MemLength: 14995 10.4	  ChunkLength: 7.56	  EvalIndex: 1.834 Change:0.1%
#
# 4900	  MemLength: 15111 10.4	  ChunkLength: 7.58	  EvalIndex: 1.831 Change:0.2%
#
# 5000	  MemLength: 15223 10.4	  ChunkLength: 7.61	  EvalIndex: 1.826 Change:0.3%
#
# 5100	  MemLength: 15305 10.4	  ChunkLength: 7.63	  EvalIndex: 1.822 Change:0.2%
#
# 5200	  MemLength: 15424 10.5	  ChunkLength: 7.65	  EvalIndex: 1.820 Change:0.1%
#
# 5300	  MemLength: 15602 10.5	  ChunkLength: 7.68	  EvalIndex: 1.813 Change:0.4%
#
# 5400	  MemLength: 15771 10.5	  ChunkLength: 7.71	  EvalIndex: 1.808 Change:0.3%
#
# 5500	  MemLength: 15854 10.5	  ChunkLength: 7.73	  EvalIndex: 1.805 Change:0.2%
#
# 5600	  MemLength: 15919 10.5	  ChunkLength: 7.75	  EvalIndex: 1.801 Change:0.2%
#
# 5700	  MemLength: 16099 10.6	  ChunkLength: 7.78	  EvalIndex: 1.797 Change:0.2%
#
# 5800	  MemLength: 16265 10.6	  ChunkLength: 7.81	  EvalIndex: 1.792 Change:0.3%
#
# 5900	  MemLength: 16342 10.6	  ChunkLength: 7.82	  EvalIndex: 1.790 Change:0.1%
#
# 6000	  MemLength: 16361 10.6	  ChunkLength: 7.83	  EvalIndex: 1.788 Change:0.1%
#
# 6100	  MemLength: 16400 10.7	  ChunkLength: 7.83	  EvalIndex: 1.788 Change:-0.0%
#
# [Length] Word 5.596 Pred 7.832 Real 8.194	Model_SE 0.007 CI 0.018
# [F1] Model 52.51 Word 38.68
# 22
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.909
#
# 100	  MemLength: 3822 6.7	  ChunkLength: 4.83	  EvalIndex: 2.462 Change:37.0%
#
# 200	  MemLength: 4826 7.2	  ChunkLength: 5.26	  EvalIndex: 2.327 Change:5.5%
#
# 300	  MemLength: 5550 7.5	  ChunkLength: 5.50	  EvalIndex: 2.262 Change:2.8%
#
# 400	  MemLength: 6128 7.7	  ChunkLength: 5.68	  EvalIndex: 2.214 Change:2.1%
#
# 500	  MemLength: 6384 7.9	  ChunkLength: 5.79	  EvalIndex: 2.183 Change:1.4%
#
# 600	  MemLength: 6826 8.1	  ChunkLength: 5.90	  EvalIndex: 2.158 Change:1.1%
#
# 700	  MemLength: 7261 8.3	  ChunkLength: 6.00	  EvalIndex: 2.139 Change:0.9%
#
# ...
#
# 1100	  MemLength: 8817 9.0	  ChunkLength: 6.34	  EvalIndex: 2.066 Change:0.6%
#
# 1200	  MemLength: 9046 9.1	  ChunkLength: 6.40	  EvalIndex: 2.054 Change:0.5%
#
# 1300	  MemLength: 9557 9.3	  ChunkLength: 6.49	  EvalIndex: 2.039 Change:0.8%
#
# 1400	  MemLength: 9819 9.3	  ChunkLength: 6.54	  EvalIndex: 2.028 Change:0.5%
#
# 1500	  MemLength: 10038 9.5	  ChunkLength: 6.59	  EvalIndex: 2.019 Change:0.5%
#
# 1600	  MemLength: 10395 9.5	  ChunkLength: 6.65	  EvalIndex: 2.007 Change:0.6%
#
# 1700	  MemLength: 10624 9.6	  ChunkLength: 6.70	  EvalIndex: 1.997 Change:0.5%
#
# 1800	  MemLength: 10754 9.6	  ChunkLength: 6.73	  EvalIndex: 1.989 Change:0.4%
#
# 1900	  MemLength: 11074 9.8	  ChunkLength: 6.79	  EvalIndex: 1.980 Change:0.5%
#
# 2000	  MemLength: 11256 9.8	  ChunkLength: 6.83	  EvalIndex: 1.972 Change:0.4%
#
# 2100	  MemLength: 11560 9.9	  ChunkLength: 6.88	  EvalIndex: 1.962 Change:0.5%
#
# 2200	  MemLength: 11954 10.1	  ChunkLength: 6.95	  EvalIndex: 1.948 Change:0.7%
#
# 2300	  MemLength: 12100 10.1	  ChunkLength: 6.97	  EvalIndex: 1.947 Change:0.1%
#
# 2400	  MemLength: 12520 10.2	  ChunkLength: 7.04	  EvalIndex: 1.934 Change:0.7%
#
# 2500	  MemLength: 12659 10.3	  ChunkLength: 7.06	  EvalIndex: 1.929 Change:0.2%
#
# 2600	  MemLength: 12867 10.3	  ChunkLength: 7.11	  EvalIndex: 1.920 Change:0.5%
#
# 2700	  MemLength: 12967 10.4	  ChunkLength: 7.14	  EvalIndex: 1.914 Change:0.3%
#
# 2800	  MemLength: 13249 10.4	  ChunkLength: 7.19	  EvalIndex: 1.904 Change:0.6%
#
# 2900	  MemLength: 13343 10.5	  ChunkLength: 7.21	  EvalIndex: 1.901 Change:0.1%
#
# 3000	  MemLength: 13456 10.5	  ChunkLength: 7.23	  EvalIndex: 1.897 Change:0.2%
#
# 3100	  MemLength: 13565 10.5	  ChunkLength: 7.25	  EvalIndex: 1.893 Change:0.2%
#
# 3200	  MemLength: 13680 10.5	  ChunkLength: 7.28	  EvalIndex: 1.889 Change:0.2%
#
# 3300	  MemLength: 13768 10.6	  ChunkLength: 7.29	  EvalIndex: 1.885 Change:0.2%
#
# 3400	  MemLength: 14002 10.6	  ChunkLength: 7.34	  EvalIndex: 1.876 Change:0.5%
#
# 3500	  MemLength: 14145 10.6	  ChunkLength: 7.37	  EvalIndex: 1.871 Change:0.3%
#
# 3600	  MemLength: 14292 10.7	  ChunkLength: 7.40	  EvalIndex: 1.866 Change:0.2%
#
# 3700	  MemLength: 14452 10.8	  ChunkLength: 7.43	  EvalIndex: 1.861 Change:0.3%
#
# 3800	  MemLength: 14677 10.8	  ChunkLength: 7.47	  EvalIndex: 1.853 Change:0.4%
#
# 3900	  MemLength: 14705 10.8	  ChunkLength: 7.48	  EvalIndex: 1.852 Change:0.1%
#
# 4000	  MemLength: 14923 10.8	  ChunkLength: 7.52	  EvalIndex: 1.844 Change:0.4%
#
# 4100	  MemLength: 15033 10.9	  ChunkLength: 7.54	  EvalIndex: 1.840 Change:0.2%
#
# 4200	  MemLength: 15171 10.9	  ChunkLength: 7.57	  EvalIndex: 1.836 Change:0.2%
#
# 4300	  MemLength: 15265 11.0	  ChunkLength: 7.58	  EvalIndex: 1.833 Change:0.1%
#
# 4400	  MemLength: 15466 11.0	  ChunkLength: 7.62	  EvalIndex: 1.826 Change:0.4%
#
# 4500	  MemLength: 15706 11.1	  ChunkLength: 7.67	  EvalIndex: 1.818 Change:0.4%
#
# 4600	  MemLength: 15759 11.1	  ChunkLength: 7.68	  EvalIndex: 1.816 Change:0.1%
#
# 4700	  MemLength: 15968 11.1	  ChunkLength: 7.73	  EvalIndex: 1.807 Change:0.5%
#
# 4800	  MemLength: 16254 11.2	  ChunkLength: 7.77	  EvalIndex: 1.800 Change:0.4%
#
# 4900	  MemLength: 16358 11.2	  ChunkLength: 7.79	  EvalIndex: 1.797 Change:0.2%
#
# 5000	  MemLength: 16519 11.3	  ChunkLength: 7.82	  EvalIndex: 1.791 Change:0.3%
#
# 5100	  MemLength: 16676 11.3	  ChunkLength: 7.85	  EvalIndex: 1.787 Change:0.2%
#
# 5200	  MemLength: 16766 11.3	  ChunkLength: 7.88	  EvalIndex: 1.782 Change:0.3%
#
# 5300	  MemLength: 16887 11.4	  ChunkLength: 7.90	  EvalIndex: 1.778 Change:0.2%
#
# 5400	  MemLength: 17083 11.4	  ChunkLength: 7.93	  EvalIndex: 1.774 Change:0.2%
#
# 5500	  MemLength: 17217 11.4	  ChunkLength: 7.95	  EvalIndex: 1.771 Change:0.1%
#
# 5600	  MemLength: 17333 11.5	  ChunkLength: 7.98	  EvalIndex: 1.765 Change:0.3%
#
# 5700	  MemLength: 17414 11.5	  ChunkLength: 8.00	  EvalIndex: 1.761 Change:0.2%
#
# 5800	  MemLength: 17516 11.5	  ChunkLength: 8.01	  EvalIndex: 1.760 Change:0.1%
#
# 5900	  MemLength: 17616 11.5	  ChunkLength: 8.05	  EvalIndex: 1.753 Change:0.4%
#
# 6000	  MemLength: 17713 11.6	  ChunkLength: 8.06	  EvalIndex: 1.752 Change:0.1%
#
# 6100	  MemLength: 17803 11.6	  ChunkLength: 8.07	  EvalIndex: 1.750 Change:0.1%
#
# 6200	  MemLength: 17970 11.6	  ChunkLength: 8.11	  EvalIndex: 1.743 Change:0.4%
#
# 6300	  MemLength: 18017 11.6	  ChunkLength: 8.12	  EvalIndex: 1.742 Change:0.1%
#
# 6400	  MemLength: 18093 11.7	  ChunkLength: 8.14	  EvalIndex: 1.737 Change:0.2%
#
# 6500	  MemLength: 18250 11.7	  ChunkLength: 8.17	  EvalIndex: 1.733 Change:0.3%
#
# 6600	  MemLength: 18357 11.7	  ChunkLength: 8.19	  EvalIndex: 1.730 Change:0.2%
#
# 6700	  MemLength: 18366 11.7	  ChunkLength: 8.19	  EvalIndex: 1.729 Change:0.1%
#
# 6800	  MemLength: 18387 11.7	  ChunkLength: 8.20	  EvalIndex: 1.728 Change:0.1%
#
# 6900	  MemLength: 18508 11.8	  ChunkLength: 8.23	  EvalIndex: 1.722 Change:0.4%
#
# 7000	  MemLength: 18577 11.8	  ChunkLength: 8.24	  EvalIndex: 1.721 Change:0.0%
#
# 7100	  MemLength: 18666 11.8	  ChunkLength: 8.25	  EvalIndex: 1.719 Change:0.1%
#
# 7200	  MemLength: 18716 11.8	  ChunkLength: 8.27	  EvalIndex: 1.717 Change:0.1%
#
# 7300	  MemLength: 18836 11.8	  ChunkLength: 8.30	  EvalIndex: 1.711 Change:0.3%
#
# 7400	  MemLength: 19027 11.9	  ChunkLength: 8.33	  EvalIndex: 1.707 Change:0.3%
#
# 7500	  MemLength: 19239 11.9	  ChunkLength: 8.37	  EvalIndex: 1.700 Change:0.4%
#
# 7600	  MemLength: 19240 11.9	  ChunkLength: 8.39	  EvalIndex: 1.696 Change:0.2%
#
# 7700	  MemLength: 19318 11.9	  ChunkLength: 8.39	  EvalIndex: 1.696 Change:-0.0%
#
# [Length] Word 5.596 Pred 8.390 Real 8.194	Model_SE 0.009 CI 0.023
# [F1] Model 52.03 Word 38.68
# 29
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.909
#
# 100	  MemLength: 4020 6.8	  ChunkLength: 4.87	  EvalIndex: 2.461 Change:37.1%
#
# 200	  MemLength: 5057 7.2	  ChunkLength: 5.26	  EvalIndex: 2.338 Change:5.0%
#
# 300	  MemLength: 5503 7.5	  ChunkLength: 5.49	  EvalIndex: 2.262 Change:3.3%
#
# 400	  MemLength: 6183 7.9	  ChunkLength: 5.70	  EvalIndex: 2.210 Change:2.3%
#
# 500	  MemLength: 6595 8.0	  ChunkLength: 5.83	  EvalIndex: 2.178 Change:1.5%
#
# 600	  MemLength: 7040 8.3	  ChunkLength: 5.93	  EvalIndex: 2.155 Change:1.0%
#
# 700	  MemLength: 7490 8.4	  ChunkLength: 6.05	  EvalIndex: 2.126 Change:1.3%
#
# 800	  MemLength: 7627 8.5	  ChunkLength: 6.10	  EvalIndex: 2.115 Change:0.5%
#
# 900	  MemLength: 7926 8.7	  ChunkLength: 6.17	  EvalIndex: 2.099 Change:0.7%
#
# 1000	  MemLength: 8221 8.9	  ChunkLength: 6.24	  EvalIndex: 2.086 Change:0.7%
#
# 1100	  MemLength: 8460 8.9	  ChunkLength: 6.29	  EvalIndex: 2.073 Change:0.6%
#
# 1200	  MemLength: 8788 9.0	  ChunkLength: 6.36	  EvalIndex: 2.061 Change:0.6%
#
# 1300	  MemLength: 8965 9.1	  ChunkLength: 6.41	  EvalIndex: 2.050 Change:0.5%
#
# 1400	  MemLength: 9233 9.2	  ChunkLength: 6.45	  EvalIndex: 2.041 Change:0.4%
#
# 1500	  MemLength: 9506 9.3	  ChunkLength: 6.51	  EvalIndex: 2.031 Change:0.5%
#
# 1600	  MemLength: 9817 9.4	  ChunkLength: 6.56	  EvalIndex: 2.020 Change:0.5%
#
# 1700	  MemLength: 9930 9.4	  ChunkLength: 6.60	  EvalIndex: 2.013 Change:0.4%
#
# 1800	  MemLength: 10191 9.5	  ChunkLength: 6.65	  EvalIndex: 2.003 Change:0.5%
#
# 1900	  MemLength: 10570 9.7	  ChunkLength: 6.72	  EvalIndex: 1.989 Change:0.7%
#
# 2000	  MemLength: 10632 9.6	  ChunkLength: 6.74	  EvalIndex: 1.985 Change:0.2%
#
# 2100	  MemLength: 10651 9.7	  ChunkLength: 6.74	  EvalIndex: 1.985 Change:0.0%
#
# 2200	  MemLength: 11033 9.8	  ChunkLength: 6.82	  EvalIndex: 1.970 Change:0.8%
#
# 2300	  MemLength: 11124 9.8	  ChunkLength: 6.84	  EvalIndex: 1.966 Change:0.2%
#
# 2400	  MemLength: 11357 9.9	  ChunkLength: 6.88	  EvalIndex: 1.958 Change:0.4%
#
# 2500	  MemLength: 11466 9.9	  ChunkLength: 6.90	  EvalIndex: 1.953 Change:0.3%
#
# 2600	  MemLength: 11553 9.9	  ChunkLength: 6.92	  EvalIndex: 1.950 Change:0.2%
#
# 2700	  MemLength: 11721 10.0	  ChunkLength: 6.94	  EvalIndex: 1.947 Change:0.2%
#
# 2800	  MemLength: 11970 10.0	  ChunkLength: 6.99	  EvalIndex: 1.939 Change:0.4%
#
# 2900	  MemLength: 12131 10.1	  ChunkLength: 7.02	  EvalIndex: 1.933 Change:0.3%
#
# 3000	  MemLength: 12412 10.2	  ChunkLength: 7.07	  EvalIndex: 1.925 Change:0.4%
#
# 3100	  MemLength: 12744 10.3	  ChunkLength: 7.13	  EvalIndex: 1.913 Change:0.6%
#
# 3200	  MemLength: 12761 10.3	  ChunkLength: 7.13	  EvalIndex: 1.913 Change:0.0%
#
# 3300	  MemLength: 13014 10.4	  ChunkLength: 7.17	  EvalIndex: 1.906 Change:0.4%
#
# 3400	  MemLength: 13247 10.4	  ChunkLength: 7.21	  EvalIndex: 1.898 Change:0.4%
#
# 3500	  MemLength: 13268 10.4	  ChunkLength: 7.22	  EvalIndex: 1.896 Change:0.1%
#
# 3600	  MemLength: 13393 10.5	  ChunkLength: 7.25	  EvalIndex: 1.890 Change:0.3%
#
# 3700	  MemLength: 13538 10.5	  ChunkLength: 7.27	  EvalIndex: 1.887 Change:0.2%
#
# 3800	  MemLength: 13580 10.5	  ChunkLength: 7.29	  EvalIndex: 1.883 Change:0.2%
#
# 3900	  MemLength: 13715 10.6	  ChunkLength: 7.31	  EvalIndex: 1.881 Change:0.1%
#
# 4000	  MemLength: 13829 10.6	  ChunkLength: 7.33	  EvalIndex: 1.876 Change:0.3%
#
# 4100	  MemLength: 14115 10.7	  ChunkLength: 7.38	  EvalIndex: 1.868 Change:0.4%
#
# 4200	  MemLength: 14370 10.7	  ChunkLength: 7.43	  EvalIndex: 1.859 Change:0.4%
#
# 4300	  MemLength: 14424 10.7	  ChunkLength: 7.44	  EvalIndex: 1.857 Change:0.2%
#
# 4400	  MemLength: 14439 10.8	  ChunkLength: 7.45	  EvalIndex: 1.854 Change:0.1%
#
# 4500	  MemLength: 14619 10.8	  ChunkLength: 7.48	  EvalIndex: 1.849 Change:0.2%
#
# 4600	  MemLength: 14680 10.9	  ChunkLength: 7.50	  EvalIndex: 1.847 Change:0.2%
#
# 4700	  MemLength: 14842 10.9	  ChunkLength: 7.53	  EvalIndex: 1.839 Change:0.4%
#
# 4800	  MemLength: 14865 10.9	  ChunkLength: 7.54	  EvalIndex: 1.838 Change:0.0%
#
# 4900	  MemLength: 15072 11.0	  ChunkLength: 7.57	  EvalIndex: 1.832 Change:0.3%
#
# 5000	  MemLength: 15246 11.0	  ChunkLength: 7.61	  EvalIndex: 1.827 Change:0.3%
#
# 5100	  MemLength: 15332 11.0	  ChunkLength: 7.64	  EvalIndex: 1.820 Change:0.3%
#
# 5200	  MemLength: 15495 11.0	  ChunkLength: 7.66	  EvalIndex: 1.817 Change:0.2%
#
# 5300	  MemLength: 15709 11.1	  ChunkLength: 7.70	  EvalIndex: 1.811 Change:0.3%
#
# 5400	  MemLength: 15915 11.1	  ChunkLength: 7.73	  EvalIndex: 1.806 Change:0.3%
#
# 5500	  MemLength: 16048 11.2	  ChunkLength: 7.75	  EvalIndex: 1.802 Change:0.2%
#
# 5600	  MemLength: 16207 11.2	  ChunkLength: 7.79	  EvalIndex: 1.796 Change:0.3%
#
# 5700	  MemLength: 16216 11.2	  ChunkLength: 7.79	  EvalIndex: 1.796 Change:0.0%
#
# 5800	  MemLength: 16405 11.3	  ChunkLength: 7.83	  EvalIndex: 1.789 Change:0.4%
#
# 5900	  MemLength: 16476 11.3	  ChunkLength: 7.85	  EvalIndex: 1.784 Change:0.3%
#
# 6000	  MemLength: 16640 11.3	  ChunkLength: 7.88	  EvalIndex: 1.780 Change:0.3%
#
# 6100	  MemLength: 16862 11.4	  ChunkLength: 7.92	  EvalIndex: 1.773 Change:0.4%
#
# 6200	  MemLength: 16980 11.4	  ChunkLength: 7.95	  EvalIndex: 1.768 Change:0.2%
#
# 6300	  MemLength: 17211 11.5	  ChunkLength: 7.99	  EvalIndex: 1.761 Change:0.4%
#
# 6400	  MemLength: 17406 11.5	  ChunkLength: 8.03	  EvalIndex: 1.755 Change:0.3%
#
# 6500	  MemLength: 17533 11.6	  ChunkLength: 8.05	  EvalIndex: 1.751 Change:0.3%
#
# 6600	  MemLength: 17730 11.6	  ChunkLength: 8.09	  EvalIndex: 1.744 Change:0.4%
#
# 6700	  MemLength: 17838 11.7	  ChunkLength: 8.12	  EvalIndex: 1.740 Change:0.2%
#
# 6800	  MemLength: 17927 11.7	  ChunkLength: 8.14	  EvalIndex: 1.735 Change:0.3%
#
# 6900	  MemLength: 17992 11.7	  ChunkLength: 8.14	  EvalIndex: 1.736 Change:-0.0%
#
# [Length] Word 5.596 Pred 8.133 Real 8.194	Model_SE 0.009 CI 0.022
# [F1] Model 52.06 Word 38.68
# 30
# 0	  MemLength: 605 3.8	  ChunkLength: 2.36	  EvalIndex: 3.909
#
# 100	  MemLength: 4020 6.8	  ChunkLength: 4.87	  EvalIndex: 2.461 Change:37.1%
#
# 200	  MemLength: 5057 7.2	  ChunkLength: 5.26	  EvalIndex: 2.338 Change:5.0%
#
# 300	  MemLength: 5503 7.5	  ChunkLength: 5.49	  EvalIndex: 2.262 Change:3.3%
#
# 400	  MemLength: 6270 8.0	  ChunkLength: 5.70	  EvalIndex: 2.213 Change:2.1%
#
# 500	  MemLength: 6676 8.1	  ChunkLength: 5.83	  EvalIndex: 2.178 Change:1.6%
#
# 600	  MemLength: 7129 8.4	  ChunkLength: 5.93	  EvalIndex: 2.157 Change:1.0%
#
# 700	  MemLength: 7690 8.6	  ChunkLength: 6.06	  EvalIndex: 2.131 Change:1.2%
#
# 800	  MemLength: 8150 8.9	  ChunkLength: 6.15	  EvalIndex: 2.111 Change:0.9%
#
# 900	  MemLength: 8445 8.9	  ChunkLength: 6.24	  EvalIndex: 2.090 Change:1.0%
#
# 1000	  MemLength: 8748 9.0	  ChunkLength: 6.31	  EvalIndex: 2.075 Change:0.8%
#
# 1100	  MemLength: 8920 9.1	  ChunkLength: 6.35	  EvalIndex: 2.068 Change:0.3%
#
# 1200	  MemLength: 9078 9.2	  ChunkLength: 6.38	  EvalIndex: 2.061 Change:0.3%
#
# 1300	  MemLength: 9468 9.4	  ChunkLength: 6.46	  EvalIndex: 2.045 Change:0.8%
#
# 1400	  MemLength: 9637 9.4	  ChunkLength: 6.51	  EvalIndex: 2.033 Change:0.6%
#
# 1500	  MemLength: 9778 9.4	  ChunkLength: 6.54	  EvalIndex: 2.028 Change:0.2%
#
# 1600	  MemLength: 9902 9.5	  ChunkLength: 6.57	  EvalIndex: 2.020 Change:0.4%
#
# 1700	  MemLength: 10129 9.5	  ChunkLength: 6.61	  EvalIndex: 2.014 Change:0.3%
#
# 1800	  MemLength: 10293 9.7	  ChunkLength: 6.64	  EvalIndex: 2.007 Change:0.4%
#
# 1900	  MemLength: 10658 9.7	  ChunkLength: 6.71	  EvalIndex: 1.995 Change:0.6%
#
# 2000	  MemLength: 10992 9.7	  ChunkLength: 6.77	  EvalIndex: 1.982 Change:0.6%
#
# 2100	  MemLength: 11186 9.8	  ChunkLength: 6.80	  EvalIndex: 1.977 Change:0.3%
#
# 2200	  MemLength: 11277 9.8	  ChunkLength: 6.83	  EvalIndex: 1.970 Change:0.3%
#
# 2300	  MemLength: 11645 10.0	  ChunkLength: 6.88	  EvalIndex: 1.962 Change:0.4%
#
# 2400	  MemLength: 11914 10.0	  ChunkLength: 6.94	  EvalIndex: 1.951 Change:0.5%
#
# 2500	  MemLength: 12049 10.1	  ChunkLength: 6.97	  EvalIndex: 1.945 Change:0.3%
#
# 2600	  MemLength: 12224 10.1	  ChunkLength: 7.02	  EvalIndex: 1.935 Change:0.5%
#
# 2700	  MemLength: 12330 10.2	  ChunkLength: 7.03	  EvalIndex: 1.934 Change:0.0%
#
# 2800	  MemLength: 12549 10.3	  ChunkLength: 7.07	  EvalIndex: 1.927 Change:0.4%
#
# 2900	  MemLength: 12612 10.3	  ChunkLength: 7.09	  EvalIndex: 1.923 Change:0.2%
#
# 3000	  MemLength: 12792 10.3	  ChunkLength: 7.12	  EvalIndex: 1.915 Change:0.4%
#
# 3100	  MemLength: 13226 10.5	  ChunkLength: 7.19	  EvalIndex: 1.905 Change:0.5%
#
# 3200	  MemLength: 13481 10.6	  ChunkLength: 7.23	  EvalIndex: 1.897 Change:0.4%
#
# 3300	  MemLength: 13843 10.7	  ChunkLength: 7.29	  EvalIndex: 1.887 Change:0.5%
#
# 3400	  MemLength: 13944 10.7	  ChunkLength: 7.32	  EvalIndex: 1.882 Change:0.3%
#
# 3500	  MemLength: 14160 10.7	  ChunkLength: 7.35	  EvalIndex: 1.876 Change:0.3%
#
# 3600	  MemLength: 14255 10.8	  ChunkLength: 7.37	  EvalIndex: 1.872 Change:0.2%
#
# 3700	  MemLength: 14456 10.8	  ChunkLength: 7.41	  EvalIndex: 1.866 Change:0.3%
#
# 3800	  MemLength: 14576 10.9	  ChunkLength: 7.44	  EvalIndex: 1.860 Change:0.3%
#
# 3900	  MemLength: 14728 10.9	  ChunkLength: 7.46	  EvalIndex: 1.856 Change:0.2%
#
# 4000	  MemLength: 14762 10.9	  ChunkLength: 7.47	  EvalIndex: 1.854 Change:0.1%
#
# 4100	  MemLength: 15007 11.0	  ChunkLength: 7.51	  EvalIndex: 1.847 Change:0.4%
#
# 4200	  MemLength: 14987 11.0	  ChunkLength: 7.52	  EvalIndex: 1.846 Change:0.0%
#
# 4300	  MemLength: 15264 11.0	  ChunkLength: 7.57	  EvalIndex: 1.835 Change:0.6%
#
# 4400	  MemLength: 15739 11.2	  ChunkLength: 7.65	  EvalIndex: 1.822 Change:0.7%
#
# 4500	  MemLength: 15835 11.1	  ChunkLength: 7.67	  EvalIndex: 1.818 Change:0.2%
#
# 4600	  MemLength: 15853 11.2	  ChunkLength: 7.69	  EvalIndex: 1.815 Change:0.2%
#
# 4700	  MemLength: 15908 11.2	  ChunkLength: 7.70	  EvalIndex: 1.812 Change:0.1%
#
# 4800	  MemLength: 16101 11.2	  ChunkLength: 7.73	  EvalIndex: 1.807 Change:0.3%
#
# 4900	  MemLength: 16343 11.3	  ChunkLength: 7.79	  EvalIndex: 1.797 Change:0.6%
#
# 5000	  MemLength: 16558 11.3	  ChunkLength: 7.82	  EvalIndex: 1.792 Change:0.2%
#
# 5100	  MemLength: 16697 11.4	  ChunkLength: 7.84	  EvalIndex: 1.789 Change:0.2%
#
# 5200	  MemLength: 16784 11.4	  ChunkLength: 7.86	  EvalIndex: 1.785 Change:0.2%
#
# 5300	  MemLength: 16992 11.5	  ChunkLength: 7.89	  EvalIndex: 1.780 Change:0.3%
#
# 5400	  MemLength: 17145 11.5	  ChunkLength: 7.93	  EvalIndex: 1.775 Change:0.3%
#
# 5500	  MemLength: 17212 11.5	  ChunkLength: 7.94	  EvalIndex: 1.771 Change:0.2%
#
# 5600	  MemLength: 17409 11.6	  ChunkLength: 7.99	  EvalIndex: 1.764 Change:0.4%
#
# 5700	  MemLength: 17387 11.6	  ChunkLength: 7.98	  EvalIndex: 1.765 Change:-0.0%
#
# [Length] Word 5.596 Pred 7.971 Real 8.194	Model_SE 0.008 CI 0.021
# [F1] Model 52.11 Word 38.68

# %%
diff_lim_en = np.array([[5,3.674,32.15],
    [6,4.080,36.93],
    [7,4.631,43.94],
    [8,5.066,48.27],
    [9,5.317,49.92],
    [10,5.730,52.02],
    [11,5.707,51.75],
    [12,6.227,53.35],
    [13,6.380,53.55],
    [14,6.238,52.94],
    [15,6.557,53.42],
    [16,6.869,53.84],
    [17,7.125,53.84],
    [18,7.125,53.64],
    [19,7.076,53.38],
    [20,6.757,52.99],
    [21,7.045,53.24],
    [22,7.238,53.39],
    [23,7.026,53.15],
    [24,7.021,53.05],
    [25,6.902,53.18],
    [26,7.035,53.03],
    [27,7.033,52.96],
    [28,7.186,53.10],
    [29,7.099,52.99],
    [30,6.720,52.81]])
diff_lim_nl = np.array([[5,3.818,31.27],
    [6,4.149,35.74],
    [7,4.612,41.75],
    [8,5.199,46.74],
    [9,5.576,49.10],
    [10,5.825,50.39],
    [11,6.444,52.73],
    [12,6.486,52.60],
    [13,6.840,53.16],
    [14,6.833,52.85],
    [15,6.993,52.93],
    [16,7.228,52.88],
    [17,7.398,52.97],
    [18,7.708,52.89],
    [19,7.571,52.68],
    [20,7.188,52.17],
    [21,7.832,52.51],
    [22,7.983,52.57],
    [23,8.651,52.32],
    [24,7.224,52.05],
    [25,8.027,52.17],
    [26,8.013,52.25],
    [27,8.843,51.86],
    [28,8.390,52.03],
    [29,8.133,52.06],
    [30,7.971,52.11]])

scores = pd.DataFrame(np.array([diff_lim_en[0:,2], diff_lim_nl[0:,2]]), columns=diff_lim_en[0:,0].astype(int), index=['English', 'Dutch']).T

fig, ax = plt.subplots(dpi=300)
sns.set_theme(style="white")
sns.lineplot(data=scores, palette="tab10", linewidth=2.5, ax=ax, dashes=False)
ax.hlines(diff_lim_en[0:,2].max(),diff_lim_en[0,0],diff_lim_en[0,0]+np.argmax(diff_lim_en[0:,2]), color='#1f77b4',linestyles='dashed')
ax.hlines(diff_lim_nl[0:,2].max(),diff_lim_nl[0,0],diff_lim_nl[0,0]+np.argmax(diff_lim_nl[0:,2]), color='#ff7f0e',linestyles='dashed')
ax.vlines(diff_lim_en[0,0]+np.argmax(diff_lim_en[0:,2]), diff_lim_nl[0,2], diff_lim_en[0:,2].max(), color='#1f77b4',linestyles='dashed')
ax.vlines(diff_lim_nl[0,0]+np.argmax(diff_lim_nl[0:,2]), diff_lim_nl[0,2], diff_lim_nl[0:,2].max(), color='#ff7f0e',linestyles='dashed')

ax.text(1, diff_lim_en[0:,2].max(), diff_lim_en[0:,2].max(), color='#1f77b4')
ax.text(1, diff_lim_nl[0:,2].max()-0.8, diff_lim_nl[0:,2].max(), color='#ff7f0e')
ax.text(diff_lim_en[0,0]+np.argmax(diff_lim_en[0:,2])-0.5, diff_lim_nl[0,2]-2.2, '16', color='#1f77b4')
ax.text(diff_lim_nl[0,0]+np.argmax(diff_lim_nl[0:,2])-0.5, diff_lim_nl[0,2]-2.2, '13', color='#ff7f0e')

# ax.arrow(diff_lim_en[0,0]+np.argmax(diff_lim_en[0:,2]), diff_lim_en[0:,2].max()-5, 0, 5, color='#1f77b4', head_width=1, width=0.5, length_includes_head=True)
# ax.arrow(diff_lim_nl[0,0]+np.argmax(diff_lim_nl[0:,2]), diff_lim_nl[0:,2].max()-5, 0, 5, color='#ff7f0e', head_width=1, width=0.5, length_includes_head=True)
ax.set_xlabel('Maximum Unit Length')
ax.set_ylabel('F1 (%)')
print(diff_lim_en[0,0]+np.argmax(diff_lim_en[0:,2]),diff_lim_nl[0,0]+np.argmax(diff_lim_nl[0:,2]))
print(diff_lim_en[0:,2].max(),diff_lim_nl[0:,2].max())
# Out:
# 16.0 13.0
# 53.84 53.16
